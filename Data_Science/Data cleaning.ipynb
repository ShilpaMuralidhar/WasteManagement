# %% [markdown]
# ### Import dependencies

# %%
# %matplotlib notebook

# %%
import pandas as pd
#from IPython.display import display
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %% [markdown]
# ### Read city level data and concat with city level code

# %%
city_code = "/Users/shilpa/Desktop/Boringppl_project/WasteManagement/Data/city_level_codebook_0.csv"
city_code_df = pd.read_csv(city_code, encoding = 'utf-8')
city_code_df.head()
# Out:
#   regionID iso3c country_name       city_name incomeID  \
# 0      SAS   AFG  Afghanistan       Jalalabad      LIC
# 1      SAS   IND        India  Vishakhapatnam      LMC
# 2      LCN   COL     Colombia            Cali      UMC
# 3      SAS   AFG  Afghanistan           Kabul      LIC
# 4      SAS   AFG  Afghanistan          Hirat       LIC
#
#                               measurement        units    year  \
# 0  population_population_number_of_people  # of people  2015.0
# 1  population_population_number_of_people  # of people  2011.0
# 2  population_population_number_of_people  # of people  2005.0
# 3  population_population_number_of_people  # of people  2016.0
# 4  population_population_number_of_people  # of people  2015.0
#
#                                               source comments
# 0  Islamic Republic of Afghanistan. 2015. "State ...      NaN
# 1  Census of India. 2014. "Databook for PC 2011."...      NaN
# 2  CCAC (Climate and Clean Air Coalition). n.d.(d...      NaN
# 3  World Bank. 2016b. "Islamic  Republic of Afgha...      NaN
# 4  UN DESA (United Nations, Department of Economi...      NaN

# %%
city_data = "/Users/shilpa/Desktop/Boringppl_project/WasteManagement/Data/city_level_data_0_0.csv"
city_data_df = pd.read_csv(city_data, encoding = 'utf-8')
city_data_df.head()
# Out:
#   iso3c region_id country_name income_id       city_name  \
# 0   AFG       SAS  Afghanistan       LIC       Jalalabad
# 1   AFG       SAS  Afghanistan       LIC        Kandahar
# 2   AFG       SAS  Afghanistan       LIC  Mazar-E-Sharif
# 3   AFG       SAS  Afghanistan       LIC           Kabul
# 4   AFG       SAS  Afghanistan       LIC         HiratÂ
#
#   additional_data_annual_budget_for_waste_management_year  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   additional_data_annual_solid_waste_budget_year  \
# 0                                            NaN
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# 4                                            NaN
#
#    additional_data_annual_swm_budget_2017_year  \
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
#
#    additional_data_annual_swm_budget_year  \
# 0                                     NaN
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
#
#    additional_data_annual_waste_budget_year  ...  \
# 0                                       NaN  ...
# 1                                       NaN  ...
# 2                                       NaN  ...
# 3                                       NaN  ...
# 4                                       NaN  ...
#
#    waste_treatment_compost_percent  \
# 0                              NaN
# 1                              NaN
# 2                              NaN
# 3                              NaN
# 4                              NaN
#
#    waste_treatment_controlled_landfill_percent  \
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
#
#   waste_treatment_incineration_percent  \
# 0                                  NaN
# 1                                  NaN
# 2                                  NaN
# 3                                  NaN
# 4                                  NaN
#
#   waste_treatment_landfill_unspecified_percent  \
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
#
#   waste_treatment_open_dump_percent  waste_treatment_other_percent  \
# 0                             100.0                            NaN
# 1                             100.0                            NaN
# 2                             100.0                            NaN
# 3                              75.0                            NaN
# 4                             100.0                            NaN
#
#    waste_treatment_recycling_percent  \
# 0                                NaN
# 1                                NaN
# 2                                NaN
# 3                                NaN
# 4                                NaN
#
#    waste_treatment_sanitary_landfill_landfill_gas_system_percent  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   waste_treatment_unaccounted_for_percent  \
# 0                                     NaN
# 1                                     NaN
# 2                                     NaN
# 3                                    25.0
# 4                                     NaN
#
#   waste_treatment_waterways_marine_percent
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
#
# [5 rows x 113 columns]

# %%
city_data_df.columns
# Out:
# Index(['iso3c', 'region_id', 'country_name', 'income_id', 'city_name',
#        'additional_data_annual_budget_for_waste_management_year',
#        'additional_data_annual_solid_waste_budget_year',
#        'additional_data_annual_swm_budget_2017_year',
#        'additional_data_annual_swm_budget_year',
#        'additional_data_annual_waste_budget_year',
#        ...
#        'waste_treatment_compost_percent',
#        'waste_treatment_controlled_landfill_percent',
#        'waste_treatment_incineration_percent',
#        'waste_treatment_landfill_unspecified_percent',
#        'waste_treatment_open_dump_percent', 'waste_treatment_other_percent',
#        'waste_treatment_recycling_percent',
#        'waste_treatment_sanitary_landfill_landfill_gas_system_percent',
#        'waste_treatment_unaccounted_for_percent',
#        'waste_treatment_waterways_marine_percent'],
#       dtype='object', length=113)

# %%
result = pd.concat([city_code_df, city_data_df], axis=1, sort=False)
result
# Out:
#     regionID iso3c          country_name  \
# 0        SAS   AFG           Afghanistan
# 1        SAS   IND                 India
# 2        LCN   COL              Colombia
# 3        SAS   AFG           Afghanistan
# 4        SAS   AFG           Afghanistan
# 5        SAS   AFG           Afghanistan
# 6        SAS   AFG           Afghanistan
# 7        SSF   COM               Comoros
# 8        SAS   IND                 India
# 9        SAS   IND                 India
# 10       SSF   AGO                Angola
# 11       LCN   CRI            Costa Rica
# 12       ECS   ALB               Albania
# 13       LCN   CUB                  Cuba
# 14       ECS   ALB               Albania
# 15       SAS   IND                 India
# 16       ECS   CYP                Cyprus
# 17       MEA   ARE  United Arab Emirates
# 18       SAS   IND                 India
# 19       MEA   ARE  United Arab Emirates
# 20       LCN   ARG             Argentina
# 21       LCN   ARG             Argentina
# 22       LCN   ARG             Argentina
# 23       SAS   NPL                 Nepal
# 24       MEA   DJI              Djibouti
# 25       SAS   IND                 India
# 26       ECS   ARM               Armenia
# 27       ECS   DNK               Denmark
# 28       LCN   DOM    Dominican Republic
# 29       ECS   ARM               Armenia
# ..       ...   ...                   ...
# 654      EAS   VUT               Vanuatu
# 655      SAS   IND                 India
# 656      SSF   BEN                 Benin
# 657      ECS   XKX                Kosovo
# 658      SAS   IND                 India
# 659      ECS   POL                Poland
# 660      ECS   XKX                Kosovo
# 661      MEA   YEM           Yemen, Rep.
# 662      SSF   ETH              Ethiopia
# 663      SAS   MDV              Maldives
# 664      SSF   ZAF          South Africa
# 665      ECS   PRT              Portugal
# 666      SSF   ZAF          South Africa
# 667      LCN   PRY              Paraguay
# 668      LCN   PRY              Paraguay
# 669      SSF   ZAF          South Africa
# 670      SSF   ZMB                Zambia
# 671      SAS   IND                 India
# 672      SSF   ZMB                Zambia
# 673      LCN   MEX                Mexico
# 674      ECS   ROU               Romania
# 675      ECS   ROU               Romania
# 676      ECS   MKD        Macedonia, FYR
# 677      SSF   ZWE              Zimbabwe
# 678      ECS   RUS    Russian Federation
# 679      SSF   ZWE              Zimbabwe
# 680      SSF   ZWE              Zimbabwe
# 681      ECS   RUS    Russian Federation
# 682      SSF   ZWE              Zimbabwe
# 683      SSF   ZWE              Zimbabwe
#
#                                     city_name incomeID  \
# 0                                   Jalalabad      LIC
# 1                              Vishakhapatnam      LMC
# 2                                        Cali      UMC
# 3                                       Kabul      LIC
# 4                                      Hirat       LIC
# 5                              Mazar-E-Sharif      LIC
# 6                                    Kandahar      LIC
# 7                                      Moroni      LIC
# 8                                     Lucknow      LMC
# 9                         Greater Hyderabad        LMC
# 10                                     Luanda      LMC
# 11                                   San José      UMC
# 12                                      Korca      UMC
# 13                                     Havana      UMC
# 14                                      Vlora      UMC
# 15                                   Gwalior       LMC
# 16                                    Nicosia      HIC
# 17                                      Dubai      HIC
# 18                                   Srinagar      LMC
# 19                                  Abu Dhabi      HIC
# 20                                    Rosario      UMC
# 21                                    Córdoba      UMC
# 22   Ciudada Autónoma De Buenos Aires (Caba).      UMC
# 23                                    Pokhara      LIC
# 24                             Djiibouti City      LMC
# 25                           Pimpri-Chinchwad      LMC
# 26                                     Spitak      LMC
# 27                                 Copenhagen      HIC
# 28                              Santo Domingo      UMC
# 29                                   Vanadzor      LMC
# ..                                        ...      ...
# 654                                 Port Vila      LMC
# 655                            Greater Mumbai      LMC
# 656                                Porto Novo      LIC
# 657                                    Gjilan      LMC
# 658                                   Cuttack      LMC
# 659                                     Lodzi      HIC
# 660                                  Pristina      LMC
# 661                                     Sanaá      LMC
# 662                               Addis Ababa      LIC
# 663                                      Male      UMC
# 664                             Johannesburg       UMC
# 665                                 Guimarães      HIC
# 666                                    Durban      UMC
# 667                                  Asunción      UMC
# 668                           Ciudad Del Este      UMC
# 669                                 Cape Town      UMC
# 670                                    Ndola       LMC
# 671                                    Tenali      LMC
# 672                                    Lusaka      LMC
# 673                                 Monterrey      UMC
# 674                                 Bucharest      UMC
# 675                               Cluj-Napoca      UMC
# 676                                   Kratovo      UMC
# 677                                    Norton      LIC
# 678                             St.petersburg      UMC
# 679                                     Gweru      LIC
# 680                                   Harare       LIC
# 681                                  Kemerovo      UMC
# 682                                  Chinhoyi      LIC
# 683                                    Kariba      LIC
#
#                                  measurement        units    year  \
# 0     population_population_number_of_people  # of people  2015.0
# 1     population_population_number_of_people  # of people  2011.0
# 2     population_population_number_of_people  # of people  2005.0
# 3     population_population_number_of_people  # of people  2016.0
# 4     population_population_number_of_people  # of people  2015.0
# 5     population_population_number_of_people  # of people  2015.0
# 6     population_population_number_of_people  # of people  2015.0
# 7     population_population_number_of_people  # of people  2015.0
# 8     population_population_number_of_people  # of people  2011.0
# 9     population_population_number_of_people  # of people  2011.0
# 10    population_population_number_of_people  # of people  2010.0
# 11    population_population_number_of_people  # of people  2000.0
# 12    population_population_number_of_people  # of people  2011.0
# 13    population_population_number_of_people  # of people  2015.0
# 14    population_population_number_of_people  # of people  2011.0
# 15    population_population_number_of_people  # of people  2011.0
# 16    population_population_number_of_people  # of people  2016.0
# 17    population_population_number_of_people  # of people  2015.0
# 18    population_population_number_of_people  # of people  2011.0
# 19    population_population_number_of_people  # of people  2015.0
# 20    population_population_number_of_people  # of people  2015.0
# 21    population_population_number_of_people  # of people  2010.0
# 22    population_population_number_of_people  # of people  2014.0
# 23    population_population_number_of_people  # of people  2011.0
# 24    population_population_number_of_people  # of people  2000.0
# 25    population_population_number_of_people  # of people  2011.0
# 26    population_population_number_of_people  # of people  2013.0
# 27    population_population_number_of_people  # of people  2014.0
# 28    population_population_number_of_people  # of people  2013.0
# 29    population_population_number_of_people  # of people  2013.0
# ..                                       ...          ...     ...
# 654  total_msw_total_msw_generated_tons_year  tonnes/year  2012.0
# 655  total_msw_total_msw_generated_tons_year  tonnes/year  2016.0
# 656  total_msw_total_msw_generated_tons_year  tonnes/year  2000.0
# 657  total_msw_total_msw_generated_tons_year  tonnes/year  2011.0
# 658  total_msw_total_msw_generated_tons_year  tonnes/year  2016.0
# 659  total_msw_total_msw_generated_tons_year  tonnes/year  2015.0
# 660  total_msw_total_msw_generated_tons_year  tonnes/year  2015.0
# 661  total_msw_total_msw_generated_tons_year  tonnes/year  2016.0
# 662  total_msw_total_msw_generated_tons_year  tonnes/year  2010.0
# 663  total_msw_total_msw_generated_tons_year  tonnes/year  2017.0
# 664  total_msw_total_msw_generated_tons_year  tonnes/year  2017.0
# 665  total_msw_total_msw_generated_tons_year  tonnes/year  2015.0
# 666  total_msw_total_msw_generated_tons_year  tonnes/year  2007.0
# 667  total_msw_total_msw_generated_tons_year  tonnes/year  2010.0
# 668  total_msw_total_msw_generated_tons_year  tonnes/year  2010.0
# 669  total_msw_total_msw_generated_tons_year  tonnes/year  2012.0
# 670  total_msw_total_msw_generated_tons_year  tonnes/year  2012.0
# 671  total_msw_total_msw_generated_tons_year  tonnes/year  2016.0
# 672  total_msw_total_msw_generated_tons_year  tonnes/year  2011.0
# 673  total_msw_total_msw_generated_tons_year  tonnes/year  2016.0
# 674  total_msw_total_msw_generated_tons_year  tonnes/year  2014.0
# 675  total_msw_total_msw_generated_tons_year  tonnes/year  2016.0
# 676  total_msw_total_msw_generated_tons_year  tonnes/year  2015.0
# 677  total_msw_total_msw_generated_tons_year  tonnes/year  2012.0
# 678  total_msw_total_msw_generated_tons_year  tonnes/year  2013.0
# 679  total_msw_total_msw_generated_tons_year  tonnes/year  2014.0
# 680  total_msw_total_msw_generated_tons_year  tonnes/year  2000.0
# 681  total_msw_total_msw_generated_tons_year  tonnes/year  2016.0
# 682  total_msw_total_msw_generated_tons_year  tonnes/year  2012.0
# 683  total_msw_total_msw_generated_tons_year  tonnes/year  2012.0
#
#                                                 source  \
# 0    Islamic Republic of Afghanistan. 2015. "State ...
# 1    Census of India. 2014. "Databook for PC 2011."...
# 2    CCAC (Climate and Clean Air Coalition). n.d.(d...
# 3    World Bank. 2016b. "Islamic  Republic of Afgha...
# 4    UN DESA (United Nations, Department of Economi...
# 5    Islamic Republic of Afghanistan. 2015. "State ...
# 6    UN DESA (United Nations, Department of Economi...
# 7    UN (United Nations). 2017a. "Comoros General I...
# 8    Census of India. 2014. "Databook for PC 2011."...
# 9    Census of India. 2014. "Databook for PC 2011."...
# 10   UN DESA (United Nations, Department of Economi...
# 11   Municipality of San José. 2011. "Diagnosis on ...
# 12   Pop, Flaviu. 2017. Technical Expert, Green Par...
# 13   JICA (Japan International Cooperation Agency)....
# 14   KfW Bankengruppe. 2014. "Status Quo Report: In...
# 15   Census of India. 2014. "Databook for PC 2011."...
# 16   Nicosia Municipality. 2016. "Nicosia Municipal...
# 17   UN DESA (United Nations, Department of Economi...
# 18   Census of India. 2014. "Databook for PC 2011."...
# 19   UN DESA (United Nations, Department of Economi...
# 20   Anon. n.d.(c) "Province of Santa Fe" ["PROVINC...
# 21   Anon. n.d.(b) "Province of Cordoba" ["PROVINCI...
# 22   Morton, J. 2017. Personal communication betwee...
# 23   ADB (Asian Development Bank). 2013b. "Solid Wa...
# 24   UN DESA (United Nations, Department of Economi...
# 25   Census of India. 2014. "Databook for PC 2011."...
# 26   ERM (Environmental Resources Management) GmbH....
# 27   European Commission. 2014f. "Capital factsheet...
# 28   Nippon Koei. n.d. "Master Plan for the Integra...
# 29   ERM (Environmental Resources Management) GmbH....
# ..                                                 ...
# 654  ADB (Asian Development Bank). 2012c. "Vanuatu ...
# 655  India, Ministry of Urban Development. 2016. Sw...
# 656  Achankeng, Eric. 2003. "Globalization, Urbaniz...
# 657  Berlin University of Technology. 2017. "Solid ...
# 658  India, Ministry of Urban Development. 2016. Sw...
# 659  Poland Statistical Office. 2016."Lodzi Statist...
# 660  Berlin University of Technology. 2017. "Solid ...
# 661  Al-Eryani, Muammer. 2017. Director of Solid Wa...
# 662  Colby College Environmental Policy Group. 2012...
# 663  Maldives, MEE (Ministry of Environment and Ene...
# 664  Johannesburg City Government. 2011. "City of J...
# 665  Sepúlveda, Dalila, Isabel Loureiro, Cândida Vi...
# 666  Siemens AG. 2011. "African Green City Index." ...
# 667  Lima Morra, Roberto Andrés. 2017. Solid waste ...
# 668  Carbon Finance Assist. 2011. "Capacity buildin...
# 669  Miezah, Kodwo, Kwasi Obiri-Danso, Zsófia Kádár...
# 670  Edema, Mojisola O., Victora Sichamba, and Feli...
# 671  India, Ministry of Urban Development. 2016. Sw...
# 672  Edema, Mojisola O., Victora Sichamba, and Feli...
# 673  Anon. n.d.(f) "Statistics SIMEPRODE, 2016" ["E...
# 674  Bucharest Environmental Protection Agency. 201...
# 675  Anon. 2016. Local Strategy on the Development ...
# 676  Dimishkovska, Jovan, Biserka Dimishkovska, and...
# 677  GIZ (Deutsche Gesellschaft für Internationale ...
# 678  Tekes (Finnish Funding Agency for Technology a...
# 679  GIZ (Deutsche Gesellschaft für Internationale ...
# 680  Achankeng, Eric. 2003. "Globalization, Urbaniz...
# 681  Evgenievna, Bannikova Anastasia. 2017. "Develo...
# 682  GIZ (Deutsche Gesellschaft für Internationale ...
# 683  GIZ (Deutsche Gesellschaft für Internationale ...
#
#                                               comments  ...  \
# 0                                                  NaN  ...
# 1                                                  NaN  ...
# 2                                                  NaN  ...
# 3                                                  NaN  ...
# 4                                                  NaN  ...
# 5                                                  NaN  ...
# 6                                                  NaN  ...
# 7                                                  NaN  ...
# 8                                                  NaN  ...
# 9                                                  NaN  ...
# 10                                                 NaN  ...
# 11                                                 NaN  ...
# 12                                                 NaN  ...
# 13                                                 NaN  ...
# 14                                                 NaN  ...
# 15                                                 NaN  ...
# 16                                                 NaN  ...
# 17                                                 NaN  ...
# 18                                                 NaN  ...
# 19                                                 NaN  ...
# 20                                                 NaN  ...
# 21                                                 NaN  ...
# 22                                                 NaN  ...
# 23                                                 NaN  ...
# 24                                                 NaN  ...
# 25                                                 NaN  ...
# 26                                                 NaN  ...
# 27                                                 NaN  ...
# 28                                                 NaN  ...
# 29                                                 NaN  ...
# ..                                                 ...  ...
# 654  1 (75 tonnes/day within the city and a few res...  ...
# 655                            1 (6,843.30 tonnes/day)  ...
# 656                              1 (0.5 kg/person/day)  ...
# 657                                                  3  ...
# 658                              1 (183 tonnes/day); 7  ...
# 659                                                NaN  ...
# 660                                                NaN  ...
# 661  Value may be for total waste generated, not on...  ...
# 662                               1 (1,132 tonnes/day)  ...
# 663  1 (hh: 1.7 kg/person/day; resorts/hotels/guest...  ...
# 664                                                  5  ...
# 665                                                NaN  ...
# 666                             1 (519 kg/person/year)  ...
# 667                            1 (1.474 kg/person/day)  ...
# 668                              1 (432.14 tonnes/day)  ...
# 669            1 (0.7-1.3 kg/person/day; average used)  ...
# 670                             1 (0.52 kg/person/day)  ...
# 671                               1 (95 tonnes/day); 7  ...
# 672                                                NaN  ...
# 673  Value for waste received in Salinas Victoria L...  ...
# 674                                                NaN  ...
# 675                             1 (0.94 kg/person/day)  ...
# 676  5; calculated based on 1.5 percent annual incr...  ...
# 677                             1 (0.24 kg/person/day)  ...
# 678  Approximately 75 percent of total waste is pro...  ...
# 679                             1 (0.24 kg/person/day)  ...
# 680                              1 (0.7 kg/person/day)  ...
# 681                                                NaN  ...
# 682                             1 (0.26 kg/person/day)  ...
# 683                             1 (0.28 kg/person/day)  ...
#
#     waste_treatment_compost_percent  \
# 0                               NaN
# 1                               NaN
# 2                               NaN
# 3                               NaN
# 4                               NaN
# 5                               NaN
# 6                               NaN
# 7                               NaN
# 8                               9.0
# 9                               NaN
# 10                              NaN
# 11                             15.2
# 12                              NaN
# 13                              NaN
# 14                              NaN
# 15                              NaN
# 16                              NaN
# 17                              NaN
# 18                              NaN
# 19                              NaN
# 20                              NaN
# 21                              NaN
# 22                              NaN
# 23                              NaN
# 24                              NaN
# 25                              NaN
# 26                             14.0
# 27                              NaN
# 28                              NaN
# 29                              NaN
# ..                              ...
# 654                             NaN
# 655                             NaN
# 656                             NaN
# 657                             NaN
# 658                             NaN
# 659                             NaN
# 660                             NaN
# 661                             NaN
# 662                             NaN
# 663                             NaN
# 664                             NaN
# 665                             NaN
# 666                             NaN
# 667                             NaN
# 668                             NaN
# 669                             NaN
# 670                             NaN
# 671                             NaN
# 672                             NaN
# 673                             NaN
# 674                             NaN
# 675                             NaN
# 676                             NaN
# 677                             NaN
# 678                             NaN
# 679                             NaN
# 680                             NaN
# 681                             NaN
# 682                             NaN
# 683                             NaN
#
#     waste_treatment_controlled_landfill_percent  \
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
# 5                                           NaN
# 6                                        100.00
# 7                                           NaN
# 8                                           NaN
# 9                                           NaN
# 10                                        69.32
# 11                                          NaN
# 12                                          NaN
# 13                                          NaN
# 14                                          NaN
# 15                                         0.00
# 16                                          NaN
# 17                                        74.19
# 18                                        28.00
# 19                                          NaN
# 20                                          NaN
# 21                                          NaN
# 22                                          NaN
# 23                                          NaN
# 24                                          NaN
# 25                                          NaN
# 26                                          NaN
# 27                                          NaN
# 28                                          NaN
# 29                                          NaN
# ..                                          ...
# 654                                         NaN
# 655                                         NaN
# 656                                         NaN
# 657                                         NaN
# 658                                         NaN
# 659                                         NaN
# 660                                         NaN
# 661                                         NaN
# 662                                         NaN
# 663                                         NaN
# 664                                         NaN
# 665                                         NaN
# 666                                         NaN
# 667                                         NaN
# 668                                         NaN
# 669                                         NaN
# 670                                         NaN
# 671                                         NaN
# 672                                         NaN
# 673                                         NaN
# 674                                         NaN
# 675                                         NaN
# 676                                         NaN
# 677                                         NaN
# 678                                         NaN
# 679                                         NaN
# 680                                         NaN
# 681                                         NaN
# 682                                         NaN
# 683                                         NaN
#
#     waste_treatment_incineration_percent  \
# 0                                    NaN
# 1                                    NaN
# 2                                    NaN
# 3                                    NaN
# 4                                    NaN
# 5                                    NaN
# 6                                    NaN
# 7                                    NaN
# 8                                    NaN
# 9                                    NaN
# 10                                   NaN
# 11                                   NaN
# 12                                   NaN
# 13                                   NaN
# 14                                   NaN
# 15                                   NaN
# 16                                   NaN
# 17                                   NaN
# 18                                   NaN
# 19                                   NaN
# 20                                 24.21
# 21                                   NaN
# 22                                   NaN
# 23                                   NaN
# 24                                   NaN
# 25                                   NaN
# 26                                 26.00
# 27                                   NaN
# 28                                   NaN
# 29                                   NaN
# ..                                   ...
# 654                                  NaN
# 655                                  NaN
# 656                                  NaN
# 657                                  NaN
# 658                                  NaN
# 659                                  NaN
# 660                                  NaN
# 661                                  NaN
# 662                                  NaN
# 663                                  NaN
# 664                                  NaN
# 665                                  NaN
# 666                                  NaN
# 667                                  NaN
# 668                                  NaN
# 669                                  NaN
# 670                                  NaN
# 671                                  NaN
# 672                                  NaN
# 673                                  NaN
# 674                                  NaN
# 675                                  NaN
# 676                                  NaN
# 677                                  NaN
# 678                                  NaN
# 679                                  NaN
# 680                                  NaN
# 681                                  NaN
# 682                                  NaN
# 683                                  NaN
#
#     waste_treatment_landfill_unspecified_percent  \
# 0                                            NaN
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# 4                                            NaN
# 5                                            NaN
# 6                                            NaN
# 7                                            NaN
# 8                                            9.0
# 9                                            NaN
# 10                                           NaN
# 11                                           NaN
# 12                                           NaN
# 13                                           NaN
# 14                                           NaN
# 15                                           NaN
# 16                                           NaN
# 17                                           NaN
# 18                                           NaN
# 19                                           NaN
# 20                                           NaN
# 21                                           NaN
# 22                                           NaN
# 23                                           NaN
# 24                                           NaN
# 25                                           NaN
# 26                                           NaN
# 27                                           NaN
# 28                                           NaN
# 29                                           NaN
# ..                                           ...
# 654                                          NaN
# 655                                          NaN
# 656                                          NaN
# 657                                          NaN
# 658                                          NaN
# 659                                          NaN
# 660                                          NaN
# 661                                          NaN
# 662                                          NaN
# 663                                          NaN
# 664                                          NaN
# 665                                          NaN
# 666                                          NaN
# 667                                          NaN
# 668                                          NaN
# 669                                          NaN
# 670                                          NaN
# 671                                          NaN
# 672                                          NaN
# 673                                          NaN
# 674                                          NaN
# 675                                          NaN
# 676                                          NaN
# 677                                          NaN
# 678                                          NaN
# 679                                          NaN
# 680                                          NaN
# 681                                          NaN
# 682                                          NaN
# 683                                          NaN
#
#     waste_treatment_open_dump_percent waste_treatment_other_percent  \
# 0                              100.00                           NaN
# 1                              100.00                           NaN
# 2                              100.00                           NaN
# 3                               75.00                           NaN
# 4                              100.00                           NaN
# 5                                 NaN                           NaN
# 6                                 NaN                           NaN
# 7                               90.00                           NaN
# 8                               62.00                           NaN
# 9                                 NaN                           NaN
# 10                              30.00                           NaN
# 11                                NaN                           NaN
# 12                                NaN                         14.42
# 13                              90.00                           NaN
# 14                              93.16                           NaN
# 15                                NaN                           NaN
# 16                                NaN                           NaN
# 17                                NaN                           NaN
# 18                                NaN                           NaN
# 19                                NaN                           NaN
# 20                                NaN                           NaN
# 21                             100.00                           NaN
# 22                                NaN                           NaN
# 23                             100.00                           NaN
# 24                             100.00                           NaN
# 25                                NaN                           NaN
# 26                                NaN                           NaN
# 27                                NaN                           NaN
# 28                                NaN                           NaN
# 29                                NaN                           NaN
# ..                                ...                           ...
# 654                               NaN                           NaN
# 655                               NaN                           NaN
# 656                               NaN                           NaN
# 657                               NaN                           NaN
# 658                               NaN                           NaN
# 659                               NaN                           NaN
# 660                               NaN                           NaN
# 661                               NaN                           NaN
# 662                               NaN                           NaN
# 663                               NaN                           NaN
# 664                               NaN                           NaN
# 665                               NaN                           NaN
# 666                               NaN                           NaN
# 667                               NaN                           NaN
# 668                               NaN                           NaN
# 669                               NaN                           NaN
# 670                               NaN                           NaN
# 671                               NaN                           NaN
# 672                               NaN                           NaN
# 673                               NaN                           NaN
# 674                               NaN                           NaN
# 675                               NaN                           NaN
# 676                               NaN                           NaN
# 677                               NaN                           NaN
# 678                               NaN                           NaN
# 679                               NaN                           NaN
# 680                               NaN                           NaN
# 681                               NaN                           NaN
# 682                               NaN                           NaN
# 683                               NaN                           NaN
#
#     waste_treatment_recycling_percent  \
# 0                                 NaN
# 1                                 NaN
# 2                                 NaN
# 3                                 NaN
# 4                                 NaN
# 5                                 NaN
# 6                                 NaN
# 7                               10.00
# 8                               20.00
# 9                               25.00
# 10                               0.68
# 11                                NaN
# 12                               7.20
# 13                                NaN
# 14                                NaN
# 15                                NaN
# 16                              18.00
# 17                              25.81
# 18                              70.00
# 19                                NaN
# 20                                NaN
# 21                                NaN
# 22                                NaN
# 23                                NaN
# 24                                NaN
# 25                                NaN
# 26                              53.00
# 27                                NaN
# 28                                NaN
# 29                                NaN
# ..                                ...
# 654                               NaN
# 655                               NaN
# 656                               NaN
# 657                               NaN
# 658                               NaN
# 659                               NaN
# 660                               NaN
# 661                               NaN
# 662                               NaN
# 663                               NaN
# 664                               NaN
# 665                               NaN
# 666                               NaN
# 667                               NaN
# 668                               NaN
# 669                               NaN
# 670                               NaN
# 671                               NaN
# 672                               NaN
# 673                               NaN
# 674                               NaN
# 675                               NaN
# 676                               NaN
# 677                               NaN
# 678                               NaN
# 679                               NaN
# 680                               NaN
# 681                               NaN
# 682                               NaN
# 683                               NaN
#
#      waste_treatment_sanitary_landfill_landfill_gas_system_percent  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# 5                                                  NaN
# 6                                                  NaN
# 7                                                  NaN
# 8                                                  NaN
# 9                                                75.00
# 10                                                 NaN
# 11                                               89.19
# 12                                               61.50
# 13                                                 NaN
# 14                                                 NaN
# 15                                                 NaN
# 16                                                 NaN
# 17                                                 NaN
# 18                                                 NaN
# 19                                                 NaN
# 20                                               36.36
# 21                                                 NaN
# 22                                                 NaN
# 23                                                 NaN
# 24                                                 NaN
# 25                                                 NaN
# 26                                                4.00
# 27                                                 NaN
# 28                                                 NaN
# 29                                                 NaN
# ..                                                 ...
# 654                                                NaN
# 655                                                NaN
# 656                                                NaN
# 657                                                NaN
# 658                                                NaN
# 659                                                NaN
# 660                                                NaN
# 661                                                NaN
# 662                                                NaN
# 663                                                NaN
# 664                                                NaN
# 665                                                NaN
# 666                                                NaN
# 667                                                NaN
# 668                                                NaN
# 669                                                NaN
# 670                                                NaN
# 671                                                NaN
# 672                                                NaN
# 673                                                NaN
# 674                                                NaN
# 675                                                NaN
# 676                                                NaN
# 677                                                NaN
# 678                                                NaN
# 679                                                NaN
# 680                                                NaN
# 681                                                NaN
# 682                                                NaN
# 683                                                NaN
#
#      waste_treatment_unaccounted_for_percent  \
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                      25.00
# 4                                        NaN
# 5                                        NaN
# 6                                        NaN
# 7                                        NaN
# 8                                        NaN
# 9                                        NaN
# 10                                       NaN
# 11                                       NaN
# 12                                     16.88
# 13                                     10.00
# 14                                      6.84
# 15                                       NaN
# 16                                       NaN
# 17                                       NaN
# 18                                      2.00
# 19                                       NaN
# 20                                     49.22
# 21                                       NaN
# 22                                       NaN
# 23                                       NaN
# 24                                       NaN
# 25                                       NaN
# 26                                       NaN
# 27                                       NaN
# 28                                       NaN
# 29                                       NaN
# ..                                       ...
# 654                                      NaN
# 655                                      NaN
# 656                                      NaN
# 657                                      NaN
# 658                                      NaN
# 659                                      NaN
# 660                                      NaN
# 661                                      NaN
# 662                                      NaN
# 663                                      NaN
# 664                                      NaN
# 665                                      NaN
# 666                                      NaN
# 667                                      NaN
# 668                                      NaN
# 669                                      NaN
# 670                                      NaN
# 671                                      NaN
# 672                                      NaN
# 673                                      NaN
# 674                                      NaN
# 675                                      NaN
# 676                                      NaN
# 677                                      NaN
# 678                                      NaN
# 679                                      NaN
# 680                                      NaN
# 681                                      NaN
# 682                                      NaN
# 683                                      NaN
#
#      waste_treatment_waterways_marine_percent
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
# 5                                         NaN
# 6                                         NaN
# 7                                         NaN
# 8                                         NaN
# 9                                         NaN
# 10                                        NaN
# 11                                        NaN
# 12                                        NaN
# 13                                        NaN
# 14                                        NaN
# 15                                        NaN
# 16                                        NaN
# 17                                        NaN
# 18                                        NaN
# 19                                        NaN
# 20                                        NaN
# 21                                        NaN
# 22                                        NaN
# 23                                        NaN
# 24                                        NaN
# 25                                        NaN
# 26                                        NaN
# 27                                        NaN
# 28                                        NaN
# 29                                        NaN
# ..                                        ...
# 654                                       NaN
# 655                                       NaN
# 656                                       NaN
# 657                                       NaN
# 658                                       NaN
# 659                                       NaN
# 660                                       NaN
# 661                                       NaN
# 662                                       NaN
# 663                                       NaN
# 664                                       NaN
# 665                                       NaN
# 666                                       NaN
# 667                                       NaN
# 668                                       NaN
# 669                                       NaN
# 670                                       NaN
# 671                                       NaN
# 672                                       NaN
# 673                                       NaN
# 674                                       NaN
# 675                                       NaN
# 676                                       NaN
# 677                                       NaN
# 678                                       NaN
# 679                                       NaN
# 680                                       NaN
# 681                                       NaN
# 682                                       NaN
# 683                                       NaN
#
# [684 rows x 123 columns]

# %% [markdown]
# ### Read country level data and merge with country level code

# %%
country_code = "/Users/shilpa/Desktop/Boringppl_project/WasteManagement/Data/country_level_codebook.csv"
country_code_df = pd.read_csv(country_code, encoding = 'utf-8')
country_code_df
# Out:
#      regionID iso3c            country_name incomeID  \
# 0         ECS   LUX              Luxembourg      HIC
# 1         ECS   NOR                  Norway      HIC
# 2         MEA   MLT                   Malta      HIC
# 3         EAS   NZL             New Zealand      HIC
# 4         EAS   JPN                   Japan      HIC
# 5         MEA   JOR                  Jordan      LMC
# 6         ECS   UKR                 Ukraine      LMC
# 7         ECS   ROU                 Romania      UMC
# 8         ECS   SWE                  Sweden      HIC
# 9         ECS   BEL                 Belgium      HIC
# 10        ECS   MKD          Macedonia, FYR      UMC
# 11        ECS   FIN                 Finland      HIC
# 12        MEA   IRN      Iran, Islamic Rep.      UMC
# 13        EAS   MYS                Malaysia      UMC
# 14        EAS   IDN               Indonesia      LMC
# 15        NAC   CAN                  Canada      HIC
# 16        ECS   ISL                 Iceland      HIC
# 17        ECS   ARM                 Armenia      LMC
# 18        ECS   XKX                  Kosovo      LMC
# 19        ECS   NLD             Netherlands      HIC
# 20        ECS   CYP                  Cyprus      HIC
# 21        ECS   DNK                 Denmark      HIC
# 22        ECS   HRV                 Croatia      UMC
# 23        SAS   PAK                Pakistan      LMC
# 24        MEA   EGY        Egypt, Arab Rep.      LMC
# 25        MEA   ARE    United Arab Emirates      HIC
# 26        ECS   KGZ         Kyrgyz Republic      LMC
# 27        ECS   AUT                 Austria      HIC
# 28        ECS   EST                 Estonia      HIC
# 29        ECS   GBR          United Kingdom      HIC
# ...       ...   ...                     ...      ...
# 3746      EAS   PLW                   Palau      HIC
# 3747      SSF   COM                 Comoros      LIC
# 3748      LCN   GTM               Guatemala      LMC
# 3749      EAS   MHL        Marshall Islands      UMC
# 3750      ECS   SRB                  Serbia      UMC
# 3751      ECS   HRV                 Croatia      UMC
# 3752      ECS   IRL                 Ireland      HIC
# 3753      EAS   BRN       Brunei Darussalam      HIC
# 3754      MEA   IRQ                    Iraq      UMC
# 3755      ECS   DNK                 Denmark      HIC
# 3756      ECS   AZE              Azerbaijan      UMC
# 3757      ECS   BGR                Bulgaria      UMC
# 3758      ECS   BEL                 Belgium      HIC
# 3759      LCN   BRB                Barbados      HIC
# 3760      LCN   PRI             Puerto Rico      HIC
# 3761      ECS   GBR          United Kingdom      HIC
# 3762      MEA   KWT                  Kuwait      HIC
# 3763      LCN   CYM          Cayman Islands      HIC
# 3764      EAS   SGP               Singapore      HIC
# 3765      MEA   OMN                    Oman      HIC
# 3766      NAC   USA           United States      HIC
# 3767      ECS   ISL                 Iceland      HIC
# 3768      EAS   FJI                    Fiji      UMC
# 3769      ECS   MKD          Macedonia, FYR      UMC
# 3770      ECS   PRT                Portugal      HIC
# 3771      EAS   LAO                 Lao PDR      LMC
# 3772      MEA   YEM             Yemen, Rep.      LMC
# 3773      ECS   NOR                  Norway      HIC
# 3774      ECS   BIH  Bosnia and Herzegovina      UMC
# 3775      MEA   ISR                  Israel      HIC
#
#                                       measurement        units  year  \
# 0      special_waste_agricultural_waste_tons_year  tonnes/year  2014
# 1      special_waste_agricultural_waste_tons_year  tonnes/year  2014
# 2      special_waste_agricultural_waste_tons_year  tonnes/year  2014
# 3      special_waste_agricultural_waste_tons_year  tonnes/year  2014
# 4      special_waste_agricultural_waste_tons_year  tonnes/year  2010
# 5      special_waste_agricultural_waste_tons_year  tonnes/year  2014
# 6      special_waste_agricultural_waste_tons_year  tonnes/year  2015
# 7      special_waste_agricultural_waste_tons_year  tonnes/year  2014
# 8      special_waste_agricultural_waste_tons_year  tonnes/year  2014
# 9      special_waste_agricultural_waste_tons_year  tonnes/year  2014
# 10     special_waste_agricultural_waste_tons_year  tonnes/year  2014
# 11     special_waste_agricultural_waste_tons_year  tonnes/year  2014
# 12     special_waste_agricultural_waste_tons_year  tonnes/year  2005
# 13     special_waste_agricultural_waste_tons_year  tonnes/year  1997
# 14     special_waste_agricultural_waste_tons_year  tonnes/year  1997
# 15     special_waste_agricultural_waste_tons_year  tonnes/year  2006
# 16     special_waste_agricultural_waste_tons_year  tonnes/year  2013
# 17     special_waste_agricultural_waste_tons_year  tonnes/year  2015
# 18     special_waste_agricultural_waste_tons_year  tonnes/year  2015
# 19     special_waste_agricultural_waste_tons_year  tonnes/year  2014
# 20     special_waste_agricultural_waste_tons_year  tonnes/year  2015
# 21     special_waste_agricultural_waste_tons_year  tonnes/year  2015
# 22     special_waste_agricultural_waste_tons_year  tonnes/year  2015
# 23     special_waste_agricultural_waste_tons_year  tonnes/year  2013
# 24     special_waste_agricultural_waste_tons_year  tonnes/year  2012
# 25     special_waste_agricultural_waste_tons_year  tonnes/year  2015
# 26     special_waste_agricultural_waste_tons_year  tonnes/year  2010
# 27     special_waste_agricultural_waste_tons_year  tonnes/year  2014
# 28     special_waste_agricultural_waste_tons_year  tonnes/year  2015
# 29     special_waste_agricultural_waste_tons_year  tonnes/year  2014
# ...                                           ...          ...   ...
# 3746  composition_yard_garden_green_waste_percent            %  2014
# 3747  composition_yard_garden_green_waste_percent            %  2003
# 3748  composition_yard_garden_green_waste_percent            %  2013
# 3749  composition_yard_garden_green_waste_percent            %  2012
# 3750  composition_yard_garden_green_waste_percent            %  2012
# 3751  composition_yard_garden_green_waste_percent            %  2013
# 3752  composition_yard_garden_green_waste_percent            %  2012
# 3753  composition_yard_garden_green_waste_percent            %  2005
# 3754  composition_yard_garden_green_waste_percent            %  2009
# 3755  composition_yard_garden_green_waste_percent            %  2015
# 3756  composition_yard_garden_green_waste_percent            %  2015
# 3757  composition_yard_garden_green_waste_percent            %  2014
# 3758  composition_yard_garden_green_waste_percent            %  2014
# 3759  composition_yard_garden_green_waste_percent            %  2013
# 3760  composition_yard_garden_green_waste_percent            %  2003
# 3761  composition_yard_garden_green_waste_percent            %  2011
# 3762  composition_yard_garden_green_waste_percent            %  2014
# 3763  composition_yard_garden_green_waste_percent            %  2003
# 3764  composition_yard_garden_green_waste_percent            %  2017
# 3765  composition_yard_garden_green_waste_percent            %  2013
# 3766  composition_yard_garden_green_waste_percent            %  2014
# 3767  composition_yard_garden_green_waste_percent            %  2013
# 3768  composition_yard_garden_green_waste_percent            %  2011
# 3769  composition_yard_garden_green_waste_percent            %  2015
# 3770  composition_yard_garden_green_waste_percent            %  2015
# 3771  composition_yard_garden_green_waste_percent            %  2015
# 3772  composition_yard_garden_green_waste_percent            %  2016
# 3773  composition_yard_garden_green_waste_percent            %  2010
# 3774  composition_yard_garden_green_waste_percent            %  2015
# 3775  composition_yard_garden_green_waste_percent            %  2012
#
#                                                  source  \
# 0     Eurostat. 2017a. "Generation of waste by waste...
# 1     Eurostat. 2017a. "Generation of waste by waste...
# 2     Eurostat. 2017a. "Generation of waste by waste...
# 3     New Zealand, MFE (Ministry for the Environment...
# 4     Modak, Prasad, Agamuthu Pariatamby, Jeffrey Se...
# 5     GIZ and SWEEP-Net. 2014d. "Country Report on t...
# 6     GIZ (Deutsche Gesellschaft für Internationale ...
# 7     Eurostat. 2017a. "Generation of waste by waste...
# 8     Eurostat. 2017a. "Generation of waste by waste...
# 9     Eurostat. 2017a. "Generation of waste by waste...
# 10    Eurostat. 2017a. "Generation of waste by waste...
# 11    Eurostat. 2017a. "Generation of waste by waste...
# 12    Modak, Prasad, Agamuthu Pariatamby, Jeffrey Se...
# 13    Modak, Prasad, Agamuthu Pariatamby, Jeffrey Se...
# 14    Modak, Prasad, Agamuthu Pariatamby, Jeffrey Se...
# 15    Canada, Statistics Canada. 2012. "Human Activi...
# 16    Iceland, Statistics Iceland. 2015. "Statistica...
# 17    Armenia National Statistical Service. 2015. Ac...
# 18    Eurostat. 2017a. "Generation of waste by waste...
# 19    Eurostat. 2017a. "Generation of waste by waste...
# 20    Eurostat. 2017a. "Generation of waste by waste...
# 21    Eurostat. 2017a. "Generation of waste by waste...
# 22    Eurostat. 2017a. "Generation of waste by waste...
# 23    Saeed, M. A., A. Irshad, H. Sattar, G.E. Andre...
# 24    GIZ and SWEEP-Net. 2014c. "Country Report on t...
# 25    Abu Dhabi SCAD (Statistics Centre Abu Dhabi). ...
# 26    Anon. 2012. "Waste production and disposal in ...
# 27    Eurostat. 2017a. "Generation of waste by waste...
# 28    Eurostat. 2017a. "Generation of waste by waste...
# 29    Eurostat. 2017a. "Generation of waste by waste...
# ...                                                 ...
# 3746  Palau, MPIIC (Ministry of Public Infrastructur...
# 3747  Mouafo, V., and M. S. Hassani. 2011. "A Study ...
# 3748  Guatemala, INE (National Statistics Institute)...
# 3749  Marshall Islands. 2012. "National Waste Manage...
# 3750  Anthouli, Aida, Konstantine Aravossis, Rozy Ch...
# 3751  European Union. 2016. Municipal Waste Complian...
# 3752  Ireland, EPA (Environmental Protection Agency)...
# 3753  Shams, S., R. H. M. Juani, and Z. Guo. 2014. "...
# 3754  Al-Rawi, S. M., and A. Al-Tayar [ساطع محمود ال...
# 3755  Denmark, MST (Environmental Protection Agency)...
# 3756  Azerbaijan, Ministry of Economy. 2017. Nationa...
# 3757  Bulgaria, MOEW (Ministry of Environment and Wa...
# 3758  Belgium, OVAM (Public Waste Agency of Flanders...
# 3759  Burnside. 2014. "Preliminary Draft: Waste Char...
# 3760  Carim, Michael, Whitney Blake, Alex Amerman, B...
# 3761  United Kingdom, DEFRA (Department for Environm...
# 3762  Kuwait, Partnerships Technical Bureau. 2014. "...
# 3763  Amec Foster Wheeler. 2016. "National Solid Was...
# 3764  Singapore, NEA (National Environment Agency). ...
# 3765  Be'ah (Oman Environmental Service Holding Comp...
# 3766  US EPA (Environmental Protection Agency). 2014...
# 3767  Iceland, Statistics Iceland. 2015. Statistical...
# 3768  Richards, E., and D. Haynes. 2014. "Solid Wast...
# 3769  Lolos, T., G. Litas, E. Ieremiadi, C. Tsompani...
# 3770  Portugal, APA (Portuguese Environment Agency)....
# 3771  Keohanam, Bounthong. 2017. Director, Urban Dev...
# 3772  Al-Eryani, Muammer. 2017. Director of Solid Wa...
# 3773  EEA (European Environment Agency). 2013b. "Mun...
# 3774  Bosnia and Herzegovina, BHAS (Agency for Stati...
# 3775  Israel, Ministry of Environmental Protection. ...
#
#                                                comments
# 0                                               1; 2; 4
# 1     1; HW includes waste containing oil, solvents,...
# 2                                            1; 2; 3; 4
# 3     CandD waste reported as over 3 million tonnes/...
# 4     6 (excludes hazardous MSW); e-waste includes h...
# 5     HW includes phosphogypsum; CandD waste reporte...
# 6                                                   NaN
# 7                                               1; 2; 4
# 8                                               1; 2; 4
# 9                                               1; 2; 4
# 10                                                  NaN
# 11                                              1; 2; 4
# 12    12; HW value is hazardous component of industr...
# 13                             8 (IW, 2,279 tonnes/day)
# 14                              8 (HCW, 225 tonnes/day)
# 15    7 (8.2 kg/bed/day); IW includes tailings from ...
# 16    HW includes hazardous wastes (6,000 tonnes) an...
# 17    5; IW includes manufacturing (18,360 tonnes) a...
# 18                                              1; 2; 4
# 19                                              1; 2; 4
# 20                                              1; 2; 4
# 21                                              1; 2; 4
# 22                                              1; 2; 4
# 23                                                  NaN
# 24    HW reported as a range of 260,000-500,000 tonn...
# 25             3; HCW value for hazardous medical waste
# 26                                                    5
# 27                                              1; 2; 4
# 28                                              1; 2; 4
# 29                                              1; 2; 4
# ...                                                 ...
# 3746                                                NaN
# 3747                                                NaN
# 3748                                                NaN
# 3749                                                NaN
# 3750                                                NaN
# 3751                                                NaN
# 3752                                                NaN
# 3753                                                NaN
# 3754                                                NaN
# 3755                                                NaN
# 3756                                                NaN
# 3757                                                NaN
# 3758                                                NaN
# 3759                                                NaN
# 3760                                                NaN
# 3761                                                NaN
# 3762                                                NaN
# 3763                                                NaN
# 3764                                                NaN
# 3765                                                NaN
# 3766                                                NaN
# 3767                                                NaN
# 3768                                                NaN
# 3769                                                NaN
# 3770                                                NaN
# 3771                                                NaN
# 3772                                                NaN
# 3773                                                NaN
# 3774                                                NaN
# 3775                                                NaN
#
# [3776 rows x 9 columns]

# %%
country_data = "/Users/shilpa/Desktop/Boringppl_project/WasteManagement/Data/country_level_data_0.csv"
country_data_df = pd.read_csv(country_data, encoding = 'utf-8')
country_data_df.head(2)
# Out:
#   iso3c region_id country_name income_id           gdp  \
# 0   ABW       LCN        Aruba       HIC           NaN
# 1   AFG       SAS  Afghanistan       LIC  2.141361e+10
#
#    composition_food_organic_waste_percent  composition_glass_percent  \
# 0                                     NaN                        NaN
# 1                                     NaN                        NaN
#
#    composition_metal_percent  composition_other_percent  \
# 0                        NaN                        NaN
# 1                        NaN                        NaN
#
#    composition_paper_cardboard_percent  ...  \
# 0                                  NaN  ...
# 1                                  NaN  ...
#
#    waste_treatment_controlled_landfill_percent  \
# 0                                          NaN
# 1                                          NaN
#
#    waste_treatment_incineration_percent  \
# 0                                   NaN
# 1                                   NaN
#
#    waste_treatment_landfill_unspecified_percent  \
# 0                                           NaN
# 1                                           NaN
#
#    waste_treatment_open_dump_percent waste_treatment_other_percent  \
# 0                                NaN                           NaN
# 1                                NaN                           NaN
#
#   waste_treatment_recycling_percent  \
# 0                              11.0
# 1                               NaN
#
#   waste_treatment_sanitary_landfill_landfill_gas_system_percent  \
# 0                                                NaN
# 1                                                NaN
#
#   waste_treatment_unaccounted_for_percent  \
# 0                                    89.0
# 1                                     NaN
#
#   waste_treatment_waterways_marine_percent  where_where_is_this_data_measured
# 0                                      NaN                                NaN
# 1                                      NaN                              Other
#
# [2 rows x 51 columns]

# %%
country_data_df.columns
# Out:
# Index(['iso3c', 'region_id', 'country_name', 'income_id', 'gdp',
#        'composition_food_organic_waste_percent', 'composition_glass_percent',
#        'composition_metal_percent', 'composition_other_percent',
#        'composition_paper_cardboard_percent', 'composition_plastic_percent',
#        'composition_rubber_leather_percent', 'composition_wood_percent',
#        'composition_yard_garden_green_waste_percent',
#        'other_information_information_system_for_solid_waste_management',
#        'other_information_national_agency_to_enforce_solid_waste_laws_and_regulations',
#        'other_information_national_law_governing_solid_waste_management_in_the_country',
#        'other_information_ppp_rules_and_regulations',
#        'other_information_summary_of_key_solid_waste_information_made_available_to_the_public',
#        'population_population_number_of_people',
#        'special_waste_agricultural_waste_tons_year',
#        'special_waste_construction_and_demolition_waste_tons_year',
#        'special_waste_e_waste_tons_year',
#        'special_waste_hazardous_waste_tons_year',
#        'special_waste_industrial_waste_tons_year',
#        'special_waste_medical_waste_tons_year',
#        'total_msw_total_msw_generated_tons_year',
#        'waste_collection_coverage_rural_percent_of_geographic_area',
#        'waste_collection_coverage_rural_percent_of_households',
#        'waste_collection_coverage_rural_percent_of_population',
#        'waste_collection_coverage_rural_percent_of_waste',
#        'waste_collection_coverage_total_percent_of_geographic_area',
#        'waste_collection_coverage_total_percent_of_households',
#        'waste_collection_coverage_total_percent_of_population',
#        'waste_collection_coverage_total_percent_of_waste',
#        'waste_collection_coverage_urban_percent_of_geographic_area',
#        'waste_collection_coverage_urban_percent_of_households',
#        'waste_collection_coverage_urban_percent_of_population',
#        'waste_collection_coverage_urban_percent_of_waste',
#        'waste_treatment_anaerobic_digestion_percent',
#        'waste_treatment_compost_percent',
#        'waste_treatment_controlled_landfill_percent',
#        'waste_treatment_incineration_percent',
#        'waste_treatment_landfill_unspecified_percent',
#        'waste_treatment_open_dump_percent', 'waste_treatment_other_percent',
#        'waste_treatment_recycling_percent',
#        'waste_treatment_sanitary_landfill_landfill_gas_system_percent',
#        'waste_treatment_unaccounted_for_percent',
#        'waste_treatment_waterways_marine_percent',
#        'where_where_is_this_data_measured'],
#       dtype='object')

# %%
world_merge = pd.merge(country_data_df, country_code_df, on='country_name')
world_merge
# Out:
#      iso3c_x region_id  country_name income_id           gdp  \
# 0        ABW       LCN         Aruba       HIC           NaN
# 1        ABW       LCN         Aruba       HIC           NaN
# 2        ABW       LCN         Aruba       HIC           NaN
# 3        AFG       SAS   Afghanistan       LIC  2.141361e+10
# 4        AFG       SAS   Afghanistan       LIC  2.141361e+10
# 5        AFG       SAS   Afghanistan       LIC  2.141361e+10
# 6        AFG       SAS   Afghanistan       LIC  2.141361e+10
# 7        AGO       SSF        Angola       LMC  1.030423e+11
# 8        AGO       SSF        Angola       LMC  1.030423e+11
# 9        AGO       SSF        Angola       LMC  1.030423e+11
# 10       AGO       SSF        Angola       LMC  1.030423e+11
# 11       AGO       SSF        Angola       LMC  1.030423e+11
# 12       AGO       SSF        Angola       LMC  1.030423e+11
# 13       AGO       SSF        Angola       LMC  1.030423e+11
# 14       AGO       SSF        Angola       LMC  1.030423e+11
# 15       AGO       SSF        Angola       LMC  1.030423e+11
# 16       AGO       SSF        Angola       LMC  1.030423e+11
# 17       AGO       SSF        Angola       LMC  1.030423e+11
# 18       AGO       SSF        Angola       LMC  1.030423e+11
# 19       AGO       SSF        Angola       LMC  1.030423e+11
# 20       AGO       SSF        Angola       LMC  1.030423e+11
# 21       ALB       ECS       Albania       UMC  1.347108e+10
# 22       ALB       ECS       Albania       UMC  1.347108e+10
# 23       ALB       ECS       Albania       UMC  1.347108e+10
# 24       ALB       ECS       Albania       UMC  1.347108e+10
# 25       ALB       ECS       Albania       UMC  1.347108e+10
# 26       ALB       ECS       Albania       UMC  1.347108e+10
# 27       ALB       ECS       Albania       UMC  1.347108e+10
# 28       ALB       ECS       Albania       UMC  1.347108e+10
# 29       ALB       ECS       Albania       UMC  1.347108e+10
# ...      ...       ...           ...       ...           ...
# 3746     ZAF       SSF  South Africa       UMC  4.212087e+11
# 3747     ZAF       SSF  South Africa       UMC  4.212087e+11
# 3748     ZAF       SSF  South Africa       UMC  4.212087e+11
# 3749     ZMB       SSF        Zambia       LMC  2.703717e+10
# 3750     ZMB       SSF        Zambia       LMC  2.703717e+10
# 3751     ZMB       SSF        Zambia       LMC  2.703717e+10
# 3752     ZMB       SSF        Zambia       LMC  2.703717e+10
# 3753     ZMB       SSF        Zambia       LMC  2.703717e+10
# 3754     ZMB       SSF        Zambia       LMC  2.703717e+10
# 3755     ZMB       SSF        Zambia       LMC  2.703717e+10
# 3756     ZMB       SSF        Zambia       LMC  2.703717e+10
# 3757     ZMB       SSF        Zambia       LMC  2.703717e+10
# 3758     ZMB       SSF        Zambia       LMC  2.703717e+10
# 3759     ZMB       SSF        Zambia       LMC  2.703717e+10
# 3760     ZWE       SSF      Zimbabwe       LIC  1.481899e+10
# 3761     ZWE       SSF      Zimbabwe       LIC  1.481899e+10
# 3762     ZWE       SSF      Zimbabwe       LIC  1.481899e+10
# 3763     ZWE       SSF      Zimbabwe       LIC  1.481899e+10
# 3764     ZWE       SSF      Zimbabwe       LIC  1.481899e+10
# 3765     ZWE       SSF      Zimbabwe       LIC  1.481899e+10
# 3766     ZWE       SSF      Zimbabwe       LIC  1.481899e+10
# 3767     ZWE       SSF      Zimbabwe       LIC  1.481899e+10
# 3768     ZWE       SSF      Zimbabwe       LIC  1.481899e+10
# 3769     ZWE       SSF      Zimbabwe       LIC  1.481899e+10
# 3770     ZWE       SSF      Zimbabwe       LIC  1.481899e+10
# 3771     ZWE       SSF      Zimbabwe       LIC  1.481899e+10
# 3772     ZWE       SSF      Zimbabwe       LIC  1.481899e+10
# 3773     ZWE       SSF      Zimbabwe       LIC  1.481899e+10
# 3774     ZWE       SSF      Zimbabwe       LIC  1.481899e+10
# 3775     ZWE       SSF      Zimbabwe       LIC  1.481899e+10
#
#       composition_food_organic_waste_percent  composition_glass_percent  \
# 0                                        NaN                        NaN
# 1                                        NaN                        NaN
# 2                                        NaN                        NaN
# 3                                        NaN                        NaN
# 4                                        NaN                        NaN
# 5                                        NaN                        NaN
# 6                                        NaN                        NaN
# 7                                  51.800000                   6.700000
# 8                                  51.800000                   6.700000
# 9                                  51.800000                   6.700000
# 10                                 51.800000                   6.700000
# 11                                 51.800000                   6.700000
# 12                                 51.800000                   6.700000
# 13                                 51.800000                   6.700000
# 14                                 51.800000                   6.700000
# 15                                 51.800000                   6.700000
# 16                                 51.800000                   6.700000
# 17                                 51.800000                   6.700000
# 18                                 51.800000                   6.700000
# 19                                 51.800000                   6.700000
# 20                                 51.800000                   6.700000
# 21                                 51.400000                   4.500000
# 22                                 51.400000                   4.500000
# 23                                 51.400000                   4.500000
# 24                                 51.400000                   4.500000
# 25                                 51.400000                   4.500000
# 26                                 51.400000                   4.500000
# 27                                 51.400000                   4.500000
# 28                                 51.400000                   4.500000
# 29                                 51.400000                   4.500000
# ...                                      ...                        ...
# 3746                               16.381655                   5.200216
# 3747                               16.381655                   5.200216
# 3748                               16.381655                   5.200216
# 3749                                     NaN                        NaN
# 3750                                     NaN                        NaN
# 3751                                     NaN                        NaN
# 3752                                     NaN                        NaN
# 3753                                     NaN                        NaN
# 3754                                     NaN                        NaN
# 3755                                     NaN                        NaN
# 3756                                     NaN                        NaN
# 3757                                     NaN                        NaN
# 3758                                     NaN                        NaN
# 3759                                     NaN                        NaN
# 3760                               36.000000                   5.000000
# 3761                               36.000000                   5.000000
# 3762                               36.000000                   5.000000
# 3763                               36.000000                   5.000000
# 3764                               36.000000                   5.000000
# 3765                               36.000000                   5.000000
# 3766                               36.000000                   5.000000
# 3767                               36.000000                   5.000000
# 3768                               36.000000                   5.000000
# 3769                               36.000000                   5.000000
# 3770                               36.000000                   5.000000
# 3771                               36.000000                   5.000000
# 3772                               36.000000                   5.000000
# 3773                               36.000000                   5.000000
# 3774                               36.000000                   5.000000
# 3775                               36.000000                   5.000000
#
#       composition_metal_percent  composition_other_percent  \
# 0                           NaN                        NaN
# 1                           NaN                        NaN
# 2                           NaN                        NaN
# 3                           NaN                        NaN
# 4                           NaN                        NaN
# 5                           NaN                        NaN
# 6                           NaN                        NaN
# 7                      4.400000                  11.500000
# 8                      4.400000                  11.500000
# 9                      4.400000                  11.500000
# 10                     4.400000                  11.500000
# 11                     4.400000                  11.500000
# 12                     4.400000                  11.500000
# 13                     4.400000                  11.500000
# 14                     4.400000                  11.500000
# 15                     4.400000                  11.500000
# 16                     4.400000                  11.500000
# 17                     4.400000                  11.500000
# 18                     4.400000                  11.500000
# 19                     4.400000                  11.500000
# 20                     4.400000                  11.500000
# 21                     4.800000                  15.210000
# 22                     4.800000                  15.210000
# 23                     4.800000                  15.210000
# 24                     4.800000                  15.210000
# 25                     4.800000                  15.210000
# 26                     4.800000                  15.210000
# 27                     4.800000                  15.210000
# 28                     4.800000                  15.210000
# 29                     4.800000                  15.210000
# ...                         ...                        ...
# 3746                  16.910461                  45.020646
# 3747                  16.910461                  45.020646
# 3748                  16.910461                  45.020646
# 3749                        NaN                        NaN
# 3750                        NaN                        NaN
# 3751                        NaN                        NaN
# 3752                        NaN                        NaN
# 3753                        NaN                        NaN
# 3754                        NaN                        NaN
# 3755                        NaN                        NaN
# 3756                        NaN                        NaN
# 3757                        NaN                        NaN
# 3758                        NaN                        NaN
# 3759                        NaN                        NaN
# 3760                   6.000000                   3.000000
# 3761                   6.000000                   3.000000
# 3762                   6.000000                   3.000000
# 3763                   6.000000                   3.000000
# 3764                   6.000000                   3.000000
# 3765                   6.000000                   3.000000
# 3766                   6.000000                   3.000000
# 3767                   6.000000                   3.000000
# 3768                   6.000000                   3.000000
# 3769                   6.000000                   3.000000
# 3770                   6.000000                   3.000000
# 3771                   6.000000                   3.000000
# 3772                   6.000000                   3.000000
# 3773                   6.000000                   3.000000
# 3774                   6.000000                   3.000000
# 3775                   6.000000                   3.000000
#
#       composition_paper_cardboard_percent  ...  \
# 0                                     NaN  ...
# 1                                     NaN  ...
# 2                                     NaN  ...
# 3                                     NaN  ...
# 4                                     NaN  ...
# 5                                     NaN  ...
# 6                                     NaN  ...
# 7                               11.900000  ...
# 8                               11.900000  ...
# 9                               11.900000  ...
# 10                              11.900000  ...
# 11                              11.900000  ...
# 12                              11.900000  ...
# 13                              11.900000  ...
# 14                              11.900000  ...
# 15                              11.900000  ...
# 16                              11.900000  ...
# 17                              11.900000  ...
# 18                              11.900000  ...
# 19                              11.900000  ...
# 20                              11.900000  ...
# 21                               9.900000  ...
# 22                               9.900000  ...
# 23                               9.900000  ...
# 24                               9.900000  ...
# 25                               9.900000  ...
# 26                               9.900000  ...
# 27                               9.900000  ...
# 28                               9.900000  ...
# 29                               9.900000  ...
# ...                                   ...  ...
# 3746                             9.396918  ...
# 3747                             9.396918  ...
# 3748                             9.396918  ...
# 3749                                  NaN  ...
# 3750                                  NaN  ...
# 3751                                  NaN  ...
# 3752                                  NaN  ...
# 3753                                  NaN  ...
# 3754                                  NaN  ...
# 3755                                  NaN  ...
# 3756                                  NaN  ...
# 3757                                  NaN  ...
# 3758                                  NaN  ...
# 3759                                  NaN  ...
# 3760                            27.000000  ...
# 3761                            27.000000  ...
# 3762                            27.000000  ...
# 3763                            27.000000  ...
# 3764                            27.000000  ...
# 3765                            27.000000  ...
# 3766                            27.000000  ...
# 3767                            27.000000  ...
# 3768                            27.000000  ...
# 3769                            27.000000  ...
# 3770                            27.000000  ...
# 3771                            27.000000  ...
# 3772                            27.000000  ...
# 3773                            27.000000  ...
# 3774                            27.000000  ...
# 3775                            27.000000  ...
#
#       waste_treatment_waterways_marine_percent  \
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
# 5                                          NaN
# 6                                          NaN
# 7                                          NaN
# 8                                          NaN
# 9                                          NaN
# 10                                         NaN
# 11                                         NaN
# 12                                         NaN
# 13                                         NaN
# 14                                         NaN
# 15                                         NaN
# 16                                         NaN
# 17                                         NaN
# 18                                         NaN
# 19                                         NaN
# 20                                         NaN
# 21                                         NaN
# 22                                         NaN
# 23                                         NaN
# 24                                         NaN
# 25                                         NaN
# 26                                         NaN
# 27                                         NaN
# 28                                         NaN
# 29                                         NaN
# ...                                        ...
# 3746                                       NaN
# 3747                                       NaN
# 3748                                       NaN
# 3749                                       NaN
# 3750                                       NaN
# 3751                                       NaN
# 3752                                       NaN
# 3753                                       NaN
# 3754                                       NaN
# 3755                                       NaN
# 3756                                       NaN
# 3757                                       NaN
# 3758                                       NaN
# 3759                                       NaN
# 3760                                       NaN
# 3761                                       NaN
# 3762                                       NaN
# 3763                                       NaN
# 3764                                       NaN
# 3765                                       NaN
# 3766                                       NaN
# 3767                                       NaN
# 3768                                       NaN
# 3769                                       NaN
# 3770                                       NaN
# 3771                                       NaN
# 3772                                       NaN
# 3773                                       NaN
# 3774                                       NaN
# 3775                                       NaN
#
#       where_where_is_this_data_measured  regionID  iso3c_y incomeID  \
# 0                                   NaN       LCN      ABW      HIC
# 1                                   NaN       LCN      ABW      HIC
# 2                                   NaN       LCN      ABW      HIC
# 3                                 Other       SAS      AFG      LIC
# 4                                 Other       SAS      AFG      LIC
# 5                                 Other       SAS      AFG      LIC
# 6                                 Other       SAS      AFG      LIC
# 7                                   NaN       SSF      AGO      LMC
# 8                                   NaN       SSF      AGO      LMC
# 9                                   NaN       SSF      AGO      LMC
# 10                                  NaN       SSF      AGO      LMC
# 11                                  NaN       SSF      AGO      LMC
# 12                                  NaN       SSF      AGO      LMC
# 13                                  NaN       SSF      AGO      LMC
# 14                                  NaN       SSF      AGO      LMC
# 15                                  NaN       SSF      AGO      LMC
# 16                                  NaN       SSF      AGO      LMC
# 17                                  NaN       SSF      AGO      LMC
# 18                                  NaN       SSF      AGO      LMC
# 19                                  NaN       SSF      AGO      LMC
# 20                                  NaN       SSF      AGO      LMC
# 21                  Some disposal sites       ECS      ALB      UMC
# 22                  Some disposal sites       ECS      ALB      UMC
# 23                  Some disposal sites       ECS      ALB      UMC
# 24                  Some disposal sites       ECS      ALB      UMC
# 25                  Some disposal sites       ECS      ALB      UMC
# 26                  Some disposal sites       ECS      ALB      UMC
# 27                  Some disposal sites       ECS      ALB      UMC
# 28                  Some disposal sites       ECS      ALB      UMC
# 29                  Some disposal sites       ECS      ALB      UMC
# ...                                 ...       ...      ...      ...
# 3746                                NaN       SSF      ZAF      UMC
# 3747                                NaN       SSF      ZAF      UMC
# 3748                                NaN       SSF      ZAF      UMC
# 3749                                NaN       SSF      ZMB      LMC
# 3750                                NaN       SSF      ZMB      LMC
# 3751                                NaN       SSF      ZMB      LMC
# 3752                                NaN       SSF      ZMB      LMC
# 3753                                NaN       SSF      ZMB      LMC
# 3754                                NaN       SSF      ZMB      LMC
# 3755                                NaN       SSF      ZMB      LMC
# 3756                                NaN       SSF      ZMB      LMC
# 3757                                NaN       SSF      ZMB      LMC
# 3758                                NaN       SSF      ZMB      LMC
# 3759                                NaN       SSF      ZMB      LMC
# 3760                                NaN       SSF      ZWE      LIC
# 3761                                NaN       SSF      ZWE      LIC
# 3762                                NaN       SSF      ZWE      LIC
# 3763                                NaN       SSF      ZWE      LIC
# 3764                                NaN       SSF      ZWE      LIC
# 3765                                NaN       SSF      ZWE      LIC
# 3766                                NaN       SSF      ZWE      LIC
# 3767                                NaN       SSF      ZWE      LIC
# 3768                                NaN       SSF      ZWE      LIC
# 3769                                NaN       SSF      ZWE      LIC
# 3770                                NaN       SSF      ZWE      LIC
# 3771                                NaN       SSF      ZWE      LIC
# 3772                                NaN       SSF      ZWE      LIC
# 3773                                NaN       SSF      ZWE      LIC
# 3774                                NaN       SSF      ZWE      LIC
# 3775                                NaN       SSF      ZWE      LIC
#
#                                             measurement  \
# 0                     waste_treatment_recycling_percent
# 1               total_msw_total_msw_generated_tons_year
# 2               waste_treatment_unaccounted_for_percent
# 3            special_waste_agricultural_waste_tons_year
# 4                       special_waste_e_waste_tons_year
# 5                 special_waste_medical_waste_tons_year
# 6               total_msw_total_msw_generated_tons_year
# 7      waste_collection_coverage_total_percent_of_waste
# 8     waste_collection_coverage_total_percent_of_pop...
# 9     waste_collection_coverage_total_percent_of_hou...
# 10    waste_collection_coverage_total_percent_of_geo...
# 11                      special_waste_e_waste_tons_year
# 12               composition_food_organic_waste_percent
# 13                            composition_glass_percent
# 14                special_waste_medical_waste_tons_year
# 15                            composition_metal_percent
# 16                        waste_treatment_other_percent
# 17                            composition_other_percent
# 18                  composition_paper_cardboard_percent
# 19                          composition_plastic_percent
# 20              total_msw_total_msw_generated_tons_year
# 21    special_waste_construction_and_demolition_wast...
# 22     waste_collection_coverage_total_percent_of_waste
# 23    waste_collection_coverage_total_percent_of_pop...
# 24    waste_collection_coverage_total_percent_of_hou...
# 25    waste_collection_coverage_total_percent_of_geo...
# 26                      special_waste_e_waste_tons_year
# 27               composition_food_organic_waste_percent
# 28                            composition_glass_percent
# 29              special_waste_hazardous_waste_tons_year
# ...                                                 ...
# 3746                        composition_plastic_percent
# 3747                  waste_treatment_recycling_percent
# 3748            total_msw_total_msw_generated_tons_year
# 3749   waste_collection_coverage_total_percent_of_waste
# 3750  waste_collection_coverage_total_percent_of_pop...
# 3751  waste_collection_coverage_total_percent_of_hou...
# 3752  waste_collection_coverage_total_percent_of_geo...
# 3753   waste_collection_coverage_total_percent_of_waste
# 3754  waste_collection_coverage_total_percent_of_pop...
# 3755  waste_collection_coverage_total_percent_of_hou...
# 3756  waste_collection_coverage_total_percent_of_geo...
# 3757                    special_waste_e_waste_tons_year
# 3758            special_waste_hazardous_waste_tons_year
# 3759            total_msw_total_msw_generated_tons_year
# 3760   waste_collection_coverage_total_percent_of_waste
# 3761  waste_collection_coverage_total_percent_of_pop...
# 3762  waste_collection_coverage_total_percent_of_hou...
# 3763  waste_collection_coverage_total_percent_of_geo...
# 3764                    special_waste_e_waste_tons_year
# 3765             composition_food_organic_waste_percent
# 3766                          composition_glass_percent
# 3767            special_waste_hazardous_waste_tons_year
# 3768                          composition_metal_percent
# 3769                      waste_treatment_other_percent
# 3770                          composition_other_percent
# 3771                composition_paper_cardboard_percent
# 3772                        composition_plastic_percent
# 3773                  waste_treatment_recycling_percent
# 3774            total_msw_total_msw_generated_tons_year
# 3775            waste_treatment_unaccounted_for_percent
#
#                       units  year  \
# 0               tonnes/year  2013
# 1               tonnes/year  2013
# 2               tonnes/year   NaN
# 3               tonnes/year  2009
# 4               tonnes/year  2016
# 5               tonnes/year  2014
# 6               tonnes/year  2016
# 7     Percent of population  2011
# 8     Percent of population  2011
# 9     Percent of population  2011
# 10    Percent of population  2011
# 11              tonnes/year  2016
# 12                        %  2008
# 13                        %  2008
# 14              tonnes/year  2009
# 15                        %  2008
# 16                        %  2008
# 17                        %  2008
# 18                        %  2008
# 19                        %  2008
# 20              tonnes/year  2012
# 21              tonnes/year  2016
# 22    Percent of population  2015
# 23    Percent of population  2015
# 24    Percent of population  2015
# 25    Percent of population  2015
# 26              tonnes/year  2016
# 27                        %  2015
# 28                        %  2015
# 29              tonnes/year  2015
# ...                     ...   ...
# 3746                      %  2006
# 3747            tonnes/year  2011
# 3748            tonnes/year  2011
# 3749  Percent of households  2004
# 3750  Percent of households  2004
# 3751  Percent of households  2004
# 3752  Percent of households  2004
# 3753  Percent of population  2005
# 3754  Percent of population  2005
# 3755  Percent of population  2005
# 3756  Percent of population  2005
# 3757            tonnes/year  2016
# 3758            tonnes/year  2005
# 3759            tonnes/year  2011
# 3760  Percent of households  2013
# 3761  Percent of households  2013
# 3762  Percent of households  2013
# 3763  Percent of households  2013
# 3764            tonnes/year  2016
# 3765                      %  2015
# 3766                      %  2015
# 3767            tonnes/year  2012
# 3768                      %  2015
# 3769                      %  2015
# 3770                      %  2015
# 3771                      %  2015
# 3772                      %  2015
# 3773            tonnes/year  2005
# 3774            tonnes/year  2002
# 3775            tonnes/year   NaN
#
#                                                  source  \
# 0     PricewaterhouseCoopers Aruba. 2014. "Environme...
# 1     PricewaterhouseCoopers Aruba. 2014. "Environme...
# 2                                                   NaN
# 3     Milbrandt, Anelia, and Ralph Overend. 2011. "A...
# 4     Baldé, C.P., Forti V., Gray, V., Kuehr, R., St...
# 5     Islamic Republic of Afghanistan, Ministry of P...
# 6     World Bank. 2016d. "Rapid Assessment of Kabul ...
# 7     UNSD (United Nations Statistics Division). 201...
# 8     UNSD (United Nations Statistics Division). 201...
# 9     UNSD (United Nations Statistics Division). 201...
# 10    UNSD (United Nations Statistics Division). 201...
# 11    Baldé, C.P., Forti V., Gray, V., Kuehr, R., St...
# 12    UNSD (United Nations Statistics Division). 201...
# 13    UNSD (United Nations Statistics Division). 201...
# 14    Vide, Aderito de Castro. 2009. "Angola's Natio...
# 15    UNSD (United Nations Statistics Division). 201...
# 16    UNSD (United Nations Statistics Division). 201...
# 17    UNSD (United Nations Statistics Division). 201...
# 18    UNSD (United Nations Statistics Division). 201...
# 19    UNSD (United Nations Statistics Division). 201...
# 20    Angola, Ministry of Environment. 2012. "Strate...
# 21    Albania, INSTAT (Institute of Statistics). 201...
# 22    Albania, INSTAT (Institute of Statistics). 201...
# 23    Albania, INSTAT (Institute of Statistics). 201...
# 24    Albania, INSTAT (Institute of Statistics). 201...
# 25    Albania, INSTAT (Institute of Statistics). 201...
# 26    Baldé, C.P., Forti V., Gray, V., Kuehr, R., St...
# 27    Albania, INSTAT (Institute of Statistics). 201...
# 28    Albania, INSTAT (Institute of Statistics). 201...
# 29    Albania, INSTAT (Institute of Statistics). 201...
# ...                                                 ...
# 3746  South Africa, Department of Environmental Affa...
# 3747  South Africa, Department of Environmental Affa...
# 3748  South Africa, Department of Environmental Affa...
# 3749  Environmental Council of Zambia. 2004. "Nation...
# 3750  Environmental Council of Zambia. 2004. "Nation...
# 3751  Environmental Council of Zambia. 2004. "Nation...
# 3752  Environmental Council of Zambia. 2004. "Nation...
# 3753  UNSD (United Nations Statistics Division). 201...
# 3754  UNSD (United Nations Statistics Division). 201...
# 3755  UNSD (United Nations Statistics Division). 201...
# 3756  UNSD (United Nations Statistics Division). 201...
# 3757  Baldé, C.P., Forti V., Gray, V., Kuehr, R., St...
# 3758  UNSD (United Nations Statistics Division). 201...
# 3759  Edema, Mojisola O., Victora Sichamba, and Feli...
# 3760  Muchandiona, Aleck. 2013. "Challenges and Oppo...
# 3761  Muchandiona, Aleck. 2013. "Challenges and Oppo...
# 3762  Muchandiona, Aleck. 2013. "Challenges and Oppo...
# 3763  Muchandiona, Aleck. 2013. "Challenges and Oppo...
# 3764  Baldé, C.P., Forti V., Gray, V., Kuehr, R., St...
# 3765  Mohee, R., and M. A. Z. Bundhoo. 2015. "A Comp...
# 3766  Mohee, R., and M. A. Z. Bundhoo. 2015. "A Comp...
# 3767  UNSD (United Nations Statistics Division). 201...
# 3768  Mohee, R., and M. A. Z. Bundhoo. 2015. "A Comp...
# 3769  Mohee, R., and M. A. Z. Bundhoo. 2015. "A Comp...
# 3770  Mohee, R., and M. A. Z. Bundhoo. 2015. "A Comp...
# 3771  Mohee, R., and M. A. Z. Bundhoo. 2015. "A Comp...
# 3772  Mohee, R., and M. A. Z. Bundhoo. 2015. "A Comp...
# 3773  AFED (Arab Forum for Environment and Developme...
# 3774  GIZ (Deutsche Gesellschaft für Internationale ...
# 3775                                                NaN
#
#                                                comments
# 0                                                   NaN
# 1                                1 (2.34 kg/person/day)
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# 5                                                   NaN
# 6                          2 (Kabul, 0.7 kg/person/day)
# 7                                                   NaN
# 8                                                   NaN
# 9                                                   NaN
# 10                                                  NaN
# 11                                                  NaN
# 12                                                  NaN
# 13                                                  NaN
# 14                                                  NaN
# 15                                                  NaN
# 16    Data from Benguela Province; other includes te...
# 17    Data from Benguela Province; other includes te...
# 18                                                  NaN
# 19                                                  NaN
# 20                               1 (0.46 kg/person/day)
# 21                                                  NaN
# 22                                                  NaN
# 23                                                  NaN
# 24                                                  NaN
# 25                                                  NaN
# 26                                                  NaN
# 27                                                  NaN
# 28                                                  NaN
# 29                                                  NaN
# ...                                                 ...
# 3746                                                NaN
# 3747                                                NaN
# 3748  Includes municipal, commercial, and industrial...
# 3749                                                NaN
# 3750                                                NaN
# 3751                                                NaN
# 3752                                                NaN
# 3753                                                NaN
# 3754                                                NaN
# 3755                                                NaN
# 3756                                                NaN
# 3757                                                NaN
# 3758                                                NaN
# 3759           2 (Lusaka and Ndola, 0.72 kg/person/day)
# 3760                                                NaN
# 3761                                                NaN
# 3762                                                NaN
# 3763                                                NaN
# 3764                                                NaN
# 3765                                                NaN
# 3766                                                NaN
# 3767                                                NaN
# 3768                                                NaN
# 3769                                                  1
# 3770                                                  1
# 3771                                                NaN
# 3772                                                NaN
# 3773                                                NaN
# 3774  2 (Chinhoyi, Gweru, Kariba, Kadoma, and Norton...
# 3775                                                NaN
#
# [3776 rows x 59 columns]

# %%
world_merge.columns
# Out:
# Index(['iso3c_x', 'region_id', 'country_name', 'income_id', 'gdp',
#        'composition_food_organic_waste_percent', 'composition_glass_percent',
#        'composition_metal_percent', 'composition_other_percent',
#        'composition_paper_cardboard_percent', 'composition_plastic_percent',
#        'composition_rubber_leather_percent', 'composition_wood_percent',
#        'composition_yard_garden_green_waste_percent',
#        'other_information_information_system_for_solid_waste_management',
#        'other_information_national_agency_to_enforce_solid_waste_laws_and_regulations',
#        'other_information_national_law_governing_solid_waste_management_in_the_country',
#        'other_information_ppp_rules_and_regulations',
#        'other_information_summary_of_key_solid_waste_information_made_available_to_the_public',
#        'population_population_number_of_people',
#        'special_waste_agricultural_waste_tons_year',
#        'special_waste_construction_and_demolition_waste_tons_year',
#        'special_waste_e_waste_tons_year',
#        'special_waste_hazardous_waste_tons_year',
#        'special_waste_industrial_waste_tons_year',
#        'special_waste_medical_waste_tons_year',
#        'total_msw_total_msw_generated_tons_year',
#        'waste_collection_coverage_rural_percent_of_geographic_area',
#        'waste_collection_coverage_rural_percent_of_households',
#        'waste_collection_coverage_rural_percent_of_population',
#        'waste_collection_coverage_rural_percent_of_waste',
#        'waste_collection_coverage_total_percent_of_geographic_area',
#        'waste_collection_coverage_total_percent_of_households',
#        'waste_collection_coverage_total_percent_of_population',
#        'waste_collection_coverage_total_percent_of_waste',
#        'waste_collection_coverage_urban_percent_of_geographic_area',
#        'waste_collection_coverage_urban_percent_of_households',
#        'waste_collection_coverage_urban_percent_of_population',
#        'waste_collection_coverage_urban_percent_of_waste',
#        'waste_treatment_anaerobic_digestion_percent',
#        'waste_treatment_compost_percent',
#        'waste_treatment_controlled_landfill_percent',
#        'waste_treatment_incineration_percent',
#        'waste_treatment_landfill_unspecified_percent',
#        'waste_treatment_open_dump_percent', 'waste_treatment_other_percent',
#        'waste_treatment_recycling_percent',
#        'waste_treatment_sanitary_landfill_landfill_gas_system_percent',
#        'waste_treatment_unaccounted_for_percent',
#        'waste_treatment_waterways_marine_percent',
#        'where_where_is_this_data_measured', 'regionID', 'iso3c_y', 'incomeID',
#        'measurement', 'units', 'year', 'source', 'comments'],
#       dtype='object')

# %% [markdown]
# ### Merge city with country on "country name"

# %%
world_city_merge = pd.merge(city_data_df, country_data_df,on='country_name')
world_city_merge.head(2)
# Out:
#   iso3c_x region_id_x country_name income_id_x  city_name  \
# 0     AFG         SAS  Afghanistan         LIC  Jalalabad
# 1     AFG         SAS  Afghanistan         LIC   Kandahar
#
#   additional_data_annual_budget_for_waste_management_year  \
# 0                                                NaN
# 1                                                NaN
#
#   additional_data_annual_solid_waste_budget_year  \
# 0                                            NaN
# 1                                            NaN
#
#    additional_data_annual_swm_budget_2017_year  \
# 0                                          NaN
# 1                                          NaN
#
#    additional_data_annual_swm_budget_year  \
# 0                                     NaN
# 1                                     NaN
#
#    additional_data_annual_waste_budget_year  ...  \
# 0                                       NaN  ...
# 1                                       NaN  ...
#
#    waste_treatment_controlled_landfill_percent_y  \
# 0                                            NaN
# 1                                            NaN
#
#    waste_treatment_incineration_percent_y  \
# 0                                     NaN
# 1                                     NaN
#
#   waste_treatment_landfill_unspecified_percent_y  \
# 0                                            NaN
# 1                                            NaN
#
#   waste_treatment_open_dump_percent_y waste_treatment_other_percent_y  \
# 0                                 NaN                             NaN
# 1                                 NaN                             NaN
#
#    waste_treatment_recycling_percent_y  \
# 0                                  NaN
# 1                                  NaN
#
#    waste_treatment_sanitary_landfill_landfill_gas_system_percent_y  \
# 0                                                NaN
# 1                                                NaN
#
#    waste_treatment_unaccounted_for_percent_y  \
# 0                                        NaN
# 1                                        NaN
#
#   waste_treatment_waterways_marine_percent_y where_where_is_this_data_measured
# 0                                        NaN                             Other
# 1                                        NaN                             Other
#
# [2 rows x 163 columns]

# %%
world_city_merge.columns
# Out:
# Index(['iso3c_x', 'region_id_x', 'country_name', 'income_id_x', 'city_name',
#        'additional_data_annual_budget_for_waste_management_year',
#        'additional_data_annual_solid_waste_budget_year',
#        'additional_data_annual_swm_budget_2017_year',
#        'additional_data_annual_swm_budget_year',
#        'additional_data_annual_waste_budget_year',
#        ...
#        'waste_treatment_controlled_landfill_percent_y',
#        'waste_treatment_incineration_percent_y',
#        'waste_treatment_landfill_unspecified_percent_y',
#        'waste_treatment_open_dump_percent_y',
#        'waste_treatment_other_percent_y',
#        'waste_treatment_recycling_percent_y',
#        'waste_treatment_sanitary_landfill_landfill_gas_system_percent_y',
#        'waste_treatment_unaccounted_for_percent_y',
#        'waste_treatment_waterways_marine_percent_y',
#        'where_where_is_this_data_measured'],
#       dtype='object', length=163)

# %% [markdown]
# #### Use country level data to group by "year 2017". World group had three types of data -
# #### 1. waste generated
# #### 2. information
# #### 3. collection
# #### 4. treatment

# %%
grouped = world_merge.groupby('year')
world_group_2017 = grouped.get_group('2017')
world_group_2017.head()

#for name,group in grouped:
    #print(grouped.get_group('2017'))
# Out:
#     iso3c_x region_id        country_name income_id           gdp  \
# 538     BTN       SAS              Bhutan       LMC  2.234759e+09
# 905     DOM       LCN  Dominican Republic       UMC  7.366413e+10
# 911     DOM       LCN  Dominican Republic       UMC  7.366413e+10
# 913     DOM       LCN  Dominican Republic       UMC  7.366413e+10
# 918     DZA       MEA             Algeria       UMC  1.960348e+11
#
#      composition_food_organic_waste_percent  composition_glass_percent  \
# 538                                    58.0                        4.0
# 905                                    51.0                        6.0
# 911                                    51.0                        6.0
# 913                                    51.0                        6.0
# 918                                    54.4                        1.2
#
#      composition_metal_percent  composition_other_percent  \
# 538                        1.0                        7.0
# 905                        3.0                       10.0
# 911                        3.0                       10.0
# 913                        3.0                       10.0
# 918                        2.8                        0.8
#
#      composition_paper_cardboard_percent  ...  \
# 538                                 17.0  ...
# 905                                 16.0  ...
# 911                                 16.0  ...
# 913                                 16.0  ...
# 918                                  9.8  ...
#
#      waste_treatment_waterways_marine_percent  \
# 538                                       NaN
# 905                                       NaN
# 911                                       NaN
# 913                                       NaN
# 918                                       NaN
#
#      where_where_is_this_data_measured  regionID  iso3c_y incomeID  \
# 538                             Source       SAS      BTN      LMC
# 905                              Other       LCN      DOM      UMC
# 911                              Other       LCN      DOM      UMC
# 913                              Other       LCN      DOM      UMC
# 918                      Disposal Site       MEA      DZA      UMC
#
#                                            measurement                  units  \
# 538              special_waste_medical_waste_tons_year            tonnes/year
# 905                  waste_treatment_open_dump_percent            tonnes/year
# 911  waste_treatment_sanitary_landfill_landfill_gas...            tonnes/year
# 913            waste_treatment_unaccounted_for_percent            tonnes/year
# 918  waste_collection_coverage_rural_percent_of_hou...  Percent of population
#
#      year                                             source  \
# 538  2017  WHO (World Health Organization). 2017. "Report...
# 905  2017  Dominican Republic, Ministry of Environment an...
# 911  2017  Dominican Republic, Ministry of Environment an...
# 913  2017                                                NaN
# 918  2017  Ouamane, Karim. 2017. General Director, Waste ...
#
#                                               comments
# 538                                                NaN
# 905                                                NaN
# 911                                                NaN
# 913  OD: Calculated based on the sum of other treat...
# 918                                                NaN
#
# [5 rows x 59 columns]

# %%
world_group_2017.columns
# Out:
# Index(['iso3c_x', 'region_id', 'country_name', 'income_id', 'gdp',
#        'composition_food_organic_waste_percent', 'composition_glass_percent',
#        'composition_metal_percent', 'composition_other_percent',
#        'composition_paper_cardboard_percent', 'composition_plastic_percent',
#        'composition_rubber_leather_percent', 'composition_wood_percent',
#        'composition_yard_garden_green_waste_percent',
#        'other_information_information_system_for_solid_waste_management',
#        'other_information_national_agency_to_enforce_solid_waste_laws_and_regulations',
#        'other_information_national_law_governing_solid_waste_management_in_the_country',
#        'other_information_ppp_rules_and_regulations',
#        'other_information_summary_of_key_solid_waste_information_made_available_to_the_public',
#        'population_population_number_of_people',
#        'special_waste_agricultural_waste_tons_year',
#        'special_waste_construction_and_demolition_waste_tons_year',
#        'special_waste_e_waste_tons_year',
#        'special_waste_hazardous_waste_tons_year',
#        'special_waste_industrial_waste_tons_year',
#        'special_waste_medical_waste_tons_year',
#        'total_msw_total_msw_generated_tons_year',
#        'waste_collection_coverage_rural_percent_of_geographic_area',
#        'waste_collection_coverage_rural_percent_of_households',
#        'waste_collection_coverage_rural_percent_of_population',
#        'waste_collection_coverage_rural_percent_of_waste',
#        'waste_collection_coverage_total_percent_of_geographic_area',
#        'waste_collection_coverage_total_percent_of_households',
#        'waste_collection_coverage_total_percent_of_population',
#        'waste_collection_coverage_total_percent_of_waste',
#        'waste_collection_coverage_urban_percent_of_geographic_area',
#        'waste_collection_coverage_urban_percent_of_households',
#        'waste_collection_coverage_urban_percent_of_population',
#        'waste_collection_coverage_urban_percent_of_waste',
#        'waste_treatment_anaerobic_digestion_percent',
#        'waste_treatment_compost_percent',
#        'waste_treatment_controlled_landfill_percent',
#        'waste_treatment_incineration_percent',
#        'waste_treatment_landfill_unspecified_percent',
#        'waste_treatment_open_dump_percent', 'waste_treatment_other_percent',
#        'waste_treatment_recycling_percent',
#        'waste_treatment_sanitary_landfill_landfill_gas_system_percent',
#        'waste_treatment_unaccounted_for_percent',
#        'waste_treatment_waterways_marine_percent',
#        'where_where_is_this_data_measured', 'regionID', 'iso3c_y', 'incomeID',
#        'measurement', 'units', 'year', 'source', 'comments'],
#       dtype='object')

# %%
List_Of_Categories_In_Column = list(world_group_2017['income_id'].value_counts().index)

List_Of_Categories_In_Column
# Out:
# ['UMC', 'HIC', 'LMC', 'LIC']

# %% [markdown]
# ### EDA on waste generated columns after grouping based on income_id

# %%
waste_generated = world_group_2017[['country_name', 
                                    'income_id', 
                                    'gdp', 
                                    'population_population_number_of_people',
                                    'composition_food_organic_waste_percent', 
                                    'composition_glass_percent',
                                    'composition_metal_percent', 
                                    'composition_other_percent',
                                    'composition_paper_cardboard_percent', 
                                    'composition_plastic_percent',
                                    'composition_rubber_leather_percent', 
                                    'composition_wood_percent',
                                    'composition_yard_garden_green_waste_percent']]
waste_generated.fillna(0).head(2)
#Nan values were converted too zeros because dtypes were float
# Out:
#            country_name income_id           gdp  \
# 538              Bhutan       LMC  2.234759e+09
# 905  Dominican Republic       UMC  7.366413e+10
#
#      population_population_number_of_people  \
# 538                                686958.0
# 905                              10528394.0
#
#      composition_food_organic_waste_percent  composition_glass_percent  \
# 538                                    58.0                        4.0
# 905                                    51.0                        6.0
#
#      composition_metal_percent  composition_other_percent  \
# 538                        1.0                        7.0
# 905                        3.0                       10.0
#
#      composition_paper_cardboard_percent  composition_plastic_percent  \
# 538                                 17.0                         13.0
# 905                                 16.0                         10.0
#
#      composition_rubber_leather_percent  composition_wood_percent  \
# 538                                 0.0                       0.0
# 905                                 0.0                       4.0
#
#      composition_yard_garden_green_waste_percent
# 538                                          0.0
# 905                                          0.0

# %%
waste_generated_LIC = waste_generated.groupby('income_id').get_group('LIC').fillna(0).drop_duplicates().set_index('country_name')
waste_generated_LIC.columns
# Out:
# Index(['income_id', 'gdp', 'population_population_number_of_people',
#        'composition_food_organic_waste_percent', 'composition_glass_percent',
#        'composition_metal_percent', 'composition_other_percent',
#        'composition_paper_cardboard_percent', 'composition_plastic_percent',
#        'composition_rubber_leather_percent', 'composition_wood_percent',
#        'composition_yard_garden_green_waste_percent'],
#       dtype='object')

# %%
LIC_waste = pd.DataFrame(waste_generated_LIC, columns =[
       'composition_food_organic_waste_percent', 'composition_glass_percent',
       'composition_metal_percent', 'composition_other_percent',
       'composition_paper_cardboard_percent', 'composition_plastic_percent',
       'composition_rubber_leather_percent', 'composition_wood_percent'])
LIC_waste.plot.bar(legend=True, stacked=True);
plt.legend(loc='center left',bbox_to_anchor=(1.0, 0.5))
plt.show()
plt.tight_layout()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
waste_generated_LMC = waste_generated.groupby('income_id').get_group('LMC').fillna(0).drop_duplicates().set_index('country_name')
waste_generated_LMC
# Out:
#              income_id           gdp  population_population_number_of_people  \
# country_name
# Bhutan             LMC  2.234759e+09                            6.869580e+05
# Indonesia          LMC  1.037864e+12                            2.611155e+08
# India              LMC  2.466177e+12                            1.071478e+09
# Sri Lanka          LMC  7.990704e+10                            2.120300e+07
# Myanmar            LMC  7.446983e+10                            4.609546e+07
# Pakistan           LMC  2.278669e+11                            1.932035e+08
#
#               composition_food_organic_waste_percent  \
# country_name
# Bhutan                                          58.0
# Indonesia                                       53.8
# India                                            0.0
# Sri Lanka                                       62.0
# Myanmar                                          0.0
# Pakistan                                        30.0
#
#               composition_glass_percent  composition_metal_percent  \
# country_name
# Bhutan                              4.0                        1.0
# Indonesia                           2.5                        1.8
# India                               0.0                        0.0
# Sri Lanka                           2.0                        3.0
# Myanmar                             0.0                        0.0
# Pakistan                            6.0                        4.0
#
#               composition_other_percent  composition_paper_cardboard_percent  \
# country_name
# Bhutan                              7.0                                 17.0
# Indonesia                          12.9                                 14.9
# India                               0.0                                  0.0
# Sri Lanka                          13.0                                  7.0
# Myanmar                             0.0                                  0.0
# Pakistan                           20.0                                 13.0
#
#               composition_plastic_percent  composition_rubber_leather_percent  \
# country_name
# Bhutan                               13.0                                 0.0
# Indonesia                            14.0                                 0.0
# India                                 0.0                                 0.0
# Sri Lanka                             7.0                                 0.0
# Myanmar                               0.0                                 0.0
# Pakistan                              9.0                                 2.0
#
#               composition_wood_percent  \
# country_name
# Bhutan                             0.0
# Indonesia                          0.0
# India                              0.0
# Sri Lanka                          6.0
# Myanmar                            0.0
# Pakistan                           2.0
#
#               composition_yard_garden_green_waste_percent
# country_name
# Bhutan                                                0.0
# Indonesia                                             0.0
# India                                                 0.0
# Sri Lanka                                             0.0
# Myanmar                                               0.0
# Pakistan                                             14.0

# %%
LMC_waste = pd.DataFrame(waste_generated_LMC, columns =[
       'composition_food_organic_waste_percent', 'composition_glass_percent',
       'composition_metal_percent', 'composition_other_percent',
       'composition_paper_cardboard_percent', 'composition_plastic_percent',
       'composition_rubber_leather_percent', 'composition_wood_percent'])
LMC_waste.plot.bar(legend=True, stacked=True);
plt.legend(loc='center left',bbox_to_anchor=(1.0, 0.5))
plt.show()
plt.tight_layout()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
waste_generated_UMC = waste_generated.groupby('income_id').get_group('UMC').fillna(0).drop_duplicates().set_index('country_name')
waste_generated_UMC
# Nan values converted to zeros
# Out:
#                    income_id           gdp  \
# country_name
# Dominican Republic       UMC  7.366413e+10
# Algeria                  UMC  1.960348e+11
# Iran, Islamic Rep.       UMC  5.405812e+11
# Maldives                 UMC  3.600399e+09
# Mauritius                UMC  1.240984e+10
# Malaysia                 UMC  3.440523e+11
#
#                     population_population_number_of_people  \
# country_name
# Dominican Republic                              10528394.0
# Algeria                                         40606052.0
# Iran, Islamic Rep.                              80277428.0
# Maldives                                          409163.0
# Mauritius                                        1263473.0
# Malaysia                                        30228017.0
#
#                     composition_food_organic_waste_percent  \
# country_name
# Dominican Republic                                    51.0
# Algeria                                               54.4
# Iran, Islamic Rep.                                    72.9
# Maldives                                              24.0
# Mauritius                                             64.0
# Malaysia                                              46.0
#
#                     composition_glass_percent  composition_metal_percent  \
# country_name
# Dominican Republic                        6.0                        3.0
# Algeria                                   1.2                        2.8
# Iran, Islamic Rep.                        1.9                        2.3
# Maldives                                  0.0                        1.0
# Mauritius                                 2.8                        0.0
# Malaysia                                  3.0                        3.0
#
#                     composition_other_percent  \
# country_name
# Dominican Republic                       10.0
# Algeria                                   0.8
# Iran, Islamic Rep.                        5.0
# Maldives                                  1.0
# Mauritius                                 8.0
# Malaysia                                  9.0
#
#                     composition_paper_cardboard_percent  \
# country_name
# Dominican Republic                                 16.0
# Algeria                                             9.8
# Iran, Islamic Rep.                                  7.3
# Maldives                                            6.0
# Mauritius                                          13.0
# Malaysia                                           14.0
#
#                     composition_plastic_percent  \
# country_name
# Dominican Republic                         10.0
# Algeria                                    16.9
# Iran, Islamic Rep.                          8.5
# Maldives                                    3.0
# Mauritius                                  12.4
# Malaysia                                   15.0
#
#                     composition_rubber_leather_percent  \
# country_name
# Dominican Republic                                 0.0
# Algeria                                           12.6
# Iran, Islamic Rep.                                 1.1
# Maldives                                           0.0
# Mauritius                                          0.0
# Malaysia                                           3.0
#
#                     composition_wood_percent  \
# country_name
# Dominican Republic                       4.0
# Algeria                                  1.5
# Iran, Islamic Rep.                       1.3
# Maldives                                 0.0
# Mauritius                                0.0
# Malaysia                                 7.0
#
#                     composition_yard_garden_green_waste_percent
# country_name
# Dominican Republic                                          0.0
# Algeria                                                     0.0
# Iran, Islamic Rep.                                          0.0
# Maldives                                                   65.0
# Mauritius                                                   0.0
# Malaysia                                                    0.0

# %%
UMC_waste = pd.DataFrame(waste_generated_UMC, columns =[
       'composition_food_organic_waste_percent', 'composition_glass_percent',
       'composition_metal_percent', 'composition_other_percent',
       'composition_paper_cardboard_percent', 'composition_plastic_percent',
       'composition_rubber_leather_percent', 'composition_wood_percent'])
UMC_waste.plot.bar(legend=True, stacked=True);
plt.legend(loc='center left',bbox_to_anchor=(1.0, 0.5))
plt.show()
plt.tight_layout()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
waste_generated_HIC = waste_generated.groupby('income_id').get_group('HIC').fillna(0).drop_duplicates().set_index('country_name')
waste_generated_HIC
# Nan values converted to zeros
# Out:
#                      income_id           gdp  \
# country_name
# Hong Kong SAR, China       HIC  2.701054e+11
# Israel                     HIC  2.878076e+11
# St. Kitts and Nevis        HIC  8.583447e+08
# Oman                       HIC  7.505436e+10
# Qatar                      HIC  1.706626e+11
# Saudi Arabia               HIC  6.900688e+11
# Singapore                  HIC  2.991701e+11
#
#                       population_population_number_of_people  \
# country_name
# Hong Kong SAR, China                               7305700.0
# Israel                                             8380100.0
# St. Kitts and Nevis                                  54288.0
# Oman                                               3960925.0
# Qatar                                              2109568.0
# Saudi Arabia                                      31557144.0
# Singapore                                          5607283.0
#
#                       composition_food_organic_waste_percent  \
# country_name
# Hong Kong SAR, China                                   35.00
# Israel                                                 34.00
# St. Kitts and Nevis                                    27.20
# Oman                                                   27.00
# Qatar                                                  57.00
# Saudi Arabia                                           45.50
# Singapore                                              10.51
#
#                       composition_glass_percent  composition_metal_percent  \
# country_name
# Hong Kong SAR, China                       3.00                       2.00
# Israel                                     3.00                       3.00
# St. Kitts and Nevis                        8.10                       8.80
# Oman                                       6.00                       0.00
# Qatar                                      4.00                       9.00
# Saudi Arabia                               4.00                       5.00
# Singapore                                  0.93                      19.12
#
#                       composition_other_percent  \
# country_name
# Hong Kong SAR, China                       14.0
# Israel                                     16.0
# St. Kitts and Nevis                        12.2
# Oman                                       24.0
# Qatar                                       5.0
# Saudi Arabia                                2.5
# Singapore                                  32.3
#
#                       composition_paper_cardboard_percent  \
# country_name
# Hong Kong SAR, China                                22.00
# Israel                                              24.00
# St. Kitts and Nevis                                 20.50
# Oman                                                15.00
# Qatar                                               11.00
# Saudi Arabia                                        27.00
# Singapore                                           14.86
#
#                       composition_plastic_percent  \
# country_name
# Hong Kong SAR, China                        21.00
# Israel                                      18.00
# St. Kitts and Nevis                         23.20
# Oman                                        21.00
# Qatar                                       14.00
# Saudi Arabia                                11.00
# Singapore                                   10.58
#
#                       composition_rubber_leather_percent  \
# country_name
# Hong Kong SAR, China                                0.00
# Israel                                              0.00
# St. Kitts and Nevis                                 0.00
# Oman                                                0.00
# Qatar                                               0.00
# Saudi Arabia                                        0.00
# Singapore                                           1.96
#
#                       composition_wood_percent  \
# country_name
# Hong Kong SAR, China                       3.0
# Israel                                     0.0
# St. Kitts and Nevis                        0.0
# Oman                                       2.0
# Qatar                                      0.0
# Saudi Arabia                               5.0
# Singapore                                  5.5
#
#                       composition_yard_garden_green_waste_percent
# country_name
# Hong Kong SAR, China                                         0.00
# Israel                                                       2.00
# St. Kitts and Nevis                                          0.00
# Oman                                                         5.00
# Qatar                                                        0.00
# Saudi Arabia                                                 0.00
# Singapore                                                    4.26

# %%
HIC_waste = pd.DataFrame(waste_generated_HIC, columns =[
       'composition_food_organic_waste_percent', 'composition_glass_percent',
       'composition_metal_percent', 'composition_other_percent',
       'composition_paper_cardboard_percent', 'composition_plastic_percent',
       'composition_rubber_leather_percent', 'composition_wood_percent'])
HIC_waste.plot.bar(legend=True, stacked=True);
plt.legend(loc='center left',bbox_to_anchor=(1.0, 0.5))
plt.show()
plt.tight_layout()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# # EDA on waste information columns after grouping based on income_id

# %%
waste_information = world_group_2017[[
        'country_name', 
        'income_id', 'gdp', 
        'population_population_number_of_people',
        'other_information_information_system_for_solid_waste_management',
        'other_information_national_agency_to_enforce_solid_waste_laws_and_regulations',
        'other_information_national_law_governing_solid_waste_management_in_the_country',
        'other_information_ppp_rules_and_regulations',
        'other_information_summary_of_key_solid_waste_information_made_available_to_the_public']]
waste_information.fillna('No info').drop_duplicates().set_index('country_name')



# Converted Nan values to no info
# Out:
#                      income_id           gdp  \
# country_name
# Bhutan                     LMC  2.234759e+09
# Dominican Republic         UMC  7.366413e+10
# Algeria                    UMC  1.960348e+11
# Ethiopia                   LIC  5.234723e+10
# Hong Kong SAR, China       HIC  2.701054e+11
# Indonesia                  LMC  1.037864e+12
# India                      LMC  2.466177e+12
# Iran, Islamic Rep.         UMC  5.405812e+11
# Israel                     HIC  2.878076e+11
# St. Kitts and Nevis        HIC  8.583447e+08
# Sri Lanka                  LMC  7.990704e+10
# Maldives                   UMC  3.600399e+09
# Myanmar                    LMC  7.446983e+10
# Mauritius                  UMC  1.240984e+10
# Malaysia                   UMC  3.440523e+11
# Nepal                      LIC  1.985663e+10
# Oman                       HIC  7.505436e+10
# Pakistan                   LMC  2.278669e+11
# Qatar                      HIC  1.706626e+11
# Saudi Arabia               HIC  6.900688e+11
# Singapore                  HIC  2.991701e+11
# Uganda                     LIC  2.748306e+10
#
#                       population_population_number_of_people  \
# country_name
# Bhutan                                          6.869580e+05
# Dominican Republic                              1.052839e+07
# Algeria                                         4.060605e+07
# Ethiopia                                        9.987303e+07
# Hong Kong SAR, China                            7.305700e+06
# Indonesia                                       2.611155e+08
# India                                           1.071478e+09
# Iran, Islamic Rep.                              8.027743e+07
# Israel                                          8.380100e+06
# St. Kitts and Nevis                             5.428800e+04
# Sri Lanka                                       2.120300e+07
# Maldives                                        4.091630e+05
# Myanmar                                         4.609546e+07
# Mauritius                                       1.263473e+06
# Malaysia                                        3.022802e+07
# Nepal                                           2.898277e+07
# Oman                                            3.960925e+06
# Pakistan                                        1.932035e+08
# Qatar                                           2.109568e+06
# Saudi Arabia                                    3.155714e+07
# Singapore                                       5.607283e+06
# Uganda                                          3.509365e+07
#
#                      other_information_information_system_for_solid_waste_management  \
# country_name
# Bhutan                                                               No
# Dominican Republic                                                   No
# Algeria                                                             Yes
# Ethiopia                                                        No info
# Hong Kong SAR, China                                                Yes
# Indonesia                                                       No info
# India                                                                No
# Iran, Islamic Rep.                                                   No
# Israel                                                          No info
# St. Kitts and Nevis                                                 Yes
# Sri Lanka                                                           Yes
# Maldives                                                             No
# Myanmar                                                         No info
# Mauritius                                                       No info
# Malaysia                                                             No
# Nepal                                                           No info
# Oman                                                                 No
# Pakistan                                                             No
# Qatar                                                               Yes
# Saudi Arabia                                                        Yes
# Singapore                                                           Yes
# Uganda                                                          No info
#
#                      other_information_national_agency_to_enforce_solid_waste_laws_and_regulations  \
# country_name
# Bhutan                                                              Yes
# Dominican Republic                                                  Yes
# Algeria                                                             Yes
# Ethiopia                                                            Yes
# Hong Kong SAR, China                                                Yes
# Indonesia                                                           Yes
# India                                                               Yes
# Iran, Islamic Rep.                                                  Yes
# Israel                                                              Yes
# St. Kitts and Nevis                                                 Yes
# Sri Lanka                                                           Yes
# Maldives                                                            Yes
# Myanmar                                                             Yes
# Mauritius                                                       No info
# Malaysia                                                            Yes
# Nepal                                                               Yes
# Oman                                                                Yes
# Pakistan                                                            Yes
# Qatar                                                               Yes
# Saudi Arabia                                                        Yes
# Singapore                                                           Yes
# Uganda                                                          No info
#
#                      other_information_national_law_governing_solid_waste_management_in_the_country  \
# country_name
# Bhutan                                                              Yes
# Dominican Republic                                                   No
# Algeria                                                             Yes
# Ethiopia                                                            Yes
# Hong Kong SAR, China                                                Yes
# Indonesia                                                           Yes
# India                                                               Yes
# Iran, Islamic Rep.                                                  Yes
# Israel                                                              Yes
# St. Kitts and Nevis                                                 Yes
# Sri Lanka                                                           Yes
# Maldives                                                            Yes
# Myanmar                                                             Yes
# Mauritius                                                           Yes
# Malaysia                                                            Yes
# Nepal                                                               Yes
# Oman                                                                Yes
# Pakistan                                                             No
# Qatar                                                               Yes
# Saudi Arabia                                                        yes
# Singapore                                                           Yes
# Uganda                                                          No info
#
#                      other_information_ppp_rules_and_regulations  \
# country_name
# Bhutan                                                       Yes
# Dominican Republic                                            No
# Algeria                                                  No info
# Ethiopia                                                 No info
# Hong Kong SAR, China                                         Yes
# Indonesia                                                    Yes
# India                                                        Yes
# Iran, Islamic Rep.                                           Yes
# Israel                                                   No info
# St. Kitts and Nevis                                           No
# Sri Lanka                                                     No
# Maldives                                                      No
# Myanmar                                                      Yes
# Mauritius                                                    Yes
# Malaysia                                                     Yes
# Nepal                                                        Yes
# Oman                                                         Yes
# Pakistan                                                     Yes
# Qatar                                                    No info
# Saudi Arabia                                             No info
# Singapore                                                    Yes
# Uganda                                                   No info
#
#                      other_information_summary_of_key_solid_waste_information_made_available_to_the_public
# country_name
# Bhutan                                                              Yes
# Dominican Republic                                              No info
# Algeria                                                             Yes
# Ethiopia                                                        No info
# Hong Kong SAR, China                                                Yes
# Indonesia                                                       No info
# India                                                               Yes
# Iran, Islamic Rep.                                                   No
# Israel                                                              Yes
# St. Kitts and Nevis                                                 Yes
# Sri Lanka                                                           Yes
# Maldives                                                            Yes
# Myanmar                                                         No info
# Mauritius                                                       No info
# Malaysia                                                            Yes
# Nepal                                                           No info
# Oman                                                            No info
# Pakistan                                                        No info
# Qatar                                                                No
# Saudi Arabia                                                    No info
# Singapore                                                           Yes
# Uganda                                                          No info

# %%
waste_information.dtypes
# Out:
# country_name                                                                              object
# income_id                                                                                 object
# gdp                                                                                      float64
# population_population_number_of_people                                                   float64
# other_information_information_system_for_solid_waste_management                           object
# other_information_national_agency_to_enforce_solid_waste_laws_and_regulations             object
# other_information_national_law_governing_solid_waste_management_in_the_country            object
# other_information_ppp_rules_and_regulations                                               object
# other_information_summary_of_key_solid_waste_information_made_available_to_the_public     object
# dtype: object

# %%
df  = waste_information[[
        'country_name',
        'income_id',
        'other_information_information_system_for_solid_waste_management',
        'other_information_national_agency_to_enforce_solid_waste_laws_and_regulations',
        'other_information_national_law_governing_solid_waste_management_in_the_country',
        'other_information_ppp_rules_and_regulations',
        'other_information_summary_of_key_solid_waste_information_made_available_to_the_public']]\
        .fillna('No info').drop_duplicates().set_index('country_name').replace({'other_information_national_law_governing_solid_waste_management_in_the_country': {'yes': 'Yes'}})
df
# Out:
#                      income_id  \
# country_name
# Bhutan                     LMC
# Dominican Republic         UMC
# Algeria                    UMC
# Ethiopia                   LIC
# Hong Kong SAR, China       HIC
# Indonesia                  LMC
# India                      LMC
# Iran, Islamic Rep.         UMC
# Israel                     HIC
# St. Kitts and Nevis        HIC
# Sri Lanka                  LMC
# Maldives                   UMC
# Myanmar                    LMC
# Mauritius                  UMC
# Malaysia                   UMC
# Nepal                      LIC
# Oman                       HIC
# Pakistan                   LMC
# Qatar                      HIC
# Saudi Arabia               HIC
# Singapore                  HIC
# Uganda                     LIC
#
#                      other_information_information_system_for_solid_waste_management  \
# country_name
# Bhutan                                                               No
# Dominican Republic                                                   No
# Algeria                                                             Yes
# Ethiopia                                                        No info
# Hong Kong SAR, China                                                Yes
# Indonesia                                                       No info
# India                                                                No
# Iran, Islamic Rep.                                                   No
# Israel                                                          No info
# St. Kitts and Nevis                                                 Yes
# Sri Lanka                                                           Yes
# Maldives                                                             No
# Myanmar                                                         No info
# Mauritius                                                       No info
# Malaysia                                                             No
# Nepal                                                           No info
# Oman                                                                 No
# Pakistan                                                             No
# Qatar                                                               Yes
# Saudi Arabia                                                        Yes
# Singapore                                                           Yes
# Uganda                                                          No info
#
#                      other_information_national_agency_to_enforce_solid_waste_laws_and_regulations  \
# country_name
# Bhutan                                                              Yes
# Dominican Republic                                                  Yes
# Algeria                                                             Yes
# Ethiopia                                                            Yes
# Hong Kong SAR, China                                                Yes
# Indonesia                                                           Yes
# India                                                               Yes
# Iran, Islamic Rep.                                                  Yes
# Israel                                                              Yes
# St. Kitts and Nevis                                                 Yes
# Sri Lanka                                                           Yes
# Maldives                                                            Yes
# Myanmar                                                             Yes
# Mauritius                                                       No info
# Malaysia                                                            Yes
# Nepal                                                               Yes
# Oman                                                                Yes
# Pakistan                                                            Yes
# Qatar                                                               Yes
# Saudi Arabia                                                        Yes
# Singapore                                                           Yes
# Uganda                                                          No info
#
#                      other_information_national_law_governing_solid_waste_management_in_the_country  \
# country_name
# Bhutan                                                              Yes
# Dominican Republic                                                   No
# Algeria                                                             Yes
# Ethiopia                                                            Yes
# Hong Kong SAR, China                                                Yes
# Indonesia                                                           Yes
# India                                                               Yes
# Iran, Islamic Rep.                                                  Yes
# Israel                                                              Yes
# St. Kitts and Nevis                                                 Yes
# Sri Lanka                                                           Yes
# Maldives                                                            Yes
# Myanmar                                                             Yes
# Mauritius                                                           Yes
# Malaysia                                                            Yes
# Nepal                                                               Yes
# Oman                                                                Yes
# Pakistan                                                             No
# Qatar                                                               Yes
# Saudi Arabia                                                        Yes
# Singapore                                                           Yes
# Uganda                                                          No info
#
#                      other_information_ppp_rules_and_regulations  \
# country_name
# Bhutan                                                       Yes
# Dominican Republic                                            No
# Algeria                                                  No info
# Ethiopia                                                 No info
# Hong Kong SAR, China                                         Yes
# Indonesia                                                    Yes
# India                                                        Yes
# Iran, Islamic Rep.                                           Yes
# Israel                                                   No info
# St. Kitts and Nevis                                           No
# Sri Lanka                                                     No
# Maldives                                                      No
# Myanmar                                                      Yes
# Mauritius                                                    Yes
# Malaysia                                                     Yes
# Nepal                                                        Yes
# Oman                                                         Yes
# Pakistan                                                     Yes
# Qatar                                                    No info
# Saudi Arabia                                             No info
# Singapore                                                    Yes
# Uganda                                                   No info
#
#                      other_information_summary_of_key_solid_waste_information_made_available_to_the_public
# country_name
# Bhutan                                                              Yes
# Dominican Republic                                              No info
# Algeria                                                             Yes
# Ethiopia                                                        No info
# Hong Kong SAR, China                                                Yes
# Indonesia                                                       No info
# India                                                               Yes
# Iran, Islamic Rep.                                                   No
# Israel                                                              Yes
# St. Kitts and Nevis                                                 Yes
# Sri Lanka                                                           Yes
# Maldives                                                            Yes
# Myanmar                                                         No info
# Mauritius                                                       No info
# Malaysia                                                            Yes
# Nepal                                                           No info
# Oman                                                            No info
# Pakistan                                                        No info
# Qatar                                                                No
# Saudi Arabia                                                    No info
# Singapore                                                           Yes
# Uganda                                                          No info

# %%
df1 = (df.melt('income_id', value_name='Response')
       .groupby(['income_id', 'Response', 'variable'])
       .size()
       .unstack(fill_value=0)
       .rename_axis(None, axis=1))
df1
# Out:
#                     other_information_information_system_for_solid_waste_management  \
# income_id Response
# HIC       No                                                        1
#           No info                                                   1
#           Yes                                                       5
# LIC       No info                                                   3
#           Yes                                                       0
# LMC       No                                                        3
#           No info                                                   2
#           Yes                                                       1
# UMC       No                                                        4
#           No info                                                   1
#           Yes                                                       1
#
#                     other_information_national_agency_to_enforce_solid_waste_laws_and_regulations  \
# income_id Response
# HIC       No                                                        0
#           No info                                                   0
#           Yes                                                       7
# LIC       No info                                                   1
#           Yes                                                       2
# LMC       No                                                        0
#           No info                                                   0
#           Yes                                                       6
# UMC       No                                                        0
#           No info                                                   1
#           Yes                                                       5
#
#                     other_information_national_law_governing_solid_waste_management_in_the_country  \
# income_id Response
# HIC       No                                                        0
#           No info                                                   0
#           Yes                                                       7
# LIC       No info                                                   1
#           Yes                                                       2
# LMC       No                                                        1
#           No info                                                   0
#           Yes                                                       5
# UMC       No                                                        1
#           No info                                                   0
#           Yes                                                       5
#
#                     other_information_ppp_rules_and_regulations  \
# income_id Response
# HIC       No                                                  1
#           No info                                             3
#           Yes                                                 3
# LIC       No info                                             2
#           Yes                                                 1
# LMC       No                                                  1
#           No info                                             0
#           Yes                                                 5
# UMC       No                                                  2
#           No info                                             1
#           Yes                                                 3
#
#                     other_information_summary_of_key_solid_waste_information_made_available_to_the_public
# income_id Response
# HIC       No                                                        1
#           No info                                                   2
#           Yes                                                       4
# LIC       No info                                                   3
#           Yes                                                       0
# LMC       No                                                        0
#           No info                                                   3
#           Yes                                                       3
# UMC       No                                                        1
#           No info                                                   2
#           Yes                                                       3

# %%
#df_HIC = df1.groupby('income_id').get_group('HIC').reset_index().set_index('income_id', 'Response').T
df_HIC = df1.groupby('income_id').get_group('HIC')


df_HIC_info = pd.DataFrame(df_HIC, columns =[
    'other_information_information_system_for_solid_waste_management',
    'other_information_national_agency_to_enforce_solid_waste_laws_and_regulations',
    'other_information_national_law_governing_solid_waste_management_in_the_country',
    'other_information_ppp_rules_and_regulations',
    'other_information_summary_of_key_solid_waste_information_made_available_to_the_public'
       ])
df_HIC_info.plot.bar(legend=True, stacked=True);
plt.legend(loc='center left',bbox_to_anchor=(1.0, 0.5))
plt.show()
plt.tight_layout()
# Out:
# <img src="data:image/png;base64,..." width="640">
# <ipython-input-30-1a21c35c9ee3>:15: UserWarning: Tight layout not applied. The left and right margins cannot be made large enough to accommodate all axes decorations.
#   plt.tight_layout()

# %%
df_LIC = df1.groupby('income_id').get_group('LIC')


df_LIC_info = pd.DataFrame(df_LIC, columns =[
    'other_information_information_system_for_solid_waste_management',
    'other_information_national_agency_to_enforce_solid_waste_laws_and_regulations',
    'other_information_national_law_governing_solid_waste_management_in_the_country',
    'other_information_ppp_rules_and_regulations',
    'other_information_summary_of_key_solid_waste_information_made_available_to_the_public'
       ])
df_LIC_info.plot.bar(legend=True, stacked=True);
plt.legend(loc='center left',bbox_to_anchor=(1.0, 0.5))
plt.show()
plt.tight_layout()
# Out:
# <img src="data:image/png;base64,..." width="640">
# <ipython-input-31-d6be37c20228>:14: UserWarning: Tight layout not applied. The left and right margins cannot be made large enough to accommodate all axes decorations.
#   plt.tight_layout()

# %%
df_LMC = df1.groupby('income_id').get_group('LMC')


df_LMC_info = pd.DataFrame(df_LMC, columns =[
    'other_information_information_system_for_solid_waste_management',
    'other_information_national_agency_to_enforce_solid_waste_laws_and_regulations',
    'other_information_national_law_governing_solid_waste_management_in_the_country',
    'other_information_ppp_rules_and_regulations',
    'other_information_summary_of_key_solid_waste_information_made_available_to_the_public'
       ])
df_LMC_info.plot.bar(legend=True, stacked=True);
plt.legend(loc='center left',bbox_to_anchor=(1.0, 0.5))
plt.show()
plt.tight_layout()
# Out:
# <img src="data:image/png;base64,..." width="640">
# <ipython-input-32-444e03a1fe4d>:14: UserWarning: Tight layout not applied. The left and right margins cannot be made large enough to accommodate all axes decorations.
#   plt.tight_layout()

# %%
df_UMC = df1.groupby('income_id').get_group('UMC')


df_UMC_info = pd.DataFrame(df_UMC, columns =[
    'other_information_information_system_for_solid_waste_management',
    'other_information_national_agency_to_enforce_solid_waste_laws_and_regulations',
    'other_information_national_law_governing_solid_waste_management_in_the_country',
    'other_information_ppp_rules_and_regulations',
    'other_information_summary_of_key_solid_waste_information_made_available_to_the_public'
       ])
df_UMC_info.plot.bar(legend=True, stacked=True);
plt.legend(loc='center left',bbox_to_anchor=(1.0, 0.5))
plt.show()
plt.tight_layout()
# Out:
# <img src="data:image/png;base64,..." width="640">
# <ipython-input-33-7adcaeae2c05>:14: UserWarning: Tight layout not applied. The left and right margins cannot be made large enough to accommodate all axes decorations.
#   plt.tight_layout()

# %%
a = df1.reset_index().set_index('income_id', 'Response').T
a
# Out:
# income_id                                          HIC      HIC  HIC      LIC  \
# Response                                            No  No info  Yes  No info
# other_information_information_system_for_solid_...   1        1    5        3
# other_information_national_agency_to_enforce_so...   0        0    7        1
# other_information_national_law_governing_solid_...   0        0    7        1
# other_information_ppp_rules_and_regulations          1        3    3        2
# other_information_summary_of_key_solid_waste_in...   1        2    4        3
#
# income_id                                           LIC LMC      LMC  LMC UMC  \
# Response                                            Yes  No  No info  Yes  No
# other_information_information_system_for_solid_...    0   3        2    1   4
# other_information_national_agency_to_enforce_so...    2   0        0    6   0
# other_information_national_law_governing_solid_...    2   1        0    5   1
# other_information_ppp_rules_and_regulations           1   1        0    5   2
# other_information_summary_of_key_solid_waste_in...    0   0        3    3   1
#
# income_id                                               UMC  UMC
# Response                                            No info  Yes
# other_information_information_system_for_solid_...        1    1
# other_information_national_agency_to_enforce_so...        1    5
# other_information_national_law_governing_solid_...        0    5
# other_information_ppp_rules_and_regulations               1    3
# other_information_summary_of_key_solid_waste_in...        2    3

# %%
df1_waste_info = pd.DataFrame(df1, columns =[
    'other_information_information_system_for_solid_waste_management',
    'other_information_national_agency_to_enforce_solid_waste_laws_and_regulations',
    'other_information_national_law_governing_solid_waste_management_in_the_country',
    'other_information_ppp_rules_and_regulations',
    'other_information_summary_of_key_solid_waste_information_made_available_to_the_public'
       ])
df1_waste_info.plot.barh(legend=True, stacked=True);
plt.legend(loc='center left',bbox_to_anchor=(1.0, 0.5))
plt.show()
plt.tight_layout()
# Out:
# <img src="data:image/png;base64,..." width="640">
# <ipython-input-35-95cbf80613a5>:11: UserWarning: Tight layout not applied. The left and right margins cannot be made large enough to accommodate all axes decorations.
#   plt.tight_layout()

# %% [markdown]
# ## Special waste

# %%
special_waste =  world_group_2017[[
        'country_name', 
        'income_id', 'gdp', 
        'population_population_number_of_people',
        'special_waste_agricultural_waste_tons_year',
        'special_waste_construction_and_demolition_waste_tons_year',
        'special_waste_e_waste_tons_year',
        'special_waste_hazardous_waste_tons_year',
        'special_waste_industrial_waste_tons_year',
        'special_waste_medical_waste_tons_year',
        'total_msw_total_msw_generated_tons_year']]
special_waste.fillna(0).drop_duplicates().set_index('country_name').head(3)

# Nan values converted to zeros
# Out:
#                    income_id           gdp  \
# country_name
# Bhutan                   LMC  2.234759e+09
# Dominican Republic       UMC  7.366413e+10
# Algeria                  UMC  1.960348e+11
#
#                     population_population_number_of_people  \
# country_name
# Bhutan                                            686958.0
# Dominican Republic                              10528394.0
# Algeria                                         40606052.0
#
#                     special_waste_agricultural_waste_tons_year  \
# country_name
# Bhutan                                                     0.0
# Dominican Republic                                         0.0
# Algeria                                                    0.0
#
#                     special_waste_construction_and_demolition_waste_tons_year  \
# country_name
# Bhutan                                                            0.0
# Dominican Republic                                                0.0
# Algeria                                                    11000000.0
#
#                     special_waste_e_waste_tons_year  \
# country_name
# Bhutan                                       1457.5
# Dominican Republic                          57000.0
# Algeria                                    252000.0
#
#                     special_waste_hazardous_waste_tons_year  \
# country_name
# Bhutan                                                  0.0
# Dominican Republic                                      0.0
# Algeria                                            330000.0
#
#                     special_waste_industrial_waste_tons_year  \
# country_name
# Bhutan                                               1476.37
# Dominican Republic                                      0.00
# Algeria                                           2547000.00
#
#                     special_waste_medical_waste_tons_year  \
# country_name
# Bhutan                                              358.0
# Dominican Republic                                    0.0
# Algeria                                           30000.0
#
#                     total_msw_total_msw_generated_tons_year
# country_name
# Bhutan                                            111314.05
# Dominican Republic                               4063910.00
# Algeria                                         12378740.00

# %%
special_waste_HIC = special_waste.groupby('income_id').get_group('HIC').fillna(0).drop_duplicates().set_index('country_name')
special_waste_HIC.columns
# Out:
# Index(['income_id', 'gdp', 'population_population_number_of_people',
#        'special_waste_agricultural_waste_tons_year',
#        'special_waste_construction_and_demolition_waste_tons_year',
#        'special_waste_e_waste_tons_year',
#        'special_waste_hazardous_waste_tons_year',
#        'special_waste_industrial_waste_tons_year',
#        'special_waste_medical_waste_tons_year',
#        'total_msw_total_msw_generated_tons_year'],
#       dtype='object')

# %%
special_waste_HIC = pd.DataFrame(special_waste_HIC, columns =[
       'special_waste_agricultural_waste_tons_year', 
       'special_waste_construction_and_demolition_waste_tons_year',
       'special_waste_e_waste_tons_year',
       'special_waste_hazardous_waste_tons_year',
       'special_waste_industrial_waste_tons_year',
       'special_waste_medical_waste_tons_year',
       'total_msw_total_msw_generated_tons_year'])
special_waste_HIC.plot.bar(legend=True, stacked=True);
plt.legend(loc='center left',bbox_to_anchor=(1.0, 0.5))
plt.show()
plt.tight_layout()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
special_waste_LIC = special_waste.groupby('income_id').get_group('LIC').fillna(0).drop_duplicates().set_index('country_name')
special_waste_LIC
# Out:
#              income_id           gdp  population_population_number_of_people  \
# country_name
# Ethiopia           LIC  5.234723e+10                              99873033.0
# Nepal              LIC  1.985663e+10                              28982771.0
# Uganda             LIC  2.748306e+10                              35093648.0
#
#               special_waste_agricultural_waste_tons_year  \
# country_name
# Ethiopia                                             0.0
# Nepal                                                0.0
# Uganda                                               0.0
#
#               special_waste_construction_and_demolition_waste_tons_year  \
# country_name
# Ethiopia                                                    0.0
# Nepal                                                       0.0
# Uganda                                                      0.0
#
#               special_waste_e_waste_tons_year  \
# country_name
# Ethiopia                              49000.0
# Nepal                                 23000.0
# Uganda                                25000.0
#
#               special_waste_hazardous_waste_tons_year  \
# country_name
# Ethiopia                                          0.0
# Nepal                                          5051.0
# Uganda                                            0.0
#
#               special_waste_industrial_waste_tons_year  \
# country_name
# Ethiopia                                           0.0
# Nepal                                              0.0
# Uganda                                             0.0
#
#               special_waste_medical_waste_tons_year  \
# country_name
# Ethiopia                                       0.00
# Nepal                                      13408.27
# Uganda                                         0.00
#
#               total_msw_total_msw_generated_tons_year
# country_name
# Ethiopia                                  6532786.970
# Nepal                                     1768977.490
# Uganda                                    7045049.836

# %%
special_waste_LIC = pd.DataFrame(special_waste_LIC, columns =[
       'special_waste_agricultural_waste_tons_year', 
       'special_waste_construction_and_demolition_waste_tons_year',
       'special_waste_e_waste_tons_year',
       'special_waste_hazardous_waste_tons_year',
       'special_waste_industrial_waste_tons_year',
       'special_waste_medical_waste_tons_year',
       'total_msw_total_msw_generated_tons_year'])
special_waste_LIC.plot.bar(legend=True, stacked=True);
plt.legend(loc='center left',bbox_to_anchor=(1.0, 0.5))
plt.show()
plt.tight_layout()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
special_waste_LMC = special_waste.groupby('income_id').get_group('LMC').fillna(0).drop_duplicates().set_index('country_name')
special_waste_LMC
# Out:
#              income_id           gdp  population_population_number_of_people  \
# country_name
# Bhutan             LMC  2.234759e+09                            6.869580e+05
# Indonesia          LMC  1.037864e+12                            2.611155e+08
# India              LMC  2.466177e+12                            1.071478e+09
# Sri Lanka          LMC  7.990704e+10                            2.120300e+07
# Myanmar            LMC  7.446983e+10                            4.609546e+07
# Pakistan           LMC  2.278669e+11                            1.932035e+08
#
#               special_waste_agricultural_waste_tons_year  \
# country_name
# Bhutan                                               0.0
# Indonesia                                    122000000.0
# India                                                0.0
# Sri Lanka                                            0.0
# Myanmar                                              0.0
# Pakistan                                      82120000.0
#
#               special_waste_construction_and_demolition_waste_tons_year  \
# country_name
# Bhutan                                                      0.0
# Indonesia                                                   0.0
# India                                                27500000.0
# Sri Lanka                                               65700.0
# Myanmar                                                     0.0
# Pakistan                                                    0.0
#
#               special_waste_e_waste_tons_year  \
# country_name
# Bhutan                                 1457.5
# Indonesia                           1274000.0
# India                               1700000.0
# Sri Lanka                                72.5
# Myanmar                               55000.0
# Pakistan                             301000.0
#
#               special_waste_hazardous_waste_tons_year  \
# country_name
# Bhutan                                            0.0
# Indonesia                                  23000000.0
# India                                       7467000.0
# Sri Lanka                                         0.0
# Myanmar                                           0.0
# Pakistan                                    1538000.0
#
#               special_waste_industrial_waste_tons_year  \
# country_name
# Bhutan                                         1476.37
# Indonesia                                         0.00
# India                                             0.00
# Sri Lanka                                     53000.00
# Myanmar                                       54750.00
# Pakistan                                          0.00
#
#               special_waste_medical_waste_tons_year  \
# country_name
# Bhutan                                        358.0
# Indonesia                                   82125.0
# India                                      180784.5
# Sri Lanka                                    9855.0
# Myanmar                                       648.2
# Pakistan                                292000000.0
#
#               total_msw_total_msw_generated_tons_year
# country_name
# Bhutan                                   1.113141e+05
# Indonesia                                6.520000e+07
# India                                    1.684032e+08
# Sri Lanka                                2.631650e+06
# Myanmar                                  4.677307e+06
# Pakistan                                 3.076000e+07

# %%
special_waste_LMC = pd.DataFrame(special_waste_LMC, columns =[
       'special_waste_agricultural_waste_tons_year', 
       'special_waste_construction_and_demolition_waste_tons_year',
       'special_waste_e_waste_tons_year',
       'special_waste_hazardous_waste_tons_year',
       'special_waste_industrial_waste_tons_year',
       'special_waste_medical_waste_tons_year',
       'total_msw_total_msw_generated_tons_year'])
special_waste_LMC.plot.bar(legend=True, stacked=True);
plt.legend(loc='center left',bbox_to_anchor=(1.0, 0.5))
plt.show()
plt.tight_layout()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
special_waste_UMC = special_waste.groupby('income_id').get_group('UMC').fillna(0).drop_duplicates().set_index('country_name')
special_waste_UMC
# Out:
#                    income_id           gdp  \
# country_name
# Dominican Republic       UMC  7.366413e+10
# Algeria                  UMC  1.960348e+11
# Iran, Islamic Rep.       UMC  5.405812e+11
# Maldives                 UMC  3.600399e+09
# Mauritius                UMC  1.240984e+10
# Malaysia                 UMC  3.440523e+11
#
#                     population_population_number_of_people  \
# country_name
# Dominican Republic                              10528394.0
# Algeria                                         40606052.0
# Iran, Islamic Rep.                              80277428.0
# Maldives                                          409163.0
# Mauritius                                        1263473.0
# Malaysia                                        30228017.0
#
#                     special_waste_agricultural_waste_tons_year  \
# country_name
# Dominican Republic                                         0.0
# Algeria                                                    0.0
# Iran, Islamic Rep.                                  16049000.0
# Maldives                                                   0.0
# Mauritius                                                  0.0
# Malaysia                                            42000000.0
#
#                     special_waste_construction_and_demolition_waste_tons_year  \
# country_name
# Dominican Republic                                                0.0
# Algeria                                                    11000000.0
# Iran, Islamic Rep.                                         80000000.0
# Maldives                                                       6161.2
# Mauritius                                                         0.0
# Malaysia                                                          0.0
#
#                     special_waste_e_waste_tons_year  \
# country_name
# Dominican Republic                         57000.00
# Algeria                                   252000.00
# Iran, Islamic Rep.                        630000.00
# Maldives                                    3003.95
# Mauritius                                  11000.00
# Malaysia                                  280000.00
#
#                     special_waste_hazardous_waste_tons_year  \
# country_name
# Dominican Republic                                    0.000
# Algeria                                          330000.000
# Iran, Islamic Rep.                              8000000.000
# Maldives                                          15105.525
# Mauritius                                         17000.000
# Malaysia                                        2918478.000
#
#                     special_waste_industrial_waste_tons_year  \
# country_name
# Dominican Republic                                       0.0
# Algeria                                            2547000.0
# Iran, Islamic Rep.                                30000000.0
# Maldives                                                 0.0
# Mauritius                                                0.0
# Malaysia                                            831835.0
#
#                     special_waste_medical_waste_tons_year  \
# country_name
# Dominican Republic                                    0.0
# Algeria                                           30000.0
# Iran, Islamic Rep.                              1609650.0
# Maldives                                           1737.4
# Mauritius                                             0.0
# Malaysia                                          19500.0
#
#                     total_msw_total_msw_generated_tons_year
# country_name
# Dominican Republic                               4063910.00
# Algeria                                         12378740.00
# Iran, Islamic Rep.                              17885000.00
# Maldives                                          211505.78
# Mauritius                                         438000.00
# Malaysia                                        12982685.00

# %%
special_waste_UMC = pd.DataFrame(special_waste_UMC, columns =[
       'special_waste_agricultural_waste_tons_year', 
       'special_waste_construction_and_demolition_waste_tons_year',
       'special_waste_e_waste_tons_year',
       'special_waste_hazardous_waste_tons_year',
       'special_waste_industrial_waste_tons_year',
       'special_waste_medical_waste_tons_year',
       'total_msw_total_msw_generated_tons_year'])
special_waste_UMC.plot.bar(legend=True, stacked=True);
plt.legend(loc='center left',bbox_to_anchor=(1.0, 0.5))
plt.show()
plt.tight_layout()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ## Waste Collection

# %%
waste_collection = world_group_2017[[
        'country_name', 
        'income_id', 'gdp', 
        'population_population_number_of_people',
        'waste_collection_coverage_rural_percent_of_geographic_area',
        'waste_collection_coverage_rural_percent_of_households',
        'waste_collection_coverage_rural_percent_of_population',
        'waste_collection_coverage_rural_percent_of_waste',
        'waste_collection_coverage_total_percent_of_geographic_area',
        'waste_collection_coverage_total_percent_of_households',
        'waste_collection_coverage_total_percent_of_population',
        'waste_collection_coverage_total_percent_of_waste',
        'waste_collection_coverage_urban_percent_of_geographic_area',
        'waste_collection_coverage_urban_percent_of_households',
        'waste_collection_coverage_urban_percent_of_population',
        'waste_collection_coverage_urban_percent_of_waste'
]]
waste_collection.fillna(0).drop_duplicates().set_index('country_name').head(3)


# converted Nan values to zeros
# Out:
#                    income_id           gdp  \
# country_name
# Bhutan                   LMC  2.234759e+09
# Dominican Republic       UMC  7.366413e+10
# Algeria                  UMC  1.960348e+11
#
#                     population_population_number_of_people  \
# country_name
# Bhutan                                            686958.0
# Dominican Republic                              10528394.0
# Algeria                                         40606052.0
#
#                     waste_collection_coverage_rural_percent_of_geographic_area  \
# country_name
# Bhutan                                                            0.0
# Dominican Republic                                                0.0
# Algeria                                                           0.0
#
#                     waste_collection_coverage_rural_percent_of_households  \
# country_name
# Bhutan                                                            0.0
# Dominican Republic                                                0.0
# Algeria                                                           0.0
#
#                     waste_collection_coverage_rural_percent_of_population  \
# country_name
# Bhutan                                                            0.0
# Dominican Republic                                                0.0
# Algeria                                                          87.5
#
#                     waste_collection_coverage_rural_percent_of_waste  \
# country_name
# Bhutan                                                           0.0
# Dominican Republic                                               0.0
# Algeria                                                          0.0
#
#                     waste_collection_coverage_total_percent_of_geographic_area  \
# country_name
# Bhutan                                                            0.0
# Dominican Republic                                                0.0
# Algeria                                                           0.0
#
#                     waste_collection_coverage_total_percent_of_households  \
# country_name
# Bhutan                                                            0.0
# Dominican Republic                                               74.9
# Algeria                                                           0.0
#
#                     waste_collection_coverage_total_percent_of_population  \
# country_name
# Bhutan                                                            0.0
# Dominican Republic                                                0.0
# Algeria                                                           0.0
#
#                     waste_collection_coverage_total_percent_of_waste  \
# country_name
# Bhutan                                                           0.0
# Dominican Republic                                               0.0
# Algeria                                                          0.0
#
#                     waste_collection_coverage_urban_percent_of_geographic_area  \
# country_name
# Bhutan                                                            0.0
# Dominican Republic                                                0.0
# Algeria                                                           0.0
#
#                     waste_collection_coverage_urban_percent_of_households  \
# country_name
# Bhutan                                                            0.0
# Dominican Republic                                                0.0
# Algeria                                                           0.0
#
#                     waste_collection_coverage_urban_percent_of_population  \
# country_name
# Bhutan                                                            0.0
# Dominican Republic                                                0.0
# Algeria                                                          87.5
#
#                     waste_collection_coverage_urban_percent_of_waste
# country_name
# Bhutan                                                          95.0
# Dominican Republic                                               0.0
# Algeria                                                          0.0

# %%
waste_treatment = world_group_2017[[
        'country_name', 
        'income_id', 'gdp', 
        'population_population_number_of_people',
        'waste_treatment_anaerobic_digestion_percent',
        'waste_treatment_compost_percent',
        'waste_treatment_controlled_landfill_percent',
        'waste_treatment_incineration_percent',
        'waste_treatment_landfill_unspecified_percent',
        'waste_treatment_open_dump_percent', 'waste_treatment_other_percent',
        'waste_treatment_recycling_percent',
        'waste_treatment_sanitary_landfill_landfill_gas_system_percent',
        'waste_treatment_unaccounted_for_percent']]
waste_treatment.fillna(0).drop_duplicates().set_index('country_name').head(3)


# Nan values converted to zeros
# Out:
#                    income_id           gdp  \
# country_name
# Bhutan                   LMC  2.234759e+09
# Dominican Republic       UMC  7.366413e+10
# Algeria                  UMC  1.960348e+11
#
#                     population_population_number_of_people  \
# country_name
# Bhutan                                            686958.0
# Dominican Republic                              10528394.0
# Algeria                                         40606052.0
#
#                     waste_treatment_anaerobic_digestion_percent  \
# country_name
# Bhutan                                                      0.0
# Dominican Republic                                          0.0
# Algeria                                                     0.0
#
#                     waste_treatment_compost_percent  \
# country_name
# Bhutan                                         1.39
# Dominican Republic                             0.00
# Algeria                                        1.00
#
#                     waste_treatment_controlled_landfill_percent  \
# country_name
# Bhutan                                                     98.0
# Dominican Republic                                          0.0
# Algeria                                                     2.0
#
#                     waste_treatment_incineration_percent  \
# country_name
# Bhutan                                               0.0
# Dominican Republic                                   0.0
# Algeria                                              0.0
#
#                     waste_treatment_landfill_unspecified_percent  \
# country_name
# Bhutan                                                       0.0
# Dominican Republic                                           0.0
# Algeria                                                      0.0
#
#                     waste_treatment_open_dump_percent  \
# country_name
# Bhutan                                       0.000000
# Dominican Republic                          72.575831
# Algeria                                      0.000000
#
#                     waste_treatment_other_percent  \
# country_name
# Bhutan                                        0.0
# Dominican Republic                            0.0
# Algeria                                       0.0
#
#                     waste_treatment_recycling_percent  \
# country_name
# Bhutan                                           0.86
# Dominican Republic                               8.20
# Algeria                                          8.00
#
#                     waste_treatment_sanitary_landfill_landfill_gas_system_percent  \
# country_name
# Bhutan                                                            0.0
# Dominican Republic                                                0.1
# Algeria                                                          89.0
#
#                     waste_treatment_unaccounted_for_percent
# country_name
# Bhutan                                             0.000000
# Dominican Republic                                19.124169
# Algeria                                            0.000000

# %%
waste_treatment_LIC = waste_treatment.groupby('income_id').get_group('LIC').fillna(0).drop_duplicates().set_index('country_name')
waste_treatment_LIC
# Out:
#              income_id           gdp  population_population_number_of_people  \
# country_name
# Ethiopia           LIC  5.234723e+10                              99873033.0
# Nepal              LIC  1.985663e+10                              28982771.0
# Uganda             LIC  2.748306e+10                              35093648.0
#
#               waste_treatment_anaerobic_digestion_percent  \
# country_name
# Ethiopia                                              0.0
# Nepal                                                 0.0
# Uganda                                                0.0
#
#               waste_treatment_compost_percent  \
# country_name
# Ethiopia                                 0.00
# Nepal                                    2.87
# Uganda                                   0.00
#
#               waste_treatment_controlled_landfill_percent  \
# country_name
# Ethiopia                                              0.0
# Nepal                                                 0.0
# Uganda                                                0.0
#
#               waste_treatment_incineration_percent  \
# country_name
# Ethiopia                                       0.0
# Nepal                                          0.0
# Uganda                                         0.0
#
#               waste_treatment_landfill_unspecified_percent  \
# country_name
# Ethiopia                                               0.0
# Nepal                                                 37.0
# Uganda                                                 0.0
#
#               waste_treatment_open_dump_percent  \
# country_name
# Ethiopia                                   43.0
# Nepal                                       0.0
# Uganda                                     87.0
#
#               waste_treatment_other_percent  \
# country_name
# Ethiopia                                0.0
# Nepal                                   0.0
# Uganda                                  0.0
#
#               waste_treatment_recycling_percent  \
# country_name
# Ethiopia                                    0.0
# Nepal                                       0.0
# Uganda                                      6.0
#
#               waste_treatment_sanitary_landfill_landfill_gas_system_percent  \
# country_name
# Ethiopia                                                    0.0
# Nepal                                                       0.0
# Uganda                                                      7.0
#
#               waste_treatment_unaccounted_for_percent
# country_name
# Ethiopia                                        57.00
# Nepal                                           60.13
# Uganda                                           0.00

# %%
waste_treatment_LIC = pd.DataFrame(waste_treatment_LIC, columns =[
       'waste_treatment_anaerobic_digestion_percent',
       'waste_treatment_compost_percent',
       'waste_treatment_controlled_landfill_percent',
       'waste_treatment_incineration_percent',
       'waste_treatment_landfill_unspecified_percent',
       'waste_treatment_open_dump_percent', 'waste_treatment_other_percent',
       'waste_treatment_recycling_percent',
       'waste_treatment_sanitary_landfill_landfill_gas_system_percent',
       'waste_treatment_unaccounted_for_percent'])
waste_treatment_LIC.plot.bar(legend=True, stacked=True);
plt.legend(loc='center left',bbox_to_anchor=(1.0, 0.5))
plt.show()
plt.tight_layout()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
waste_treatment_LMC = waste_treatment.groupby('income_id').get_group('LMC').fillna(0).drop_duplicates().set_index('country_name')
waste_treatment_LMC
# Out:
#              income_id           gdp  population_population_number_of_people  \
# country_name
# Bhutan             LMC  2.234759e+09                            6.869580e+05
# Indonesia          LMC  1.037864e+12                            2.611155e+08
# India              LMC  2.466177e+12                            1.071478e+09
# Sri Lanka          LMC  7.990704e+10                            2.120300e+07
# Myanmar            LMC  7.446983e+10                            4.609546e+07
# Pakistan           LMC  2.278669e+11                            1.932035e+08
#
#               waste_treatment_anaerobic_digestion_percent  \
# country_name
# Bhutan                                                0.0
# Indonesia                                             0.0
# India                                                 0.0
# Sri Lanka                                             0.0
# Myanmar                                               0.0
# Pakistan                                              0.0
#
#               waste_treatment_compost_percent  \
# country_name
# Bhutan                                   1.39
# Indonesia                                0.00
# India                                   18.00
# Sri Lanka                                5.00
# Myanmar                                  0.00
# Pakistan                                 2.00
#
#               waste_treatment_controlled_landfill_percent  \
# country_name
# Bhutan                                               98.0
# Indonesia                                             0.0
# India                                                 0.0
# Sri Lanka                                             0.0
# Myanmar                                               0.0
# Pakistan                                              0.0
#
#               waste_treatment_incineration_percent  \
# country_name
# Bhutan                                         0.0
# Indonesia                                      0.0
# India                                          0.0
# Sri Lanka                                      0.0
# Myanmar                                        0.0
# Pakistan                                       0.0
#
#               waste_treatment_landfill_unspecified_percent  \
# country_name
# Bhutan                                                 0.0
# Indonesia                                             69.0
# India                                                  0.0
# Sri Lanka                                              0.0
# Myanmar                                                0.0
# Pakistan                                              40.0
#
#               waste_treatment_open_dump_percent  \
# country_name
# Bhutan                                      0.0
# Indonesia                                  10.0
# India                                      77.0
# Sri Lanka                                  85.0
# Myanmar                                     0.0
# Pakistan                                   50.0
#
#               waste_treatment_other_percent  \
# country_name
# Bhutan                                  0.0
# Indonesia                              14.0
# India                                   0.0
# Sri Lanka                               0.0
# Myanmar                                 8.0
# Pakistan                                0.0
#
#               waste_treatment_recycling_percent  \
# country_name
# Bhutan                                     0.86
# Indonesia                                  7.00
# India                                      5.00
# Sri Lanka                                 12.79
# Myanmar                                    0.00
# Pakistan                                   8.00
#
#               waste_treatment_sanitary_landfill_landfill_gas_system_percent  \
# country_name
# Bhutan                                                      0.0
# Indonesia                                                   0.0
# India                                                       0.0
# Sri Lanka                                                   0.0
# Myanmar                                                     0.0
# Pakistan                                                    0.0
#
#               waste_treatment_unaccounted_for_percent
# country_name
# Bhutan                                            0.0
# Indonesia                                         0.0
# India                                             0.0
# Sri Lanka                                         0.0
# Myanmar                                          92.0
# Pakistan                                          0.0

# %%
waste_treatment_LMC = pd.DataFrame(waste_treatment_LMC, columns =[
       'waste_treatment_anaerobic_digestion_percent',
       'waste_treatment_compost_percent',
       'waste_treatment_controlled_landfill_percent',
       'waste_treatment_incineration_percent',
       'waste_treatment_landfill_unspecified_percent',
       'waste_treatment_open_dump_percent', 'waste_treatment_other_percent',
       'waste_treatment_recycling_percent',
       'waste_treatment_sanitary_landfill_landfill_gas_system_percent',
       'waste_treatment_unaccounted_for_percent'])
waste_treatment_LMC.plot.bar(legend=True, stacked=True);
plt.legend(loc='center left',bbox_to_anchor=(1.0, 0.5))
plt.show()
plt.tight_layout()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
waste_treatment_UMC = waste_treatment.groupby('income_id').get_group('UMC').fillna(0).drop_duplicates().set_index('country_name')
waste_treatment_UMC
# Out:
#                    income_id           gdp  \
# country_name
# Dominican Republic       UMC  7.366413e+10
# Algeria                  UMC  1.960348e+11
# Iran, Islamic Rep.       UMC  5.405812e+11
# Maldives                 UMC  3.600399e+09
# Mauritius                UMC  1.240984e+10
# Malaysia                 UMC  3.440523e+11
#
#                     population_population_number_of_people  \
# country_name
# Dominican Republic                              10528394.0
# Algeria                                         40606052.0
# Iran, Islamic Rep.                              80277428.0
# Maldives                                          409163.0
# Mauritius                                        1263473.0
# Malaysia                                        30228017.0
#
#                     waste_treatment_anaerobic_digestion_percent  \
# country_name
# Dominican Republic                                          0.0
# Algeria                                                     0.0
# Iran, Islamic Rep.                                          0.3
# Maldives                                                    0.0
# Mauritius                                                   0.0
# Malaysia                                                    0.0
#
#                     waste_treatment_compost_percent  \
# country_name
# Dominican Republic                              0.0
# Algeria                                         1.0
# Iran, Islamic Rep.                             12.0
# Maldives                                        7.0
# Mauritius                                       9.0
# Malaysia                                        1.0
#
#                     waste_treatment_controlled_landfill_percent  \
# country_name
# Dominican Republic                                          0.0
# Algeria                                                     2.0
# Iran, Islamic Rep.                                         10.0
# Maldives                                                    0.0
# Mauritius                                                   0.0
# Malaysia                                                    0.0
#
#                     waste_treatment_incineration_percent  \
# country_name
# Dominican Republic                                   0.0
# Algeria                                              0.0
# Iran, Islamic Rep.                                   0.4
# Maldives                                             6.0
# Mauritius                                            0.0
# Malaysia                                             0.0
#
#                     waste_treatment_landfill_unspecified_percent  \
# country_name
# Dominican Republic                                           0.0
# Algeria                                                      0.0
# Iran, Islamic Rep.                                           0.0
# Maldives                                                     0.0
# Mauritius                                                    0.0
# Malaysia                                                    71.5
#
#                     waste_treatment_open_dump_percent  \
# country_name
# Dominican Republic                          72.575831
# Algeria                                      0.000000
# Iran, Islamic Rep.                          72.000000
# Maldives                                     0.000000
# Mauritius                                    0.000000
# Malaysia                                     0.000000
#
#                     waste_treatment_other_percent  \
# country_name
# Dominican Republic                            0.0
# Algeria                                       0.0
# Iran, Islamic Rep.                            0.0
# Maldives                                     24.0
# Mauritius                                     0.0
# Malaysia                                      0.0
#
#                     waste_treatment_recycling_percent  \
# country_name
# Dominican Republic                                8.2
# Algeria                                           8.0
# Iran, Islamic Rep.                                5.0
# Maldives                                          0.0
# Mauritius                                         0.0
# Malaysia                                         17.5
#
#                     waste_treatment_sanitary_landfill_landfill_gas_system_percent  \
# country_name
# Dominican Republic                                                0.1
# Algeria                                                          89.0
# Iran, Islamic Rep.                                                0.0
# Maldives                                                          0.0
# Mauritius                                                        91.0
# Malaysia                                                         10.0
#
#                     waste_treatment_unaccounted_for_percent
# country_name
# Dominican Republic                                19.124169
# Algeria                                            0.000000
# Iran, Islamic Rep.                                 0.300000
# Maldives                                           0.000000
# Mauritius                                          0.000000
# Malaysia                                           0.000000

# %%
waste_treatment_UMC = pd.DataFrame(waste_treatment_UMC, columns =[
       'waste_treatment_anaerobic_digestion_percent',
       'waste_treatment_compost_percent',
       'waste_treatment_controlled_landfill_percent',
       'waste_treatment_incineration_percent',
       'waste_treatment_landfill_unspecified_percent',
       'waste_treatment_open_dump_percent', 'waste_treatment_other_percent',
       'waste_treatment_recycling_percent',
       'waste_treatment_sanitary_landfill_landfill_gas_system_percent',
       'waste_treatment_unaccounted_for_percent'])
waste_treatment_UMC.plot.bar(legend=True, stacked=True);
plt.legend(loc='center left',bbox_to_anchor=(1.0, 0.5))
plt.show()
plt.tight_layout()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
waste_treatment_HIC = waste_treatment.groupby('income_id').get_group('HIC').fillna(0).drop_duplicates().set_index('country_name')
waste_treatment_HIC
# Out:
#                      income_id           gdp  \
# country_name
# Hong Kong SAR, China       HIC  2.701054e+11
# Israel                     HIC  2.878076e+11
# St. Kitts and Nevis        HIC  8.583447e+08
# Oman                       HIC  7.505436e+10
# Qatar                      HIC  1.706626e+11
# Saudi Arabia               HIC  6.900688e+11
# Singapore                  HIC  2.991701e+11
#
#                       population_population_number_of_people  \
# country_name
# Hong Kong SAR, China                               7305700.0
# Israel                                             8380100.0
# St. Kitts and Nevis                                  54288.0
# Oman                                               3960925.0
# Qatar                                              2109568.0
# Saudi Arabia                                      31557144.0
# Singapore                                          5607283.0
#
#                       waste_treatment_anaerobic_digestion_percent  \
# country_name
# Hong Kong SAR, China                                          0.0
# Israel                                                        0.0
# St. Kitts and Nevis                                           0.0
# Oman                                                          0.0
# Qatar                                                         0.0
# Saudi Arabia                                                  0.0
# Singapore                                                     0.0
#
#                       waste_treatment_compost_percent  \
# country_name
# Hong Kong SAR, China                              0.0
# Israel                                            0.0
# St. Kitts and Nevis                               0.0
# Oman                                              0.0
# Qatar                                             0.0
# Saudi Arabia                                      0.0
# Singapore                                         0.0
#
#                       waste_treatment_controlled_landfill_percent  \
# country_name
# Hong Kong SAR, China                                         0.00
# Israel                                                       0.00
# St. Kitts and Nevis                                        100.00
# Oman                                                         0.01
# Qatar                                                        0.00
# Saudi Arabia                                                85.00
# Singapore                                                    0.00
#
#                       waste_treatment_incineration_percent  \
# country_name
# Hong Kong SAR, China                                   0.0
# Israel                                                 0.0
# St. Kitts and Nevis                                    0.0
# Oman                                                   0.0
# Qatar                                                  4.0
# Saudi Arabia                                           0.0
# Singapore                                             37.0
#
#                       waste_treatment_landfill_unspecified_percent  \
# country_name
# Hong Kong SAR, China                                          66.0
# Israel                                                        75.0
# St. Kitts and Nevis                                            0.0
# Oman                                                           0.0
# Qatar                                                         93.0
# Saudi Arabia                                                   0.0
# Singapore                                                      2.0
#
#                       waste_treatment_open_dump_percent  \
# country_name
# Hong Kong SAR, China                               0.00
# Israel                                             0.00
# St. Kitts and Nevis                                0.00
# Oman                                              99.99
# Qatar                                              0.00
# Saudi Arabia                                       0.00
# Singapore                                          0.00
#
#                       waste_treatment_other_percent  \
# country_name
# Hong Kong SAR, China                            0.0
# Israel                                          0.0
# St. Kitts and Nevis                             0.0
# Oman                                            0.0
# Qatar                                           0.0
# Saudi Arabia                                    0.0
# Singapore                                       0.0
#
#                       waste_treatment_recycling_percent  \
# country_name
# Hong Kong SAR, China                               34.0
# Israel                                             25.0
# St. Kitts and Nevis                                 0.0
# Oman                                                0.0
# Qatar                                               3.0
# Saudi Arabia                                       15.0
# Singapore                                          61.0
#
#                       waste_treatment_sanitary_landfill_landfill_gas_system_percent  \
# country_name
# Hong Kong SAR, China                                                0.0
# Israel                                                              0.0
# St. Kitts and Nevis                                                 0.0
# Oman                                                                0.0
# Qatar                                                               0.0
# Saudi Arabia                                                        0.0
# Singapore                                                           0.0
#
#                       waste_treatment_unaccounted_for_percent
# country_name
# Hong Kong SAR, China                                      0.0
# Israel                                                    0.0
# St. Kitts and Nevis                                       0.0
# Oman                                                      0.0
# Qatar                                                     0.0
# Saudi Arabia                                              0.0
# Singapore                                                 0.0

# %%
waste_treatment_HIC = pd.DataFrame(waste_treatment_HIC, columns =[
       'waste_treatment_anaerobic_digestion_percent',
       'waste_treatment_compost_percent',
       'waste_treatment_controlled_landfill_percent',
       'waste_treatment_incineration_percent',
       'waste_treatment_landfill_unspecified_percent',
       'waste_treatment_open_dump_percent', 'waste_treatment_other_percent',
       'waste_treatment_recycling_percent',
       'waste_treatment_sanitary_landfill_landfill_gas_system_percent',
       'waste_treatment_unaccounted_for_percent'])
waste_treatment_HIC.plot.bar(legend=True, stacked=True);
plt.legend(loc='center left',bbox_to_anchor=(1.0, 0.5))
plt.show()
plt.tight_layout()
# Out:
# <img src="data:image/png;base64,..." width="640">
