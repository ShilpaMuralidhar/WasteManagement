# %%
# %matplotlib notebook

# %%
import pandas as pd
#from IPython.display import display
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# import pandas as pd

# %%
city_code = "/Users/shilpa/Desktop/Boringppl_project/WasteManagement/Data/city_level_codebook_0.csv"
city_code_df = pd.read_csv(city_code, encoding = 'utf-8')
city_code_df.head()
# Out:
#   regionID iso3c country_name       city_name incomeID  \
# 0      SAS   AFG  Afghanistan       Jalalabad      LIC
# 1      SAS   IND        India  Vishakhapatnam      LMC
# 2      LCN   COL     Colombia            Cali      UMC
# 3      SAS   AFG  Afghanistan           Kabul      LIC
# 4      SAS   AFG  Afghanistan          Hirat       LIC
#
#                               measurement        units    year  \
# 0  population_population_number_of_people  # of people  2015.0
# 1  population_population_number_of_people  # of people  2011.0
# 2  population_population_number_of_people  # of people  2005.0
# 3  population_population_number_of_people  # of people  2016.0
# 4  population_population_number_of_people  # of people  2015.0
#
#                                               source comments
# 0  Islamic Republic of Afghanistan. 2015. "State ...      NaN
# 1  Census of India. 2014. "Databook for PC 2011."...      NaN
# 2  CCAC (Climate and Clean Air Coalition). n.d.(d...      NaN
# 3  World Bank. 2016b. "Islamic  Republic of Afgha...      NaN
# 4  UN DESA (United Nations, Department of Economi...      NaN

# %%
city_data = "/Users/shilpa/Desktop/Boringppl_project/WasteManagement/Data/city_level_data_0_0.csv"
city_data_df = pd.read_csv(city_data, encoding = 'utf-8')
city_data_df.head()
# Out:
#   iso3c region_id country_name income_id       city_name  \
# 0   AFG       SAS  Afghanistan       LIC       Jalalabad
# 1   AFG       SAS  Afghanistan       LIC        Kandahar
# 2   AFG       SAS  Afghanistan       LIC  Mazar-E-Sharif
# 3   AFG       SAS  Afghanistan       LIC           Kabul
# 4   AFG       SAS  Afghanistan       LIC         HiratÂ
#
#   additional_data_annual_budget_for_waste_management_year  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   additional_data_annual_solid_waste_budget_year  \
# 0                                            NaN
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# 4                                            NaN
#
#    additional_data_annual_swm_budget_2017_year  \
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
#
#    additional_data_annual_swm_budget_year  \
# 0                                     NaN
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
#
#    additional_data_annual_waste_budget_year  ...  \
# 0                                       NaN  ...
# 1                                       NaN  ...
# 2                                       NaN  ...
# 3                                       NaN  ...
# 4                                       NaN  ...
#
#    waste_treatment_compost_percent  \
# 0                              NaN
# 1                              NaN
# 2                              NaN
# 3                              NaN
# 4                              NaN
#
#    waste_treatment_controlled_landfill_percent  \
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
#
#   waste_treatment_incineration_percent  \
# 0                                  NaN
# 1                                  NaN
# 2                                  NaN
# 3                                  NaN
# 4                                  NaN
#
#   waste_treatment_landfill_unspecified_percent  \
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
#
#   waste_treatment_open_dump_percent  waste_treatment_other_percent  \
# 0                             100.0                            NaN
# 1                             100.0                            NaN
# 2                             100.0                            NaN
# 3                              75.0                            NaN
# 4                             100.0                            NaN
#
#    waste_treatment_recycling_percent  \
# 0                                NaN
# 1                                NaN
# 2                                NaN
# 3                                NaN
# 4                                NaN
#
#    waste_treatment_sanitary_landfill_landfill_gas_system_percent  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   waste_treatment_unaccounted_for_percent  \
# 0                                     NaN
# 1                                     NaN
# 2                                     NaN
# 3                                    25.0
# 4                                     NaN
#
#   waste_treatment_waterways_marine_percent
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
#
# [5 rows x 113 columns]

# %%
city_data_df.columns
# Out:
# Index(['iso3c', 'region_id', 'country_name', 'income_id', 'city_name',
#        'additional_data_annual_budget_for_waste_management_year',
#        'additional_data_annual_solid_waste_budget_year',
#        'additional_data_annual_swm_budget_2017_year',
#        'additional_data_annual_swm_budget_year',
#        'additional_data_annual_waste_budget_year',
#        ...
#        'waste_treatment_compost_percent',
#        'waste_treatment_controlled_landfill_percent',
#        'waste_treatment_incineration_percent',
#        'waste_treatment_landfill_unspecified_percent',
#        'waste_treatment_open_dump_percent', 'waste_treatment_other_percent',
#        'waste_treatment_recycling_percent',
#        'waste_treatment_sanitary_landfill_landfill_gas_system_percent',
#        'waste_treatment_unaccounted_for_percent',
#        'waste_treatment_waterways_marine_percent'],
#       dtype='object', length=113)

# %%
result = pd.concat([city_code_df, city_data_df], axis=1, sort=False)
result.head(3)
# Out:
#   regionID iso3c country_name       city_name incomeID  \
# 0      SAS   AFG  Afghanistan       Jalalabad      LIC
# 1      SAS   IND        India  Vishakhapatnam      LMC
# 2      LCN   COL     Colombia            Cali      UMC
#
#                               measurement        units    year  \
# 0  population_population_number_of_people  # of people  2015.0
# 1  population_population_number_of_people  # of people  2011.0
# 2  population_population_number_of_people  # of people  2005.0
#
#                                               source comments  ...  \
# 0  Islamic Republic of Afghanistan. 2015. "State ...      NaN  ...
# 1  Census of India. 2014. "Databook for PC 2011."...      NaN  ...
# 2  CCAC (Climate and Clean Air Coalition). n.d.(d...      NaN  ...
#
#   waste_treatment_compost_percent waste_treatment_controlled_landfill_percent  \
# 0                             NaN                                         NaN
# 1                             NaN                                         NaN
# 2                             NaN                                         NaN
#
#   waste_treatment_incineration_percent  \
# 0                                  NaN
# 1                                  NaN
# 2                                  NaN
#
#   waste_treatment_landfill_unspecified_percent  \
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
#
#   waste_treatment_open_dump_percent waste_treatment_other_percent  \
# 0                             100.0                           NaN
# 1                             100.0                           NaN
# 2                             100.0                           NaN
#
#   waste_treatment_recycling_percent  \
# 0                               NaN
# 1                               NaN
# 2                               NaN
#
#    waste_treatment_sanitary_landfill_landfill_gas_system_percent  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
#
#    waste_treatment_unaccounted_for_percent  \
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
#
#    waste_treatment_waterways_marine_percent
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
#
# [3 rows x 123 columns]

# %%
country_code = "/Users/shilpa/Desktop/Boringppl_project/WasteManagement/Data/country_level_codebook.csv"
country_code_df = pd.read_csv(country_code, encoding = 'utf-8')
country_code_df.head()
# Out:
#   regionID iso3c country_name incomeID  \
# 0      ECS   LUX   Luxembourg      HIC
# 1      ECS   NOR       Norway      HIC
# 2      MEA   MLT        Malta      HIC
# 3      EAS   NZL  New Zealand      HIC
# 4      EAS   JPN        Japan      HIC
#
#                                   measurement        units  year  \
# 0  special_waste_agricultural_waste_tons_year  tonnes/year  2014
# 1  special_waste_agricultural_waste_tons_year  tonnes/year  2014
# 2  special_waste_agricultural_waste_tons_year  tonnes/year  2014
# 3  special_waste_agricultural_waste_tons_year  tonnes/year  2014
# 4  special_waste_agricultural_waste_tons_year  tonnes/year  2010
#
#                                               source  \
# 0  Eurostat. 2017a. "Generation of waste by waste...
# 1  Eurostat. 2017a. "Generation of waste by waste...
# 2  Eurostat. 2017a. "Generation of waste by waste...
# 3  New Zealand, MFE (Ministry for the Environment...
# 4  Modak, Prasad, Agamuthu Pariatamby, Jeffrey Se...
#
#                                             comments
# 0                                            1; 2; 4
# 1  1; HW includes waste containing oil, solvents,...
# 2                                         1; 2; 3; 4
# 3  CandD waste reported as over 3 million tonnes/...
# 4  6 (excludes hazardous MSW); e-waste includes h...

# %%
country_data = "/Users/shilpa/Desktop/Boringppl_project/WasteManagement/Data/country_level_data_0.csv"
country_data_df = pd.read_csv(country_data, encoding = 'utf-8')
country_data_df.head()
# Out:
#   iso3c region_id country_name income_id           gdp  \
# 0   ABW       LCN        Aruba       HIC           NaN
# 1   AFG       SAS  Afghanistan       LIC  2.141361e+10
# 2   AGO       SSF       Angola       LMC  1.030423e+11
# 3   ALB       ECS      Albania       UMC  1.347108e+10
# 4   AND       ECS      Andorra       HIC  3.319880e+09
#
#    composition_food_organic_waste_percent  composition_glass_percent  \
# 0                                     NaN                        NaN
# 1                                     NaN                        NaN
# 2                                    51.8                        6.7
# 3                                    51.4                        4.5
# 4                                    31.2                        8.2
#
#    composition_metal_percent  composition_other_percent  \
# 0                        NaN                        NaN
# 1                        NaN                        NaN
# 2                        4.4                      11.50
# 3                        4.8                      15.21
# 4                        2.6                      11.60
#
#    composition_paper_cardboard_percent  ...  \
# 0                                  NaN  ...
# 1                                  NaN  ...
# 2                                 11.9  ...
# 3                                  9.9  ...
# 4                                 35.1  ...
#
#    waste_treatment_controlled_landfill_percent  \
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
#
#    waste_treatment_incineration_percent  \
# 0                                   NaN
# 1                                   NaN
# 2                                   NaN
# 3                                   NaN
# 4                                  52.1
#
#    waste_treatment_landfill_unspecified_percent  \
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
#
#    waste_treatment_open_dump_percent waste_treatment_other_percent  \
# 0                                NaN                           NaN
# 1                                NaN                           NaN
# 2                                NaN                           NaN
# 3                                NaN                           NaN
# 4                                NaN                           NaN
#
#   waste_treatment_recycling_percent  \
# 0                              11.0
# 1                               NaN
# 2                               NaN
# 3                               NaN
# 4                               NaN
#
#   waste_treatment_sanitary_landfill_landfill_gas_system_percent  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   waste_treatment_unaccounted_for_percent  \
# 0                                    89.0
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4                                    47.9
#
#   waste_treatment_waterways_marine_percent  where_where_is_this_data_measured
# 0                                      NaN                                NaN
# 1                                      NaN                              Other
# 2                                      NaN                                NaN
# 3                                      NaN                Some disposal sites
# 4                                      NaN                                NaN
#
# [5 rows x 51 columns]

# %%
country_data_df.columns
# Out:
# Index(['iso3c', 'region_id', 'country_name', 'income_id', 'gdp',
#        'composition_food_organic_waste_percent', 'composition_glass_percent',
#        'composition_metal_percent', 'composition_other_percent',
#        'composition_paper_cardboard_percent', 'composition_plastic_percent',
#        'composition_rubber_leather_percent', 'composition_wood_percent',
#        'composition_yard_garden_green_waste_percent',
#        'other_information_information_system_for_solid_waste_management',
#        'other_information_national_agency_to_enforce_solid_waste_laws_and_regulations',
#        'other_information_national_law_governing_solid_waste_management_in_the_country',
#        'other_information_ppp_rules_and_regulations',
#        'other_information_summary_of_key_solid_waste_information_made_available_to_the_public',
#        'population_population_number_of_people',
#        'special_waste_agricultural_waste_tons_year',
#        'special_waste_construction_and_demolition_waste_tons_year',
#        'special_waste_e_waste_tons_year',
#        'special_waste_hazardous_waste_tons_year',
#        'special_waste_industrial_waste_tons_year',
#        'special_waste_medical_waste_tons_year',
#        'total_msw_total_msw_generated_tons_year',
#        'waste_collection_coverage_rural_percent_of_geographic_area',
#        'waste_collection_coverage_rural_percent_of_households',
#        'waste_collection_coverage_rural_percent_of_population',
#        'waste_collection_coverage_rural_percent_of_waste',
#        'waste_collection_coverage_total_percent_of_geographic_area',
#        'waste_collection_coverage_total_percent_of_households',
#        'waste_collection_coverage_total_percent_of_population',
#        'waste_collection_coverage_total_percent_of_waste',
#        'waste_collection_coverage_urban_percent_of_geographic_area',
#        'waste_collection_coverage_urban_percent_of_households',
#        'waste_collection_coverage_urban_percent_of_population',
#        'waste_collection_coverage_urban_percent_of_waste',
#        'waste_treatment_anaerobic_digestion_percent',
#        'waste_treatment_compost_percent',
#        'waste_treatment_controlled_landfill_percent',
#        'waste_treatment_incineration_percent',
#        'waste_treatment_landfill_unspecified_percent',
#        'waste_treatment_open_dump_percent', 'waste_treatment_other_percent',
#        'waste_treatment_recycling_percent',
#        'waste_treatment_sanitary_landfill_landfill_gas_system_percent',
#        'waste_treatment_unaccounted_for_percent',
#        'waste_treatment_waterways_marine_percent',
#        'where_where_is_this_data_measured'],
#       dtype='object')

# %%
world_merge = pd.merge(country_data_df, country_code_df, on='country_name')
world_merge.head(3)
# Out:
#   iso3c_x region_id country_name income_id  gdp  \
# 0     ABW       LCN        Aruba       HIC  NaN
# 1     ABW       LCN        Aruba       HIC  NaN
# 2     ABW       LCN        Aruba       HIC  NaN
#
#    composition_food_organic_waste_percent  composition_glass_percent  \
# 0                                     NaN                        NaN
# 1                                     NaN                        NaN
# 2                                     NaN                        NaN
#
#    composition_metal_percent  composition_other_percent  \
# 0                        NaN                        NaN
# 1                        NaN                        NaN
# 2                        NaN                        NaN
#
#    composition_paper_cardboard_percent  ...  \
# 0                                  NaN  ...
# 1                                  NaN  ...
# 2                                  NaN  ...
#
#    waste_treatment_waterways_marine_percent  \
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
#
#    where_where_is_this_data_measured  regionID  iso3c_y incomeID  \
# 0                                NaN       LCN      ABW      HIC
# 1                                NaN       LCN      ABW      HIC
# 2                                NaN       LCN      ABW      HIC
#
#                                measurement        units  year  \
# 0        waste_treatment_recycling_percent  tonnes/year  2013
# 1  total_msw_total_msw_generated_tons_year  tonnes/year  2013
# 2  waste_treatment_unaccounted_for_percent  tonnes/year   NaN
#
#                                               source                comments
# 0  PricewaterhouseCoopers Aruba. 2014. "Environme...                     NaN
# 1  PricewaterhouseCoopers Aruba. 2014. "Environme...  1 (2.34 kg/person/day)
# 2                                                NaN                     NaN
#
# [3 rows x 59 columns]

# %%
world_merge.columns
# Out:
# Index(['iso3c_x', 'region_id', 'country_name', 'income_id', 'gdp',
#        'composition_food_organic_waste_percent', 'composition_glass_percent',
#        'composition_metal_percent', 'composition_other_percent',
#        'composition_paper_cardboard_percent', 'composition_plastic_percent',
#        'composition_rubber_leather_percent', 'composition_wood_percent',
#        'composition_yard_garden_green_waste_percent',
#        'other_information_information_system_for_solid_waste_management',
#        'other_information_national_agency_to_enforce_solid_waste_laws_and_regulations',
#        'other_information_national_law_governing_solid_waste_management_in_the_country',
#        'other_information_ppp_rules_and_regulations',
#        'other_information_summary_of_key_solid_waste_information_made_available_to_the_public',
#        'population_population_number_of_people',
#        'special_waste_agricultural_waste_tons_year',
#        'special_waste_construction_and_demolition_waste_tons_year',
#        'special_waste_e_waste_tons_year',
#        'special_waste_hazardous_waste_tons_year',
#        'special_waste_industrial_waste_tons_year',
#        'special_waste_medical_waste_tons_year',
#        'total_msw_total_msw_generated_tons_year',
#        'waste_collection_coverage_rural_percent_of_geographic_area',
#        'waste_collection_coverage_rural_percent_of_households',
#        'waste_collection_coverage_rural_percent_of_population',
#        'waste_collection_coverage_rural_percent_of_waste',
#        'waste_collection_coverage_total_percent_of_geographic_area',
#        'waste_collection_coverage_total_percent_of_households',
#        'waste_collection_coverage_total_percent_of_population',
#        'waste_collection_coverage_total_percent_of_waste',
#        'waste_collection_coverage_urban_percent_of_geographic_area',
#        'waste_collection_coverage_urban_percent_of_households',
#        'waste_collection_coverage_urban_percent_of_population',
#        'waste_collection_coverage_urban_percent_of_waste',
#        'waste_treatment_anaerobic_digestion_percent',
#        'waste_treatment_compost_percent',
#        'waste_treatment_controlled_landfill_percent',
#        'waste_treatment_incineration_percent',
#        'waste_treatment_landfill_unspecified_percent',
#        'waste_treatment_open_dump_percent', 'waste_treatment_other_percent',
#        'waste_treatment_recycling_percent',
#        'waste_treatment_sanitary_landfill_landfill_gas_system_percent',
#        'waste_treatment_unaccounted_for_percent',
#        'waste_treatment_waterways_marine_percent',
#        'where_where_is_this_data_measured', 'regionID', 'iso3c_y', 'incomeID',
#        'measurement', 'units', 'year', 'source', 'comments'],
#       dtype='object')

# %%
world_city_merge = pd.merge(city_data_df, country_data_df,on='country_name')
world_city_merge.head()
# Out:
#   iso3c_x region_id_x country_name income_id_x       city_name  \
# 0     AFG         SAS  Afghanistan         LIC       Jalalabad
# 1     AFG         SAS  Afghanistan         LIC        Kandahar
# 2     AFG         SAS  Afghanistan         LIC  Mazar-E-Sharif
# 3     AFG         SAS  Afghanistan         LIC           Kabul
# 4     AFG         SAS  Afghanistan         LIC         HiratÂ
#
#   additional_data_annual_budget_for_waste_management_year  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   additional_data_annual_solid_waste_budget_year  \
# 0                                            NaN
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# 4                                            NaN
#
#    additional_data_annual_swm_budget_2017_year  \
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
#
#    additional_data_annual_swm_budget_year  \
# 0                                     NaN
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
#
#    additional_data_annual_waste_budget_year  ...  \
# 0                                       NaN  ...
# 1                                       NaN  ...
# 2                                       NaN  ...
# 3                                       NaN  ...
# 4                                       NaN  ...
#
#    waste_treatment_controlled_landfill_percent_y  \
# 0                                            NaN
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# 4                                            NaN
#
#    waste_treatment_incineration_percent_y  \
# 0                                     NaN
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
#
#   waste_treatment_landfill_unspecified_percent_y  \
# 0                                            NaN
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# 4                                            NaN
#
#   waste_treatment_open_dump_percent_y waste_treatment_other_percent_y  \
# 0                                 NaN                             NaN
# 1                                 NaN                             NaN
# 2                                 NaN                             NaN
# 3                                 NaN                             NaN
# 4                                 NaN                             NaN
#
#    waste_treatment_recycling_percent_y  \
# 0                                  NaN
# 1                                  NaN
# 2                                  NaN
# 3                                  NaN
# 4                                  NaN
#
#    waste_treatment_sanitary_landfill_landfill_gas_system_percent_y  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    waste_treatment_unaccounted_for_percent_y  \
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
#
#   waste_treatment_waterways_marine_percent_y where_where_is_this_data_measured
# 0                                        NaN                             Other
# 1                                        NaN                             Other
# 2                                        NaN                             Other
# 3                                        NaN                             Other
# 4                                        NaN                             Other
#
# [5 rows x 163 columns]

# %%
world_city_merge.columns
# Out:
# Index(['iso3c_x', 'region_id_x', 'country_name', 'income_id_x', 'city_name',
#        'additional_data_annual_budget_for_waste_management_year',
#        'additional_data_annual_solid_waste_budget_year',
#        'additional_data_annual_swm_budget_2017_year',
#        'additional_data_annual_swm_budget_year',
#        'additional_data_annual_waste_budget_year',
#        ...
#        'waste_treatment_controlled_landfill_percent_y',
#        'waste_treatment_incineration_percent_y',
#        'waste_treatment_landfill_unspecified_percent_y',
#        'waste_treatment_open_dump_percent_y',
#        'waste_treatment_other_percent_y',
#        'waste_treatment_recycling_percent_y',
#        'waste_treatment_sanitary_landfill_landfill_gas_system_percent_y',
#        'waste_treatment_unaccounted_for_percent_y',
#        'waste_treatment_waterways_marine_percent_y',
#        'where_where_is_this_data_measured'],
#       dtype='object', length=163)

# %%
#grouped = world_merge.groupby('year')

#for name,group in grouped:
   #print(name)
   #print(group)

# %%
grouped = world_merge.groupby('year')
world_group_2017 = grouped.get_group('2017')
world_group_2017.head()

#for name,group in grouped:
    #print(grouped.get_group('2017'))
# Out:
#     iso3c_x region_id        country_name income_id           gdp  \
# 538     BTN       SAS              Bhutan       LMC  2.234759e+09
# 905     DOM       LCN  Dominican Republic       UMC  7.366413e+10
# 911     DOM       LCN  Dominican Republic       UMC  7.366413e+10
# 913     DOM       LCN  Dominican Republic       UMC  7.366413e+10
# 918     DZA       MEA             Algeria       UMC  1.960348e+11
#
#      composition_food_organic_waste_percent  composition_glass_percent  \
# 538                                    58.0                        4.0
# 905                                    51.0                        6.0
# 911                                    51.0                        6.0
# 913                                    51.0                        6.0
# 918                                    54.4                        1.2
#
#      composition_metal_percent  composition_other_percent  \
# 538                        1.0                        7.0
# 905                        3.0                       10.0
# 911                        3.0                       10.0
# 913                        3.0                       10.0
# 918                        2.8                        0.8
#
#      composition_paper_cardboard_percent  ...  \
# 538                                 17.0  ...
# 905                                 16.0  ...
# 911                                 16.0  ...
# 913                                 16.0  ...
# 918                                  9.8  ...
#
#      waste_treatment_waterways_marine_percent  \
# 538                                       NaN
# 905                                       NaN
# 911                                       NaN
# 913                                       NaN
# 918                                       NaN
#
#      where_where_is_this_data_measured  regionID  iso3c_y incomeID  \
# 538                             Source       SAS      BTN      LMC
# 905                              Other       LCN      DOM      UMC
# 911                              Other       LCN      DOM      UMC
# 913                              Other       LCN      DOM      UMC
# 918                      Disposal Site       MEA      DZA      UMC
#
#                                            measurement                  units  \
# 538              special_waste_medical_waste_tons_year            tonnes/year
# 905                  waste_treatment_open_dump_percent            tonnes/year
# 911  waste_treatment_sanitary_landfill_landfill_gas...            tonnes/year
# 913            waste_treatment_unaccounted_for_percent            tonnes/year
# 918  waste_collection_coverage_rural_percent_of_hou...  Percent of population
#
#      year                                             source  \
# 538  2017  WHO (World Health Organization). 2017. "Report...
# 905  2017  Dominican Republic, Ministry of Environment an...
# 911  2017  Dominican Republic, Ministry of Environment an...
# 913  2017                                                NaN
# 918  2017  Ouamane, Karim. 2017. General Director, Waste ...
#
#                                               comments
# 538                                                NaN
# 905                                                NaN
# 911                                                NaN
# 913  OD: Calculated based on the sum of other treat...
# 918                                                NaN
#
# [5 rows x 59 columns]

# %%
world_group_2017.columns
# Out:
# Index(['iso3c_x', 'region_id', 'country_name', 'income_id', 'gdp',
#        'composition_food_organic_waste_percent', 'composition_glass_percent',
#        'composition_metal_percent', 'composition_other_percent',
#        'composition_paper_cardboard_percent', 'composition_plastic_percent',
#        'composition_rubber_leather_percent', 'composition_wood_percent',
#        'composition_yard_garden_green_waste_percent',
#        'other_information_information_system_for_solid_waste_management',
#        'other_information_national_agency_to_enforce_solid_waste_laws_and_regulations',
#        'other_information_national_law_governing_solid_waste_management_in_the_country',
#        'other_information_ppp_rules_and_regulations',
#        'other_information_summary_of_key_solid_waste_information_made_available_to_the_public',
#        'population_population_number_of_people',
#        'special_waste_agricultural_waste_tons_year',
#        'special_waste_construction_and_demolition_waste_tons_year',
#        'special_waste_e_waste_tons_year',
#        'special_waste_hazardous_waste_tons_year',
#        'special_waste_industrial_waste_tons_year',
#        'special_waste_medical_waste_tons_year',
#        'total_msw_total_msw_generated_tons_year',
#        'waste_collection_coverage_rural_percent_of_geographic_area',
#        'waste_collection_coverage_rural_percent_of_households',
#        'waste_collection_coverage_rural_percent_of_population',
#        'waste_collection_coverage_rural_percent_of_waste',
#        'waste_collection_coverage_total_percent_of_geographic_area',
#        'waste_collection_coverage_total_percent_of_households',
#        'waste_collection_coverage_total_percent_of_population',
#        'waste_collection_coverage_total_percent_of_waste',
#        'waste_collection_coverage_urban_percent_of_geographic_area',
#        'waste_collection_coverage_urban_percent_of_households',
#        'waste_collection_coverage_urban_percent_of_population',
#        'waste_collection_coverage_urban_percent_of_waste',
#        'waste_treatment_anaerobic_digestion_percent',
#        'waste_treatment_compost_percent',
#        'waste_treatment_controlled_landfill_percent',
#        'waste_treatment_incineration_percent',
#        'waste_treatment_landfill_unspecified_percent',
#        'waste_treatment_open_dump_percent', 'waste_treatment_other_percent',
#        'waste_treatment_recycling_percent',
#        'waste_treatment_sanitary_landfill_landfill_gas_system_percent',
#        'waste_treatment_unaccounted_for_percent',
#        'waste_treatment_waterways_marine_percent',
#        'where_where_is_this_data_measured', 'regionID', 'iso3c_y', 'incomeID',
#        'measurement', 'units', 'year', 'source', 'comments'],
#       dtype='object')

# %%
List_Of_Categories_In_Column = list(world_group_2017['income_id'].value_counts().index)

List_Of_Categories_In_Column
# Out:
# ['UMC', 'HIC', 'LMC', 'LIC']

# %%
waste_generated = world_group_2017[['country_name', 
                                    'income_id', 
                                    'gdp', 
                                    'population_population_number_of_people',
                                    'composition_food_organic_waste_percent', 
                                    'composition_glass_percent',
                                    'composition_metal_percent', 
                                    'composition_other_percent',
                                    'composition_paper_cardboard_percent', 
                                    'composition_plastic_percent',
                                    'composition_rubber_leather_percent', 
                                    'composition_wood_percent',
                                    'composition_yard_garden_green_waste_percent']]
waste_generated.fillna(0).head(2)
#Nan values were converted too zeros because dtypes were float
# Out:
#            country_name income_id           gdp  \
# 538              Bhutan       LMC  2.234759e+09
# 905  Dominican Republic       UMC  7.366413e+10
#
#      population_population_number_of_people  \
# 538                                686958.0
# 905                              10528394.0
#
#      composition_food_organic_waste_percent  composition_glass_percent  \
# 538                                    58.0                        4.0
# 905                                    51.0                        6.0
#
#      composition_metal_percent  composition_other_percent  \
# 538                        1.0                        7.0
# 905                        3.0                       10.0
#
#      composition_paper_cardboard_percent  composition_plastic_percent  \
# 538                                 17.0                         13.0
# 905                                 16.0                         10.0
#
#      composition_rubber_leather_percent  composition_wood_percent  \
# 538                                 0.0                       0.0
# 905                                 0.0                       4.0
#
#      composition_yard_garden_green_waste_percent
# 538                                          0.0
# 905                                          0.0

# %%
waste_generated_LIC = waste_generated.groupby('income_id').get_group('LIC').fillna(0).drop_duplicates().set_index('country_name')
waste_generated_LIC.columns
# Out:
# Index(['income_id', 'gdp', 'population_population_number_of_people',
#        'composition_food_organic_waste_percent', 'composition_glass_percent',
#        'composition_metal_percent', 'composition_other_percent',
#        'composition_paper_cardboard_percent', 'composition_plastic_percent',
#        'composition_rubber_leather_percent', 'composition_wood_percent',
#        'composition_yard_garden_green_waste_percent'],
#       dtype='object')

# %%
LIC_waste = pd.DataFrame(waste_generated_LIC, columns =[
       'composition_food_organic_waste_percent', 'composition_glass_percent',
       'composition_metal_percent', 'composition_other_percent',
       'composition_paper_cardboard_percent', 'composition_plastic_percent',
       'composition_rubber_leather_percent', 'composition_wood_percent'])
LIC_waste.plot.bar(legend=True, stacked=True);
plt.legend(loc='center left',bbox_to_anchor=(1.0, 0.5))
plt.show()
plt.tight_layout()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
waste_generated_LMC = waste_generated.groupby('income_id').get_group('LMC').fillna(0).drop_duplicates().set_index('country_name')
waste_generated_LMC
# Out:
#              income_id           gdp  population_population_number_of_people  \
# country_name
# Bhutan             LMC  2.234759e+09                            6.869580e+05
# Indonesia          LMC  1.037864e+12                            2.611155e+08
# India              LMC  2.466177e+12                            1.071478e+09
# Sri Lanka          LMC  7.990704e+10                            2.120300e+07
# Myanmar            LMC  7.446983e+10                            4.609546e+07
# Pakistan           LMC  2.278669e+11                            1.932035e+08
#
#               composition_food_organic_waste_percent  \
# country_name
# Bhutan                                          58.0
# Indonesia                                       53.8
# India                                            0.0
# Sri Lanka                                       62.0
# Myanmar                                          0.0
# Pakistan                                        30.0
#
#               composition_glass_percent  composition_metal_percent  \
# country_name
# Bhutan                              4.0                        1.0
# Indonesia                           2.5                        1.8
# India                               0.0                        0.0
# Sri Lanka                           2.0                        3.0
# Myanmar                             0.0                        0.0
# Pakistan                            6.0                        4.0
#
#               composition_other_percent  composition_paper_cardboard_percent  \
# country_name
# Bhutan                              7.0                                 17.0
# Indonesia                          12.9                                 14.9
# India                               0.0                                  0.0
# Sri Lanka                          13.0                                  7.0
# Myanmar                             0.0                                  0.0
# Pakistan                           20.0                                 13.0
#
#               composition_plastic_percent  composition_rubber_leather_percent  \
# country_name
# Bhutan                               13.0                                 0.0
# Indonesia                            14.0                                 0.0
# India                                 0.0                                 0.0
# Sri Lanka                             7.0                                 0.0
# Myanmar                               0.0                                 0.0
# Pakistan                              9.0                                 2.0
#
#               composition_wood_percent  \
# country_name
# Bhutan                             0.0
# Indonesia                          0.0
# India                              0.0
# Sri Lanka                          6.0
# Myanmar                            0.0
# Pakistan                           2.0
#
#               composition_yard_garden_green_waste_percent
# country_name
# Bhutan                                                0.0
# Indonesia                                             0.0
# India                                                 0.0
# Sri Lanka                                             0.0
# Myanmar                                               0.0
# Pakistan                                             14.0

# %%
LMC_waste = pd.DataFrame(waste_generated_LMC, columns =[
       'composition_food_organic_waste_percent', 'composition_glass_percent',
       'composition_metal_percent', 'composition_other_percent',
       'composition_paper_cardboard_percent', 'composition_plastic_percent',
       'composition_rubber_leather_percent', 'composition_wood_percent'])
LMC_waste.plot.bar(legend=True, stacked=True);
plt.legend(loc='center left',bbox_to_anchor=(1.0, 0.5))
plt.show()
plt.tight_layout()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
waste_generated_UMC = waste_generated.groupby('income_id').get_group('UMC').fillna(0).drop_duplicates().set_index('country_name')
waste_generated_UMC
# Nan values converted to zeros
# Out:
#                    income_id           gdp  \
# country_name
# Dominican Republic       UMC  7.366413e+10
# Algeria                  UMC  1.960348e+11
# Iran, Islamic Rep.       UMC  5.405812e+11
# Maldives                 UMC  3.600399e+09
# Mauritius                UMC  1.240984e+10
# Malaysia                 UMC  3.440523e+11
#
#                     population_population_number_of_people  \
# country_name
# Dominican Republic                              10528394.0
# Algeria                                         40606052.0
# Iran, Islamic Rep.                              80277428.0
# Maldives                                          409163.0
# Mauritius                                        1263473.0
# Malaysia                                        30228017.0
#
#                     composition_food_organic_waste_percent  \
# country_name
# Dominican Republic                                    51.0
# Algeria                                               54.4
# Iran, Islamic Rep.                                    72.9
# Maldives                                              24.0
# Mauritius                                             64.0
# Malaysia                                              46.0
#
#                     composition_glass_percent  composition_metal_percent  \
# country_name
# Dominican Republic                        6.0                        3.0
# Algeria                                   1.2                        2.8
# Iran, Islamic Rep.                        1.9                        2.3
# Maldives                                  0.0                        1.0
# Mauritius                                 2.8                        0.0
# Malaysia                                  3.0                        3.0
#
#                     composition_other_percent  \
# country_name
# Dominican Republic                       10.0
# Algeria                                   0.8
# Iran, Islamic Rep.                        5.0
# Maldives                                  1.0
# Mauritius                                 8.0
# Malaysia                                  9.0
#
#                     composition_paper_cardboard_percent  \
# country_name
# Dominican Republic                                 16.0
# Algeria                                             9.8
# Iran, Islamic Rep.                                  7.3
# Maldives                                            6.0
# Mauritius                                          13.0
# Malaysia                                           14.0
#
#                     composition_plastic_percent  \
# country_name
# Dominican Republic                         10.0
# Algeria                                    16.9
# Iran, Islamic Rep.                          8.5
# Maldives                                    3.0
# Mauritius                                  12.4
# Malaysia                                   15.0
#
#                     composition_rubber_leather_percent  \
# country_name
# Dominican Republic                                 0.0
# Algeria                                           12.6
# Iran, Islamic Rep.                                 1.1
# Maldives                                           0.0
# Mauritius                                          0.0
# Malaysia                                           3.0
#
#                     composition_wood_percent  \
# country_name
# Dominican Republic                       4.0
# Algeria                                  1.5
# Iran, Islamic Rep.                       1.3
# Maldives                                 0.0
# Mauritius                                0.0
# Malaysia                                 7.0
#
#                     composition_yard_garden_green_waste_percent
# country_name
# Dominican Republic                                          0.0
# Algeria                                                     0.0
# Iran, Islamic Rep.                                          0.0
# Maldives                                                   65.0
# Mauritius                                                   0.0
# Malaysia                                                    0.0

# %%
UMC_waste = pd.DataFrame(waste_generated_UMC, columns =[
       'composition_food_organic_waste_percent', 'composition_glass_percent',
       'composition_metal_percent', 'composition_other_percent',
       'composition_paper_cardboard_percent', 'composition_plastic_percent',
       'composition_rubber_leather_percent', 'composition_wood_percent'])
UMC_waste.plot.bar(legend=True, stacked=True);
plt.legend(loc='center left',bbox_to_anchor=(1.0, 0.5))
plt.show()
plt.tight_layout()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
waste_generated_HIC = waste_generated.groupby('income_id').get_group('HIC').fillna(0).drop_duplicates().set_index('country_name')
waste_generated_HIC
# Nan values converted to zeros
# Out:
#                      income_id           gdp  \
# country_name
# Hong Kong SAR, China       HIC  2.701054e+11
# Israel                     HIC  2.878076e+11
# St. Kitts and Nevis        HIC  8.583447e+08
# Oman                       HIC  7.505436e+10
# Qatar                      HIC  1.706626e+11
# Saudi Arabia               HIC  6.900688e+11
# Singapore                  HIC  2.991701e+11
#
#                       population_population_number_of_people  \
# country_name
# Hong Kong SAR, China                               7305700.0
# Israel                                             8380100.0
# St. Kitts and Nevis                                  54288.0
# Oman                                               3960925.0
# Qatar                                              2109568.0
# Saudi Arabia                                      31557144.0
# Singapore                                          5607283.0
#
#                       composition_food_organic_waste_percent  \
# country_name
# Hong Kong SAR, China                                   35.00
# Israel                                                 34.00
# St. Kitts and Nevis                                    27.20
# Oman                                                   27.00
# Qatar                                                  57.00
# Saudi Arabia                                           45.50
# Singapore                                              10.51
#
#                       composition_glass_percent  composition_metal_percent  \
# country_name
# Hong Kong SAR, China                       3.00                       2.00
# Israel                                     3.00                       3.00
# St. Kitts and Nevis                        8.10                       8.80
# Oman                                       6.00                       0.00
# Qatar                                      4.00                       9.00
# Saudi Arabia                               4.00                       5.00
# Singapore                                  0.93                      19.12
#
#                       composition_other_percent  \
# country_name
# Hong Kong SAR, China                       14.0
# Israel                                     16.0
# St. Kitts and Nevis                        12.2
# Oman                                       24.0
# Qatar                                       5.0
# Saudi Arabia                                2.5
# Singapore                                  32.3
#
#                       composition_paper_cardboard_percent  \
# country_name
# Hong Kong SAR, China                                22.00
# Israel                                              24.00
# St. Kitts and Nevis                                 20.50
# Oman                                                15.00
# Qatar                                               11.00
# Saudi Arabia                                        27.00
# Singapore                                           14.86
#
#                       composition_plastic_percent  \
# country_name
# Hong Kong SAR, China                        21.00
# Israel                                      18.00
# St. Kitts and Nevis                         23.20
# Oman                                        21.00
# Qatar                                       14.00
# Saudi Arabia                                11.00
# Singapore                                   10.58
#
#                       composition_rubber_leather_percent  \
# country_name
# Hong Kong SAR, China                                0.00
# Israel                                              0.00
# St. Kitts and Nevis                                 0.00
# Oman                                                0.00
# Qatar                                               0.00
# Saudi Arabia                                        0.00
# Singapore                                           1.96
#
#                       composition_wood_percent  \
# country_name
# Hong Kong SAR, China                       3.0
# Israel                                     0.0
# St. Kitts and Nevis                        0.0
# Oman                                       2.0
# Qatar                                      0.0
# Saudi Arabia                               5.0
# Singapore                                  5.5
#
#                       composition_yard_garden_green_waste_percent
# country_name
# Hong Kong SAR, China                                         0.00
# Israel                                                       2.00
# St. Kitts and Nevis                                          0.00
# Oman                                                         5.00
# Qatar                                                        0.00
# Saudi Arabia                                                 0.00
# Singapore                                                    4.26

# %%
HIC_waste = pd.DataFrame(waste_generated_HIC, columns =[
       'composition_food_organic_waste_percent', 'composition_glass_percent',
       'composition_metal_percent', 'composition_other_percent',
       'composition_paper_cardboard_percent', 'composition_plastic_percent',
       'composition_rubber_leather_percent', 'composition_wood_percent'])
HIC_waste.plot.bar(legend=True, stacked=True);
plt.legend(loc='center left',bbox_to_anchor=(1.0, 0.5))
plt.show()
plt.tight_layout()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
waste_information = world_group_2017[[
        'country_name', 
        'income_id', 'gdp', 
        'population_population_number_of_people',
        'other_information_information_system_for_solid_waste_management',
        'other_information_national_agency_to_enforce_solid_waste_laws_and_regulations',
        'other_information_national_law_governing_solid_waste_management_in_the_country',
        'other_information_ppp_rules_and_regulations',
        'other_information_summary_of_key_solid_waste_information_made_available_to_the_public']]
waste_information.fillna('No info')

# Converted Nan values to no info
# Out:
#             country_name income_id           gdp  \
# 538               Bhutan       LMC  2.234759e+09
# 905   Dominican Republic       UMC  7.366413e+10
# 911   Dominican Republic       UMC  7.366413e+10
# 913   Dominican Republic       UMC  7.366413e+10
# 918              Algeria       UMC  1.960348e+11
# ...                  ...       ...           ...
# 3013           Singapore       HIC  2.991701e+11
# 3014           Singapore       HIC  2.991701e+11
# 3462              Uganda       LIC  2.748306e+10
# 3467              Uganda       LIC  2.748306e+10
# 3468              Uganda       LIC  2.748306e+10
#
#       population_population_number_of_people  \
# 538                                 686958.0
# 905                               10528394.0
# 911                               10528394.0
# 913                               10528394.0
# 918                               40606052.0
# ...                                      ...
# 3013                               5607283.0
# 3014                               5607283.0
# 3462                              35093648.0
# 3467                              35093648.0
# 3468                              35093648.0
#
#      other_information_information_system_for_solid_waste_management  \
# 538                                                  No
# 905                                                  No
# 911                                                  No
# 913                                                  No
# 918                                                 Yes
# ...                                                 ...
# 3013                                                Yes
# 3014                                                Yes
# 3462                                            No info
# 3467                                            No info
# 3468                                            No info
#
#      other_information_national_agency_to_enforce_solid_waste_laws_and_regulations  \
# 538                                                 Yes
# 905                                                 Yes
# 911                                                 Yes
# 913                                                 Yes
# 918                                                 Yes
# ...                                                 ...
# 3013                                                Yes
# 3014                                                Yes
# 3462                                            No info
# 3467                                            No info
# 3468                                            No info
#
#      other_information_national_law_governing_solid_waste_management_in_the_country  \
# 538                                                 Yes
# 905                                                  No
# 911                                                  No
# 913                                                  No
# 918                                                 Yes
# ...                                                 ...
# 3013                                                Yes
# 3014                                                Yes
# 3462                                            No info
# 3467                                            No info
# 3468                                            No info
#
#      other_information_ppp_rules_and_regulations  \
# 538                                          Yes
# 905                                           No
# 911                                           No
# 913                                           No
# 918                                      No info
# ...                                          ...
# 3013                                         Yes
# 3014                                         Yes
# 3462                                     No info
# 3467                                     No info
# 3468                                     No info
#
#      other_information_summary_of_key_solid_waste_information_made_available_to_the_public
# 538                                                 Yes
# 905                                             No info
# 911                                             No info
# 913                                             No info
# 918                                                 Yes
# ...                                                 ...
# 3013                                                Yes
# 3014                                                Yes
# 3462                                            No info
# 3467                                            No info
# 3468                                            No info
#
# [126 rows x 9 columns]

# %%
special_waste =  world_group_2017[[
        'country_name', 
        'income_id', 'gdp', 
        'population_population_number_of_people',
        'special_waste_agricultural_waste_tons_year',
        'special_waste_construction_and_demolition_waste_tons_year',
        'special_waste_e_waste_tons_year',
        'special_waste_hazardous_waste_tons_year',
        'special_waste_industrial_waste_tons_year',
        'special_waste_medical_waste_tons_year',
        'total_msw_total_msw_generated_tons_year', 
        'waste_collection_coverage_rural_percent_of_geographic_area']]
special_waste.fillna(0)

# Nan values converted to zeros
# Out:
#             country_name income_id           gdp  \
# 538               Bhutan       LMC  2.234759e+09
# 905   Dominican Republic       UMC  7.366413e+10
# 911   Dominican Republic       UMC  7.366413e+10
# 913   Dominican Republic       UMC  7.366413e+10
# 918              Algeria       UMC  1.960348e+11
# ...                  ...       ...           ...
# 3013           Singapore       HIC  2.991701e+11
# 3014           Singapore       HIC  2.991701e+11
# 3462              Uganda       LIC  2.748306e+10
# 3467              Uganda       LIC  2.748306e+10
# 3468              Uganda       LIC  2.748306e+10
#
#       population_population_number_of_people  \
# 538                                 686958.0
# 905                               10528394.0
# 911                               10528394.0
# 913                               10528394.0
# 918                               40606052.0
# ...                                      ...
# 3013                               5607283.0
# 3014                               5607283.0
# 3462                              35093648.0
# 3467                              35093648.0
# 3468                              35093648.0
#
#       special_waste_agricultural_waste_tons_year  \
# 538                                          0.0
# 905                                          0.0
# 911                                          0.0
# 913                                          0.0
# 918                                          0.0
# ...                                          ...
# 3013                                         0.0
# 3014                                         0.0
# 3462                                         0.0
# 3467                                         0.0
# 3468                                         0.0
#
#       special_waste_construction_and_demolition_waste_tons_year  \
# 538                                                 0.0
# 905                                                 0.0
# 911                                                 0.0
# 913                                                 0.0
# 918                                          11000000.0
# ...                                                 ...
# 3013                                          1609300.0
# 3014                                          1609300.0
# 3462                                                0.0
# 3467                                                0.0
# 3468                                                0.0
#
#       special_waste_e_waste_tons_year  \
# 538                            1457.5
# 905                           57000.0
# 911                           57000.0
# 913                           57000.0
# 918                          252000.0
# ...                               ...
# 3013                         100000.0
# 3014                         100000.0
# 3462                          25000.0
# 3467                          25000.0
# 3468                          25000.0
#
#       special_waste_hazardous_waste_tons_year  \
# 538                                       0.0
# 905                                       0.0
# 911                                       0.0
# 913                                       0.0
# 918                                  330000.0
# ...                                       ...
# 3013                                 446870.0
# 3014                                 446870.0
# 3462                                      0.0
# 3467                                      0.0
# 3468                                      0.0
#
#       special_waste_industrial_waste_tons_year  \
# 538                                    1476.37
# 905                                       0.00
# 911                                       0.00
# 913                                       0.00
# 918                                 2547000.00
# ...                                        ...
# 3013                                      0.00
# 3014                                      0.00
# 3462                                      0.00
# 3467                                      0.00
# 3468                                      0.00
#
#       special_waste_medical_waste_tons_year  \
# 538                                   358.0
# 905                                     0.0
# 911                                     0.0
# 913                                     0.0
# 918                                 30000.0
# ...                                     ...
# 3013                                    0.0
# 3014                                    0.0
# 3462                                    0.0
# 3467                                    0.0
# 3468                                    0.0
#
#       total_msw_total_msw_generated_tons_year  \
# 538                              1.113141e+05
# 905                              4.063910e+06
# 911                              4.063910e+06
# 913                              4.063910e+06
# 918                              1.237874e+07
# ...                                       ...
# 3013                             7.704300e+06
# 3014                             7.704300e+06
# 3462                             7.045050e+06
# 3467                             7.045050e+06
# 3468                             7.045050e+06
#
#       waste_collection_coverage_rural_percent_of_geographic_area
# 538                                                 0.0
# 905                                                 0.0
# 911                                                 0.0
# 913                                                 0.0
# 918                                                 0.0
# ...                                                 ...
# 3013                                                0.0
# 3014                                                0.0
# 3462                                                0.0
# 3467                                                0.0
# 3468                                                0.0
#
# [126 rows x 12 columns]

# %%
waste_collection = world_group_2017[[
        'country_name', 
        'income_id', 'gdp', 
        'population_population_number_of_people',
        'waste_collection_coverage_rural_percent_of_households',
        'waste_collection_coverage_rural_percent_of_population',
        'waste_collection_coverage_rural_percent_of_waste',
        'waste_collection_coverage_total_percent_of_geographic_area',
        'waste_collection_coverage_total_percent_of_households',
        'waste_collection_coverage_total_percent_of_population',
        'waste_collection_coverage_total_percent_of_waste',
        'waste_collection_coverage_urban_percent_of_geographic_area',
        'waste_collection_coverage_urban_percent_of_households',
        'waste_collection_coverage_urban_percent_of_population',
        'waste_collection_coverage_urban_percent_of_waste'
]]
waste_collection.fillna(0)

# converted Nan values to zeros
# Out:
#             country_name income_id           gdp  \
# 538               Bhutan       LMC  2.234759e+09
# 905   Dominican Republic       UMC  7.366413e+10
# 911   Dominican Republic       UMC  7.366413e+10
# 913   Dominican Republic       UMC  7.366413e+10
# 918              Algeria       UMC  1.960348e+11
# ...                  ...       ...           ...
# 3013           Singapore       HIC  2.991701e+11
# 3014           Singapore       HIC  2.991701e+11
# 3462              Uganda       LIC  2.748306e+10
# 3467              Uganda       LIC  2.748306e+10
# 3468              Uganda       LIC  2.748306e+10
#
#       population_population_number_of_people  \
# 538                                 686958.0
# 905                               10528394.0
# 911                               10528394.0
# 913                               10528394.0
# 918                               40606052.0
# ...                                      ...
# 3013                               5607283.0
# 3014                               5607283.0
# 3462                              35093648.0
# 3467                              35093648.0
# 3468                              35093648.0
#
#       waste_collection_coverage_rural_percent_of_households  \
# 538                                                 0.0
# 905                                                 0.0
# 911                                                 0.0
# 913                                                 0.0
# 918                                                 0.0
# ...                                                 ...
# 3013                                                0.0
# 3014                                                0.0
# 3462                                                0.0
# 3467                                                0.0
# 3468                                                0.0
#
#       waste_collection_coverage_rural_percent_of_population  \
# 538                                                 0.0
# 905                                                 0.0
# 911                                                 0.0
# 913                                                 0.0
# 918                                                87.5
# ...                                                 ...
# 3013                                                0.0
# 3014                                                0.0
# 3462                                                0.0
# 3467                                                0.0
# 3468                                                0.0
#
#       waste_collection_coverage_rural_percent_of_waste  \
# 538                                                0.0
# 905                                                0.0
# 911                                                0.0
# 913                                                0.0
# 918                                                0.0
# ...                                                ...
# 3013                                               0.0
# 3014                                               0.0
# 3462                                               0.0
# 3467                                               0.0
# 3468                                               0.0
#
#       waste_collection_coverage_total_percent_of_geographic_area  \
# 538                                                 0.0
# 905                                                 0.0
# 911                                                 0.0
# 913                                                 0.0
# 918                                                 0.0
# ...                                                 ...
# 3013                                                0.0
# 3014                                                0.0
# 3462                                                0.0
# 3467                                                0.0
# 3468                                                0.0
#
#       waste_collection_coverage_total_percent_of_households  \
# 538                                                 0.0
# 905                                                74.9
# 911                                                74.9
# 913                                                74.9
# 918                                                 0.0
# ...                                                 ...
# 3013                                                0.0
# 3014                                                0.0
# 3462                                                0.0
# 3467                                                0.0
# 3468                                                0.0
#
#       waste_collection_coverage_total_percent_of_population  \
# 538                                                 0.0
# 905                                                 0.0
# 911                                                 0.0
# 913                                                 0.0
# 918                                                 0.0
# ...                                                 ...
# 3013                                              100.0
# 3014                                              100.0
# 3462                                                0.0
# 3467                                                0.0
# 3468                                                0.0
#
#       waste_collection_coverage_total_percent_of_waste  \
# 538                                                0.0
# 905                                                0.0
# 911                                                0.0
# 913                                                0.0
# 918                                                0.0
# ...                                                ...
# 3013                                               0.0
# 3014                                               0.0
# 3462                                              37.5
# 3467                                              37.5
# 3468                                              37.5
#
#       waste_collection_coverage_urban_percent_of_geographic_area  \
# 538                                                 0.0
# 905                                                 0.0
# 911                                                 0.0
# 913                                                 0.0
# 918                                                 0.0
# ...                                                 ...
# 3013                                                0.0
# 3014                                                0.0
# 3462                                                0.0
# 3467                                                0.0
# 3468                                                0.0
#
#       waste_collection_coverage_urban_percent_of_households  \
# 538                                                 0.0
# 905                                                 0.0
# 911                                                 0.0
# 913                                                 0.0
# 918                                                 0.0
# ...                                                 ...
# 3013                                                0.0
# 3014                                                0.0
# 3462                                                0.0
# 3467                                                0.0
# 3468                                                0.0
#
#       waste_collection_coverage_urban_percent_of_population  \
# 538                                                 0.0
# 905                                                 0.0
# 911                                                 0.0
# 913                                                 0.0
# 918                                                87.5
# ...                                                 ...
# 3013                                                0.0
# 3014                                                0.0
# 3462                                                0.0
# 3467                                                0.0
# 3468                                                0.0
#
#       waste_collection_coverage_urban_percent_of_waste
# 538                                               95.0
# 905                                                0.0
# 911                                                0.0
# 913                                                0.0
# 918                                                0.0
# ...                                                ...
# 3013                                               0.0
# 3014                                               0.0
# 3462                                               0.0
# 3467                                               0.0
# 3468                                               0.0
#
# [126 rows x 15 columns]

# %%
waste_treatment = world_group_2017[[
        'country_name', 
        'income_id', 'gdp', 
        'population_population_number_of_people',
        'waste_treatment_anaerobic_digestion_percent',
        'waste_treatment_compost_percent',
        'waste_treatment_controlled_landfill_percent',
        'waste_treatment_incineration_percent',
        'waste_treatment_landfill_unspecified_percent',
        'waste_treatment_open_dump_percent', 'waste_treatment_other_percent',
        'waste_treatment_recycling_percent',
        'waste_treatment_sanitary_landfill_landfill_gas_system_percent',
        'waste_treatment_unaccounted_for_percent']]
waste_treatment.fillna(0)

# Nan values converted to zeros
# Out:
#             country_name income_id           gdp  \
# 538               Bhutan       LMC  2.234759e+09
# 905   Dominican Republic       UMC  7.366413e+10
# 911   Dominican Republic       UMC  7.366413e+10
# 913   Dominican Republic       UMC  7.366413e+10
# 918              Algeria       UMC  1.960348e+11
# ...                  ...       ...           ...
# 3013           Singapore       HIC  2.991701e+11
# 3014           Singapore       HIC  2.991701e+11
# 3462              Uganda       LIC  2.748306e+10
# 3467              Uganda       LIC  2.748306e+10
# 3468              Uganda       LIC  2.748306e+10
#
#       population_population_number_of_people  \
# 538                                 686958.0
# 905                               10528394.0
# 911                               10528394.0
# 913                               10528394.0
# 918                               40606052.0
# ...                                      ...
# 3013                               5607283.0
# 3014                               5607283.0
# 3462                              35093648.0
# 3467                              35093648.0
# 3468                              35093648.0
#
#       waste_treatment_anaerobic_digestion_percent  \
# 538                                           0.0
# 905                                           0.0
# 911                                           0.0
# 913                                           0.0
# 918                                           0.0
# ...                                           ...
# 3013                                          0.0
# 3014                                          0.0
# 3462                                          0.0
# 3467                                          0.0
# 3468                                          0.0
#
#       waste_treatment_compost_percent  \
# 538                              1.39
# 905                              0.00
# 911                              0.00
# 913                              0.00
# 918                              1.00
# ...                               ...
# 3013                             0.00
# 3014                             0.00
# 3462                             0.00
# 3467                             0.00
# 3468                             0.00
#
#       waste_treatment_controlled_landfill_percent  \
# 538                                          98.0
# 905                                           0.0
# 911                                           0.0
# 913                                           0.0
# 918                                           2.0
# ...                                           ...
# 3013                                          0.0
# 3014                                          0.0
# 3462                                          0.0
# 3467                                          0.0
# 3468                                          0.0
#
#       waste_treatment_incineration_percent  \
# 538                                    0.0
# 905                                    0.0
# 911                                    0.0
# 913                                    0.0
# 918                                    0.0
# ...                                    ...
# 3013                                  37.0
# 3014                                  37.0
# 3462                                   0.0
# 3467                                   0.0
# 3468                                   0.0
#
#       waste_treatment_landfill_unspecified_percent  \
# 538                                            0.0
# 905                                            0.0
# 911                                            0.0
# 913                                            0.0
# 918                                            0.0
# ...                                            ...
# 3013                                           2.0
# 3014                                           2.0
# 3462                                           0.0
# 3467                                           0.0
# 3468                                           0.0
#
#       waste_treatment_open_dump_percent  waste_treatment_other_percent  \
# 538                            0.000000                            0.0
# 905                           72.575831                            0.0
# 911                           72.575831                            0.0
# 913                           72.575831                            0.0
# 918                            0.000000                            0.0
# ...                                 ...                            ...
# 3013                           0.000000                            0.0
# 3014                           0.000000                            0.0
# 3462                          87.000000                            0.0
# 3467                          87.000000                            0.0
# 3468                          87.000000                            0.0
#
#       waste_treatment_recycling_percent  \
# 538                                0.86
# 905                                8.20
# 911                                8.20
# 913                                8.20
# 918                                8.00
# ...                                 ...
# 3013                              61.00
# 3014                              61.00
# 3462                               6.00
# 3467                               6.00
# 3468                               6.00
#
#       waste_treatment_sanitary_landfill_landfill_gas_system_percent  \
# 538                                                 0.0
# 905                                                 0.1
# 911                                                 0.1
# 913                                                 0.1
# 918                                                89.0
# ...                                                 ...
# 3013                                                0.0
# 3014                                                0.0
# 3462                                                7.0
# 3467                                                7.0
# 3468                                                7.0
#
#       waste_treatment_unaccounted_for_percent
# 538                                  0.000000
# 905                                 19.124169
# 911                                 19.124169
# 913                                 19.124169
# 918                                  0.000000
# ...                                       ...
# 3013                                 0.000000
# 3014                                 0.000000
# 3462                                 0.000000
# 3467                                 0.000000
# 3468                                 0.000000
#
# [126 rows x 14 columns]
