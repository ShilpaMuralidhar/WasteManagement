# %%
import pandas as pd
import json
#from IPython.display import display
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

from pandas.io.json import json_normalize
pd.set_option('display.max_columns', None)

# %%
#country_code = "/Users/shilpa/Downloads/opendata-export.json"
#country_code_df = pd.read_json('/Users/shilpa/Downloads/opendata-export.json', lines = True)
#df = pd.DataFrame.from_dict(country_code_df, orient='columns')
#df

# %%
# Load the data. This gives 2 columns Trashpoints, Trashpoints_total

with open('/Users/shilpa/Downloads/opendata-export.json') as data_file:    
    data = json.load(data_file)  
df.shape
# Out:
# (283369, 30)

# %%
# Normalize the data to uncover all columns. 
df = json_normalize(data, 'trashpoints', 'trashpoints_total')

# df[df['country'] == 'Russia'] allows to search based on specific values in a column
df[df['country'] == 'Russia']
# Out:
#                             admin_area                   admin_sub_area  \
# 3                 Respublika Tatarstan             Menzelinsky District
# 29                    Tverskaya oblast                      Gorod Tver'
# 102             Arkhangel'skaya oblast                gorod Arkhangelsk
# 330                    Orenburg Oblast        Krasnogvardeysky District
# 485                   Astrakhan Oblast                             None
# 490              Astrakhanskaya oblast                 Gorod Astrakhan'
# 491              Astrakhanskaya oblast                 Gorod Astrakhan'
# 493                   Astrakhan Oblast                             None
# 643                 Smolenskaya oblast                   Gorod Smolensk
# 794                 Stavropolskiy kray                 Gorod Stavropol'
# 831                  Irkutskaya oblast                          Angarsk
# 924                   Leningrad Oblast                             None
# ...
