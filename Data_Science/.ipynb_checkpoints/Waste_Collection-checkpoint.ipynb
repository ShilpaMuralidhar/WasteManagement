# %%
# %matplotlib notebook

# %%
# %matplotlib notebook
import pandas as pd
#from IPython.display import display
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
country_data = "/Users/shilpa/Desktop/Boringppl_project/WasteManagement/Data/country_level_data_0.csv"
country_data_df = pd.read_csv(country_data, encoding = 'utf-8')
country_data_df.head(1)
# Out:
#   iso3c region_id country_name income_id  gdp  \
# 0   ABW       LCN        Aruba       HIC  NaN
#
#    composition_food_organic_waste_percent  composition_glass_percent  \
# 0                                     NaN                        NaN
#
#    composition_metal_percent  composition_other_percent  \
# 0                        NaN                        NaN
#
#    composition_paper_cardboard_percent  ...  \
# 0                                  NaN  ...
#
#    waste_treatment_controlled_landfill_percent  \
# 0                                          NaN
#
#    waste_treatment_incineration_percent  \
# 0                                   NaN
#
#    waste_treatment_landfill_unspecified_percent  \
# 0                                           NaN
#
#    waste_treatment_open_dump_percent waste_treatment_other_percent  \
# 0                                NaN                           NaN
#
#   waste_treatment_recycling_percent  \
# 0                              11.0
#
#   waste_treatment_sanitary_landfill_landfill_gas_system_percent  \
# 0                                                NaN
#
#   waste_treatment_unaccounted_for_percent  \
# 0                                    89.0
#
#   waste_treatment_waterways_marine_percent  where_where_is_this_data_measured
# 0                                      NaN                                NaN
#
# [1 rows x 51 columns]

# %%
Collection = country_data_df[['country_name', 
                       'income_id', 
                       'gdp', 
                       'population_population_number_of_people', 
                       'total_msw_total_msw_generated_tons_year',
                       'waste_collection_coverage_rural_percent_of_geographic_area',
                       'waste_collection_coverage_rural_percent_of_households',
                       'waste_collection_coverage_rural_percent_of_population',
                       'waste_collection_coverage_rural_percent_of_waste',
                       'waste_collection_coverage_total_percent_of_geographic_area',
                       'waste_collection_coverage_total_percent_of_households',
                       'waste_collection_coverage_total_percent_of_population',
                       'waste_collection_coverage_total_percent_of_waste',
                       'waste_collection_coverage_urban_percent_of_geographic_area',
                       'waste_collection_coverage_urban_percent_of_households',
                       'waste_collection_coverage_urban_percent_of_population',
                       'waste_collection_coverage_urban_percent_of_waste']]
Collection.fillna(0).set_index('country_name')
# Out:
#              income_id           gdp  population_population_number_of_people  \
# country_name
# Aruba              HIC  0.000000e+00                                103187.0
# Afghanistan        LIC  2.141361e+10                              34656032.0
# Angola             LMC  1.030423e+11                              25096150.0
#
#               total_msw_total_msw_generated_tons_year  \
# country_name
# Aruba                                    8.813202e+04
# Afghanistan                              5.628525e+06
# Angola                                   4.213644e+06
#
#               waste_collection_coverage_rural_percent_of_geographic_area  \
# country_name
# Aruba                                                       0.0
# Afghanistan                                                 0.0
# Angola                                                      0.0
#
#               waste_collection_coverage_rural_percent_of_households  \
# country_name
# Aruba                                                       0.0
# Afghanistan                                                 0.0
# Angola                                                      0.0
#
#               waste_collection_coverage_rural_percent_of_population  \
# country_name
# Aruba                                                       0.0
# Afghanistan                                                 0.0
# Angola                                                      0.0
#
#               waste_collection_coverage_rural_percent_of_waste  \
# country_name
# Aruba                                                      0.0
# Afghanistan                                                0.0
# Angola                                                     0.0
#
#               waste_collection_coverage_total_percent_of_geographic_area  \
# country_name
# Aruba                                                       0.0
# Afghanistan                                                 0.0
# Angola                                                      0.0
#
#               waste_collection_coverage_total_percent_of_households  \
# country_name
# Aruba                                                       0.0
# Afghanistan                                                 0.0
# Angola                                                      0.0
#
#               waste_collection_coverage_total_percent_of_population  \
# country_name
# Aruba                                                       0.0
# Afghanistan                                                 0.0
# Angola                                                     23.1
#
#               waste_collection_coverage_total_percent_of_waste  \
# country_name
# Aruba                                                      0.0
# Afghanistan                                                0.0
# Angola                                                     0.0
#
#               waste_collection_coverage_urban_percent_of_geographic_area  \
# country_name
# Aruba                                                       0.0
# Afghanistan                                                 0.0
# Angola                                                      0.0
#
#               waste_collection_coverage_urban_percent_of_households  \
# country_name
# Aruba                                                       0.0
# Afghanistan                                                 0.0
# Angola                                                      0.0
#
#               waste_collection_coverage_urban_percent_of_population  \
# country_name
# Aruba                                                       0.0
# Afghanistan                                                 0.0
# Angola                                                      0.0
#
#               waste_collection_coverage_urban_percent_of_waste
# country_name
# Aruba                                                      0.0
# Afghanistan                                                0.0
# Angola                                                     0.0

# %%
waste_collected_HIC = Collection.groupby('income_id').get_group('HIC').fillna(0).drop_duplicates().set_index('country_name')
waste_collected_HIC.columns
# Out:
# Index(['income_id', 'gdp', 'population_population_number_of_people',
#        'total_msw_total_msw_generated_tons_year',
#        'waste_collection_coverage_rural_percent_of_geographic_area',
#        'waste_collection_coverage_rural_percent_of_households',
#        'waste_collection_coverage_rural_percent_of_population',
#        'waste_collection_coverage_rural_percent_of_waste',
#        'waste_collection_coverage_total_percent_of_geographic_area',
#        'waste_collection_coverage_total_percent_of_households',
#        'waste_collection_coverage_total_percent_of_population',
#        'waste_collection_coverage_total_percent_of_waste',
#        'waste_collection_coverage_urban_percent_of_geographic_area',
#        'waste_collection_coverage_urban_percent_of_households',
#        'waste_collection_coverage_urban_percent_of_population',
#        'waste_collection_coverage_urban_percent_of_waste'],
#       dtype='object')

# %%
HIC_waste_collected = pd.DataFrame(waste_collected_HIC, columns =[
         'waste_collection_coverage_urban_percent_of_geographic_area',
                       'waste_collection_coverage_urban_percent_of_households',
                       'waste_collection_coverage_urban_percent_of_population',
                       'waste_collection_coverage_urban_percent_of_waste'])
HIC_waste_collected.plot.bar(stacked=True);
#plt.legend(loc='center left',bbox_to_anchor=(1.0, 0.5))
plt.show()
plt.tight_layout()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# Prepare Data
df_raw = pd.read_csv("/Users/shilpa/Desktop/Boringppl_project/WasteManagement/Data/country_level_data_0.csv")
df = df_raw[['waste_collection_coverage_urban_percent_of_waste', 'income_id']].groupby('country_name').apply(lambda x: x.mean())
df.sort_values('waste_collection_coverage_urban_percent_of_waste', inplace=True)
df.reset_index(inplace=True)

# Draw plot
import matplotlib.patches as patches

fig, ax = plt.subplots(figsize=(16,10), facecolor='white', dpi= 80)
ax.vlines(x=df.index, ymin=0, ymax=df.waste_collection_coverage_urban_percent_of_waste, color='firebrick', alpha=0.7, linewidth=20)

# Annotate Text
for i, c in enumerate(df.waste_collection_coverage_urban_percent_of_waste):
    ax.text(i, waste_collection_coverage_urban_percent_of_waste+0.5, round(waste_collection_coverage_urban_percent_of_waste, 1), horizontalalignment='center')


# Title, Label, Ticks and Ylim
ax.set_title('Bar Chart for Highway Mileage', fontdict={'size':22})
ax.set(ylabel='Miles Per Gallon', ylim=(0, 30))
plt.xticks(df.index, df.waste_collection_coverage_urban_percent_of_waste.str.upper(), rotation=60, horizontalalignment='right', fontsize=12)

# Add patches to color the X axis labels
p1 = patches.Rectangle((.57, -0.005), width=.33, height=.13, alpha=.1, facecolor='green', transform=fig.transFigure)
p2 = patches.Rectangle((.124, -0.005), width=.446, height=.13, alpha=.1, facecolor='red', transform=fig.transFigure)
fig.add_artist(p1)
fig.add_artist(p2)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1280">
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-27-2fd02561e4a6> in <module>
#      13 # Annotate Text
#      14 for i, c in enumerate(df.waste_collection_coverage_urban_percent_of_waste):
# ---> 15     ax.text(i, waste_collection_coverage_urban_percent_of_waste+0.5, round(waste_collection_coverage_urban_percent_of_waste, 1), horizontalalignment='center')
#      16
#      17
#
# NameError: name 'waste_collection_coverage_urban_percent_of_waste' is not defined
