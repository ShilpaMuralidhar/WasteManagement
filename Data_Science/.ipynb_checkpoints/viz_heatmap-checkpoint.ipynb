# %%
# %matplotlib notebook
import pandas as pd
#from IPython.display import display
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
country_data = "/Users/shilpa/Desktop/Boringppl_project/WasteManagement/Data/country_level_data_0.csv"
country_data_df = pd.read_csv(country_data, encoding = 'utf-8')
country_data_df
# Out:
#     iso3c region_id                    country_name income_id           gdp  \
# 0     ABW       LCN                           Aruba       HIC           NaN
# 1     AFG       SAS                     Afghanistan       LIC  2.141361e+10
# 2     AGO       SSF                          Angola       LMC  1.030423e+11
# 3     ALB       ECS                         Albania       UMC  1.347108e+10
# 4     AND       ECS                         Andorra       HIC  3.319880e+09
# 5     ARE       MEA            United Arab Emirates       HIC  3.842225e+11
# 6     ARG       LCN                       Argentina       HIC  4.475178e+11
# 7     ARM       ECS                         Armenia       UMC  1.150200e+10
# 8     ASM       EAS                  American Samoa       UMC  5.345551e+08
# 9     ATG       LCN             Antigua and Barbuda       HIC  1.344374e+09
# 10    AUS       EAS                       Australia       HIC  1.349305e+12
# 11    AUT       ECS                         Austria       HIC  4.200405e+11
# 12    AZE       ECS                      Azerbaijan       UMC  5.719553e+10
# 13    BDI       SSF                         Burundi       LIC  2.297241e+09
# 14    BEL       ECS                         Belgium       HIC  5.151026e+11
# 15    BEN       SSF                           Benin       LIC  9.102277e+09
# 16    BFA       SSF                    Burkina Faso       LIC  1.238052e+10
# 17    BGD       SAS                      Bangladesh       LMC  1.677713e+11
# 18    BGR       ECS                        Bulgaria       UMC  5.679241e+10
# 19    BHR       MEA                         Bahrain       HIC  3.176906e+10
# 20    BHS       LCN                    Bahamas, The       HIC  1.034380e+10
# 21    BIH       ECS          Bosnia and Herzegovina       UMC  1.892970e+10
# 22    BLR       ECS                         Belarus       UMC  5.918702e+10
# 23    BLZ       LCN                          Belize       UMC  1.602672e+09
# 24    BMU       NAC                         Bermuda       HIC           NaN
# 25    BOL       LCN                         Bolivia       LMC  2.675834e+10
# 26    BRA       LCN                          Brazil       UMC  2.256907e+12
# 27    BRB       LCN                        Barbados       HIC  4.637856e+09
# 28    BRN       EAS               Brunei Darussalam       HIC  1.330146e+10
# 29    BTN       SAS                          Bhutan       LMC  2.234759e+09
# ..    ...       ...                             ...       ...           ...
# 187   TCD       SSF                            Chad       LIC  1.264261e+10
# 188   TGO       SSF                            Togo       LIC  4.264876e+09
# 189   THA       EAS                        Thailand       UMC  4.070147e+11
# 190   TJK       ECS                      Tajikistan       LIC  8.458801e+09
# 191   TKM       ECS                    Turkmenistan       UMC  3.956338e+10
# 192   TLS       EAS                     Timor-Leste       LMC  3.765075e+09
# 193   TON       EAS                           Tonga       UMC  4.062377e+08
# 194   TTO       LCN             Trinidad and Tobago       HIC  2.151994e+10
# 195   TUN       MEA                         Tunisia       LMC  4.868206e+10
# 196   TUR       ECS                          Turkey       UMC  1.122512e+12
# 197   TUV       EAS                          Tuvalu       UMC  3.921616e+07
# 198   TWN       EAS                             NaN       HIC           NaN
# 199   TZA       SSF                        Tanzania       LIC  4.677526e+10
# 200   UGA       SSF                          Uganda       LIC  2.748306e+10
# 201   UKR       ECS                         Ukraine       LMC  1.240002e+11
# 202   URY       LCN                         Uruguay       HIC  4.836293e+10
# 203   USA       NAC                   United States       HIC  1.692033e+13
# 204   UZB       ECS                      Uzbekistan       LMC  6.246909e+10
# 205   VCT       LCN  St. Vincent and the Grenadines       UMC  7.292649e+08
# 206   VEN       LCN                   Venezuela, RB       UMC           NaN
# 207   VGB       LCN          British Virgin Islands       HIC           NaN
# 208   VIR       LCN           Virgin Islands (U.S.)       HIC           NaN
# 209   VNM       EAS                         Vietnam       LMC  1.641049e+11
# 210   VUT       EAS                         Vanuatu       LMC  7.770523e+08
# 211   WSM       EAS                           Samoa       UMC  7.380417e+08
# 212   XKX       ECS                          Kosovo       LMC  7.129272e+09
# 213   YEM       MEA                     Yemen, Rep.       LIC  1.192703e+10
# 214   ZAF       SSF                    South Africa       UMC  4.212087e+11
# 215   ZMB       SSF                          Zambia       LMC  2.703717e+10
# 216   ZWE       SSF                        Zimbabwe       LIC  1.481899e+10
#
#      composition_food_organic_waste_percent  composition_glass_percent  \
# 0                                       NaN                        NaN
# 1                                       NaN                        NaN
# 2                                 51.800000                   6.700000
# 3                                 51.400000                   4.500000
# 4                                 31.200000                   8.200000
# 5                                 39.000000                   4.000000
# 6                                 38.740000                   3.160000
# 7                                 57.000000                   3.200000
# 8                                 19.700000                   3.400000
# 9                                 46.000000                   7.000000
# 10                                48.440000                   3.810000
# 11                                31.400000                   7.000000
# 12                                45.190000                   5.280000
# 13                                81.000000                   2.900000
# 14                                14.180000                   3.100000
# 15                                52.100000                   1.600000
# 16                                21.000000                   1.000000
# 17                                80.580000                   0.440000
# 18                                24.350000                   5.830000
# 19                                59.100000                   3.400000
# 20                                46.000000                   7.000000
# 21                                      NaN                        NaN
# 22                                30.000000                   8.000000
# 23                                47.000000                   8.000000
# 24                                17.000000                   9.000000
# 25                                55.196911                   2.903475
# 26                                51.400000                   2.400000
# 27                                18.300000                   3.700000
# 28                                36.000000                   3.000000
# 29                                58.000000                   4.000000
# ..                                      ...                        ...
# 187                               70.000000                   1.000000
# 188                               38.000000                   2.000000
# 189                               65.520000                   3.040000
# 190                                     NaN                        NaN
# 191                               16.180000                   4.640000
# 192                               43.600000                   5.500000
# 193                               51.300000                   5.900000
# 194                               27.150000                  10.150000
# 195                               68.000000                   2.000000
# 196                               64.000000                   2.000000
# 197                               43.600000                   5.500000
# 198                               23.340000                   4.110000
# 199                                     NaN                        NaN
# 200                               74.500000                   0.800000
# 201                               37.000000                   5.000000
# 202                               53.500000                   3.000000
# 203                               14.900000                   4.400000
# 204                               40.000000                   3.000000
# 205                               49.600000                   5.600000
# 206                                     NaN                        NaN
# 207                                6.500000                  18.100000
# 208                               46.000000                   7.000000
# 209                               61.900000                   2.180000
# 210                               73.400000                   5.400000
# 211                               42.600000                   2.200000
# 212                               42.000000                   6.000000
# 213                               65.000000                   1.000000
# 214                               16.381655                   5.200216
# 215                                     NaN                        NaN
# 216                               36.000000                   5.000000
#
#      composition_metal_percent  composition_other_percent  \
# 0                          NaN                        NaN
# 1                          NaN                        NaN
# 2                     4.400000                  11.500000
# 3                     4.800000                  15.210000
# 4                     2.600000                  11.600000
# 5                     3.000000                  10.000000
# 6                     1.840000                  15.360000
# 7                     3.400000                  17.400000
# 8                     7.900000                  25.600000
# 9                     7.000000                  12.000000
# 10                   19.380000                   3.460000
# 11                    4.400000                  18.500000
# 12                    3.490000                  13.730000
# 13                    2.100000                   3.200000
# 14                    1.910000                  40.140000
# 15                    1.600000                  34.300000
# 16                    1.000000                  61.000000
# 17                    0.500000                   8.590000
# 18                    1.980000                  17.930000
# 19                    2.100000                  15.200000
# 20                    7.000000                  12.000000
# 21                         NaN                  92.700000
# 22                    2.000000                  35.000000
# 23                    5.000000                   5.000000
# 24                    6.000000                  26.000000
# 25                    2.501931                  22.702703
# 26                    2.900000                  16.700000
# 27                    4.900000                   5.700000
# 28                    4.000000                  15.000000
# 29                    1.000000                   7.000000
# ..                         ...                        ...
# 187                   2.000000                  18.000000
# 188                   4.000000                  42.000000
# 189                   1.850000                   4.740000
# 190                        NaN                        NaN
# 191                  11.440000                  62.540000
# 192                  10.000000                   9.300000
# 193                   9.000000                   8.900000
# 194                   3.740000                  17.190000
# 195                   4.000000                   5.000000
# 196                   1.000000                  24.000000
# 197                  10.000000                   9.300000
# 198                   3.070000                  14.110000
# 199                        NaN                        NaN
# 200                   0.600000                  10.600000
# 201                   4.000000                  22.000000
# 202                   5.000000                   7.500000
# 203                   9.000000                   3.200000
# 204                   2.000000                  17.500000
# 205                   3.800000                  10.500000
# 206                        NaN                        NaN
# 207                   8.600000                   4.800000
# 208                   7.000000                  12.000000
# 209                   0.580000                  15.180000
# 210                   3.800000                   5.700000
# 211                   8.800000                  19.400000
# 212                   6.000000                  20.000000
# 213                   6.000000                   6.000000
# 214                  16.910461                  45.020646
# 215                        NaN                        NaN
# 216                   6.000000                   3.000000
#
#      composition_paper_cardboard_percent  ...  \
# 0                                    NaN  ...
# 1                                    NaN  ...
# 2                              11.900000  ...
# 3                               9.900000  ...
# 4                              35.100000  ...
# 5                              25.000000  ...
# 6                              13.960000  ...
# 7                               6.700000  ...
# 8                              26.400000  ...
# 9                              15.000000  ...
# 10                             17.300000  ...
# 11                             19.700000  ...
# 12                             10.930000  ...
# 13                              7.300000  ...
# 14                             18.380000  ...
# 15                              3.100000  ...
# 16                              7.000000  ...
# 17                              3.040000  ...
# 18                             14.180000  ...
# 19                             12.800000  ...
# 20                             15.000000  ...
# 21                              4.900000  ...
# 22                              5.000000  ...
# 23                             16.000000  ...
# 24                             29.000000  ...
# 25                              6.501931  ...
# 26                             13.100000  ...
# 27                             19.700000  ...
# 28                             18.000000  ...
# 29                             17.000000  ...
# ..                                   ...  ...
# 187                             3.000000  ...
# 188                             4.000000  ...
# 189                             7.600000  ...
# 190                                  NaN  ...
# 191                                  NaN  ...
# 192                            10.900000  ...
# 193                             7.400000  ...
# 194                            22.600000  ...
# 195                            10.000000  ...
# 196                             6.000000  ...
# 197                            10.900000  ...
# 198                            30.010000  ...
# 199                                  NaN  ...
# 200                             6.000000  ...
# 201                            25.000000  ...
# 202                            20.000000  ...
# 203                            26.600000  ...
# 204                            17.500000  ...
# 205                            22.100000  ...
# 206                                  NaN  ...
# 207                            33.500000  ...
# 208                            15.000000  ...
# 209                             5.200000  ...
# 210                             4.050000  ...
# 211                             7.200000  ...
# 212                             8.000000  ...
# 213                             7.000000  ...
# 214                             9.396918  ...
# 215                                  NaN  ...
# 216                            27.000000  ...
#
#      waste_treatment_controlled_landfill_percent  \
# 0                                            NaN
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# 4                                            NaN
# 5                                            NaN
# 6                                        8.90000
# 7                                            NaN
# 8                                            NaN
# 9                                       98.68000
# 10                                           NaN
# 11                                           NaN
# 12                                           NaN
# 13                                           NaN
# 14                                           NaN
# 15                                           NaN
# 16                                           NaN
# 17                                           NaN
# 18                                           NaN
# 19                                           NaN
# 20                                           NaN
# 21                                       8.55000
# 22                                      76.90000
# 23                                           NaN
# 24                                      12.20000
# 25                                       0.04000
# 26                                      21.88521
# 27                                      90.00000
# 28                                           NaN
# 29                                      98.00000
# ..                                           ...
# 187                                          NaN
# 188                                          NaN
# 189                                          NaN
# 190                                          NaN
# 191                                          NaN
# 192                                          NaN
# 193                                          NaN
# 194                                     12.00000
# 195                                          NaN
# 196                                          NaN
# 197                                          NaN
# 198                                          NaN
# 199                                          NaN
# 200                                          NaN
# 201                                          NaN
# 202                                     61.70000
# 203                                          NaN
# 204                                          NaN
# 205                                          NaN
# 206                                          NaN
# 207                                          NaN
# 208                                          NaN
# 209                                          NaN
# 210                                          NaN
# 211                                     31.00000
# 212                                     66.43000
# 213                                     12.00000
# 214                                     72.00000
# 215                                          NaN
# 216                                          NaN
#
#      waste_treatment_incineration_percent  \
# 0                                     NaN
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4                                   52.10
# 5                                     NaN
# 6                                     NaN
# 7                                     NaN
# 8                                     NaN
# 9                                     NaN
# 10                                   9.77
# 11                                  37.90
# 12                                    NaN
# 13                                    NaN
# 14                                  43.39
# 15                                    NaN
# 16                                    NaN
# 17                                    NaN
# 18                                   2.75
# 19                                    NaN
# 20                                    NaN
# 21                                    NaN
# 22                                    NaN
# 23                                    NaN
# 24                                  67.60
# 25                                    NaN
# 26                                    NaN
# 27                                    NaN
# 28                                    NaN
# 29                                    NaN
# ..                                    ...
# 187                                   NaN
# 188                                   NaN
# 189                                  0.40
# 190                                   NaN
# 191                                   NaN
# 192                                   NaN
# 193                                   NaN
# 194                                   NaN
# 195                                   NaN
# 196                                   NaN
# 197                                   NaN
# 198                                 64.20
# 199                                   NaN
# 200                                   NaN
# 201                                  2.73
# 202                                   NaN
# 203                                 12.80
# 204                                   NaN
# 205                                   NaN
# 206                                   NaN
# 207                                 80.30
# 208                                   NaN
# 209                                   NaN
# 210                                   NaN
# 211                                   NaN
# 212                                   NaN
# 213                                   NaN
# 214                                   NaN
# 215                                   NaN
# 216                                   NaN
#
#      waste_treatment_landfill_unspecified_percent  \
# 0                                             NaN
# 1                                             NaN
# 2                                             NaN
# 3                                             NaN
# 4                                             NaN
# 5                                            9.00
# 6                                             NaN
# 7                                             NaN
# 8                                             NaN
# 9                                             NaN
# 10                                          48.87
# 11                                           2.98
# 12                                            NaN
# 13                                            NaN
# 14                                           0.91
# 15                                            NaN
# 16                                          17.00
# 17                                            NaN
# 18                                          66.22
# 19                                          92.00
# 20                                            NaN
# 21                                            NaN
# 22                                            NaN
# 23                                            NaN
# 24                                            NaN
# 25                                            NaN
# 26                                            NaN
# 27                                            NaN
# 28                                            NaN
# 29                                            NaN
# ..                                            ...
# 187                                           NaN
# 188                                           NaN
# 189                                         27.00
# 190                                           NaN
# 191                                        100.00
# 192                                           NaN
# 193                                         40.00
# 194                                           NaN
# 195                                         70.00
# 196                                           NaN
# 197                                           NaN
# 198                                         34.80
# 199                                           NaN
# 200                                           NaN
# 201                                         94.07
# 202                                           NaN
# 203                                         52.60
# 204                                           NaN
# 205                                         99.91
# 206                                           NaN
# 207                                           NaN
# 208                                           NaN
# 209                                           NaN
# 210                                           NaN
# 211                                           NaN
# 212                                           NaN
# 213                                           NaN
# 214                                           NaN
# 215                                           NaN
# 216                                           NaN
#
#      waste_treatment_open_dump_percent waste_treatment_other_percent  \
# 0                                  NaN                           NaN
# 1                                  NaN                           NaN
# 2                                  NaN                           NaN
# 3                                  NaN                           NaN
# 4                                  NaN                           NaN
# 5                             62.00000                           NaN
# 6                             22.60000                           NaN
# 7                            100.00000                           NaN
# 8                                  NaN                           NaN
# 9                                  NaN                           NaN
# 10                                 NaN                           NaN
# 11                                 NaN                           NaN
# 12                           100.00000                           NaN
# 13                                 NaN                           NaN
# 14                                 NaN                           NaN
# 15                                 NaN                           NaN
# 16                            59.00000                           NaN
# 17                                 NaN                           NaN
# 18                                 NaN                           NaN
# 19                                 NaN                           NaN
# 20                                 NaN                           NaN
# 21                            41.75000                         0.025
# 22                             7.10000                           NaN
# 23                            66.00000                           NaN
# 24                                 NaN                           NaN
# 25                            55.52000                           NaN
# 26                            15.61932                           NaN
# 27                                 NaN                           NaN
# 28                                 NaN                           NaN
# 29                                 NaN                           NaN
# ..                                 ...                           ...
# 187                                NaN                           NaN
# 188                           96.20000                           NaN
# 189                           53.50000                           NaN
# 190                          100.00000                           NaN
# 191                                NaN                           NaN
# 192                                NaN                           NaN
# 193                                NaN                           NaN
# 194                           84.00000                           NaN
# 195                           21.00000                           NaN
# 196                           44.00000                           NaN
# 197                           14.50000                           NaN
# 198                                NaN                         1.000
# 199                           69.00000                        22.600
# 200                           87.00000                           NaN
# 201                                NaN                           NaN
# 202                           17.50000                           NaN
# 203                                NaN                           NaN
# 204                           60.00000                           NaN
# 205                                NaN                         3.600
# 206                                NaN                           NaN
# 207                                NaN                           NaN
# 208                                NaN                           NaN
# 209                                NaN                           NaN
# 210                           11.30000                           NaN
# 211                                NaN                           NaN
# 212                           33.57000                           NaN
# 213                           25.00000                           NaN
# 214                                NaN                           NaN
# 215                                NaN                           NaN
# 216                                NaN                           NaN
#
#     waste_treatment_recycling_percent  \
# 0                            11.00000
# 1                                 NaN
# 2                                 NaN
# 3                                 NaN
# 4                                 NaN
# 5                            20.00000
# 6                             6.00000
# 7                                 NaN
# 8                                 NaN
# 9                                 NaN
# 10                           42.10000
# 11                           25.66000
# 12                                NaN
# 13                                NaN
# 14                           34.30300
# 15                           25.00000
# 16                           12.00000
# 17                                NaN
# 18                           19.03000
# 19                            8.00000
# 20                                NaN
# 21                            0.00097
# 22                           16.00000
# 23                                NaN
# 24                            2.00000
# 25                           12.11000
# 26                            1.40000
# 27                            9.00000
# 28                                NaN
# 29                            0.86000
# ..                                ...
# 187                               NaN
# 188                           2.00000
# 189                          19.10000
# 190                               NaN
# 191                               NaN
# 192                               NaN
# 193                               NaN
# 194                               NaN
# 195                           4.00000
# 196                               NaN
# 197                          15.00000
# 198                               NaN
# 199                               NaN
# 200                           6.00000
# 201                           3.20000
# 202                           8.00000
# 203                          34.60000
# 204                               NaN
# 205                               NaN
# 206                               NaN
# 207                               NaN
# 208                               NaN
# 209                          23.00000
# 210                          37.00000
# 211                          36.00000
# 212                               NaN
# 213                           8.00000
# 214                          28.00000
# 215                               NaN
# 216                          16.00000
#
#     waste_treatment_sanitary_landfill_landfill_gas_system_percent  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# 5                                                  NaN
# 6                                             62.50000
# 7                                                  NaN
# 8                                                  NaN
# 9                                                  NaN
# 10                                                 NaN
# 11                                                 NaN
# 12                                                 NaN
# 13                                                 NaN
# 14                                                 NaN
# 15                                                 NaN
# 16                                                 NaN
# 17                                                 NaN
# 18                                                 NaN
# 19                                                 NaN
# 20                                                 NaN
# 21                                            24.12000
# 22                                                 NaN
# 23                                            34.00000
# 24                                                 NaN
# 25                                            31.93000
# 26                                            53.30547
# 27                                                 NaN
# 28                                            70.00000
# 29                                                 NaN
# ..                                                 ...
# 187                                                NaN
# 188                                                NaN
# 189                                                NaN
# 190                                                NaN
# 191                                                NaN
# 192                                                NaN
# 193                                                NaN
# 194                                                NaN
# 195                                                NaN
# 196                                           54.00000
# 197                                                NaN
# 198                                                NaN
# 199                                                NaN
# 200                                            7.00000
# 201                                                NaN
# 202                                           10.50000
# 203                                                NaN
# 204                                                NaN
# 205                                                NaN
# 206                                                NaN
# 207                                                NaN
# 208                                                NaN
# 209                                                NaN
# 210                                                NaN
# 211                                                NaN
# 212                                                NaN
# 213                                                NaN
# 214                                                NaN
# 215                                                NaN
# 216                                                NaN
#
#     waste_treatment_unaccounted_for_percent  \
# 0                                  89.00000
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                  47.90000
# 5                                       NaN
# 6                                       NaN
# 7                                       NaN
# 8                                       NaN
# 9                                   1.14000
# 10                                      NaN
# 11                                  2.22000
# 12                                      NaN
# 13                                      NaN
# 14                                  2.26000
# 15                                 75.00000
# 16                                 12.00000
# 17                                 94.75000
# 18                                  1.68000
# 19                                      NaN
# 20                                      NaN
# 21                                 25.55403
# 22                                      NaN
# 23                                      NaN
# 24                                      NaN
# 25                                      NaN
# 26                                  7.59000
# 27                                  1.00000
# 28                                 28.00000
# 29                                      NaN
# ..                                      ...
# 187                                     NaN
# 188                                     NaN
# 189                                     NaN
# 190                                     NaN
# 191                                     NaN
# 192                                     NaN
# 193                                60.00000
# 194                                 3.20000
# 195                                     NaN
# 196                                 1.00000
# 197                                70.50000
# 198                                     NaN
# 199                                 8.50000
# 200                                     NaN
# 201                                     NaN
# 202                                 2.30000
# 203                                     NaN
# 204                                40.00000
# 205                                     NaN
# 206                                     NaN
# 207                                19.70000
# 208                                     NaN
# 209                                62.00000
# 210                                51.70000
# 211                                33.00000
# 212                                     NaN
# 213                                47.00000
# 214                                     NaN
# 215                                     NaN
# 216                                84.00000
#
#     waste_treatment_waterways_marine_percent  \
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
# 5                                        NaN
# 6                                        NaN
# 7                                        NaN
# 8                                        NaN
# 9                                        0.1
# 10                                       NaN
# 11                                       NaN
# 12                                       NaN
# 13                                       NaN
# 14                                       NaN
# 15                                       NaN
# 16                                       NaN
# 17                                       NaN
# 18                                       NaN
# 19                                       NaN
# 20                                       NaN
# 21                                       NaN
# 22                                       NaN
# 23                                       NaN
# 24                                       NaN
# 25                                       NaN
# 26                                       NaN
# 27                                       NaN
# 28                                       NaN
# 29                                       NaN
# ..                                       ...
# 187                                      NaN
# 188                                      NaN
# 189                                      NaN
# 190                                      NaN
# 191                                      NaN
# 192                                      NaN
# 193                                      NaN
# 194                                      NaN
# 195                                      NaN
# 196                                      NaN
# 197                                      NaN
# 198                                      NaN
# 199                                      NaN
# 200                                      NaN
# 201                                      NaN
# 202                                      NaN
# 203                                      NaN
# 204                                      NaN
# 205                                      NaN
# 206                                      NaN
# 207                                      NaN
# 208                                      NaN
# 209                                      NaN
# 210                                      NaN
# 211                                      NaN
# 212                                      NaN
# 213                                      8.0
# 214                                      NaN
# 215                                      NaN
# 216                                      NaN
#
#                      where_where_is_this_data_measured
# 0                                                  NaN
# 1                                                Other
# 2                                                  NaN
# 3                                  Some disposal sites
# 4                                                  NaN
# 5                                                  NaN
# 6                                                Other
# 7                                                Other
# 8                                                  NaN
# 9                                        Disposal Site
# 10                                                 NaN
# 11                                                 NaN
# 12                                             Various
# 13                                                 NaN
# 14                                                 NaN
# 15                                                 NaN
# 16                                                 NaN
# 17                                              Source
# 18                                               Other
# 19                                       Disposal Site
# 20                                                 NaN
# 21                                               Other
# 22   At the disposal sites and at the waste generat...
# 23                                                 NaN
# 24                                                 NaN
# 25                                              Source
# 26                                                 NaN
# 27                                       Disposal Site
# 28                                                 NaN
# 29                                              Source
# ..                                                 ...
# 187                                                NaN
# 188                                                NaN
# 189                                                NaN
# 190                                                NaN
# 191                                      Disposal Site
# 192                                                NaN
# 193                                                NaN
# 194                                      Disposal Site
# 195                                      Disposal site
# 196                                                NaN
# 197                                                NaN
# 198                                                NaN
# 199                                                NaN
# 200                                                NaN
# 201                                              Other
# 202                                                NaN
# 203                                                NaN
# 204                                      Disposal site
# 205                                                NaN
# 206                                                NaN
# 207                                                NaN
# 208                                                NaN
# 209                                                NaN
# 210                                                NaN
# 211                                                NaN
# 212                                                NaN
# 213                                              Other
# 214                                                NaN
# 215                                                NaN
# 216                                                NaN
#
# [217 rows x 51 columns]

# %% [markdown]
# # Treatment

# %%
Treatment = country_data_df[['country_name', 
                             'income_id',
                       'waste_treatment_anaerobic_digestion_percent',
                       'waste_treatment_compost_percent',
                       'waste_treatment_controlled_landfill_percent',
                       'waste_treatment_incineration_percent',
                       'waste_treatment_landfill_unspecified_percent',
                       'waste_treatment_open_dump_percent', 
                       'waste_treatment_other_percent',
                       'waste_treatment_recycling_percent',
                       'waste_treatment_sanitary_landfill_landfill_gas_system_percent',
                       'waste_treatment_unaccounted_for_percent',
                       'waste_treatment_waterways_marine_percent']]
Treatment.fillna(0).set_index('country_name').head(3)
# Out:
#              income_id  waste_treatment_anaerobic_digestion_percent  \
# country_name
# Aruba              HIC                                          0.0
# Afghanistan        LIC                                          0.0
# Angola             LMC                                          0.0
#
#               waste_treatment_compost_percent  \
# country_name
# Aruba                                     0.0
# Afghanistan                               0.0
# Angola                                    0.0
#
#               waste_treatment_controlled_landfill_percent  \
# country_name
# Aruba                                                 0.0
# Afghanistan                                           0.0
# Angola                                                0.0
#
#               waste_treatment_incineration_percent  \
# country_name
# Aruba                                          0.0
# Afghanistan                                    0.0
# Angola                                         0.0
#
#               waste_treatment_landfill_unspecified_percent  \
# country_name
# Aruba                                                  0.0
# Afghanistan                                            0.0
# Angola                                                 0.0
#
#               waste_treatment_open_dump_percent  \
# country_name
# Aruba                                       0.0
# Afghanistan                                 0.0
# Angola                                      0.0
#
#               waste_treatment_other_percent  \
# country_name
# Aruba                                   0.0
# Afghanistan                             0.0
# Angola                                  0.0
#
#               waste_treatment_recycling_percent  \
# country_name
# Aruba                                      11.0
# Afghanistan                                 0.0
# Angola                                      0.0
#
#               waste_treatment_sanitary_landfill_landfill_gas_system_percent  \
# country_name
# Aruba                                                       0.0
# Afghanistan                                                 0.0
# Angola                                                      0.0
#
#               waste_treatment_unaccounted_for_percent  \
# country_name
# Aruba                                            89.0
# Afghanistan                                       0.0
# Angola                                            0.0
#
#               waste_treatment_waterways_marine_percent
# country_name
# Aruba                                              0.0
# Afghanistan                                        0.0
# Angola                                             0.0

# %%
Treatment_LIC = Treatment.groupby('income_id').get_group('LIC').fillna(0).drop_duplicates().set_index('country_name')
df1 = Treatment_LIC.sum(axis=0)
df_LIC= pd.DataFrame(df1)

Treatment_LMC = Treatment.groupby('income_id').get_group('LMC').fillna(0).drop_duplicates().set_index('country_name')
df2 = Treatment_LMC.sum(axis=0)
df_LMC= pd.DataFrame(df2)

Treatment_UMC = Treatment.groupby('income_id').get_group('UMC').fillna(0).drop_duplicates().set_index('country_name')
df3 = Treatment_UMC.sum(axis=0)
df_UMC= pd.DataFrame(df3)

Treatment_HIC = Treatment.groupby('income_id').get_group('HIC').fillna(0).drop_duplicates().set_index('country_name')
df4 = Treatment_HIC.sum(axis=0)
df_HIC= pd.DataFrame(df4)

df_Treatment = pd.concat([df_LIC,df_LMC,df_UMC,df_HIC ], axis=1)
df_Treatment.columns=["LIC", "LMC", "UMC", "HIC"]
df_Treatment.index.names = ['Treatment']
df_Treatment

df_Treatment["Total"] = df_Treatment["LIC"] + df_Treatment["LMC"] + df_Treatment["UMC"] + df_Treatment["HIC"]
df_world = df_Treatment.drop(['income_id'])
df_world["Total"] = df_world["Total"].astype(float)
df_world["Prop_LIC"] = ((df_world["LIC"] / df_world["Total"]) * 100).astype(float)
df_world["Prop_LMC"] = ((df_world["LMC"] / df_world["Total"]) * 100).astype(float)
df_world["Prop_UMC"] = ((df_world["UMC"]/ df_world["Total"]) * 100).astype(float)
df_world["Prop_HIC"] = ((df_world["HIC"]/ df_world["Total"]) * 100).astype(float)


df=df_world.rename(index = {'waste_treatment_anaerobic_digestion_percent':'Anaerobic digestion',
                      'waste_treatment_compost_percent': 'Compost',
                      'waste_treatment_controlled_landfill_percent': 'Controlled landfill',
                      'waste_treatment_incineration_percent':'Incineration',
                      'waste_treatment_landfill_unspecified_percent':'Landfill unspecified',
                      'waste_treatment_open_dump_percent':'Open dump',
                      'waste_treatment_other_percent':'Other',
                      'waste_treatment_recycling_percent':'Recycling',
                      'waste_treatment_sanitary_landfill_landfill_gas_system_percent':'Sanitary & landfill & gas',
                      'waste_treatment_unaccounted_for_percent':'Unaccounted',
                      'waste_treatment_waterways_marine_percent':'Waterways & marine'})
df.reset_index()
a = df.drop(['LIC', 'LMC', 'UMC', 'HIC', 'Total'], axis=1)
a.rename(columns = {'Prop_LIC':'LIC', 'Prop_LMC':'LMC', 'Prop_UMC':'UMC', 'Prop_HIC':'HIC'}, inplace = True)
Transposed_Treatment = a.T
Transposed_Treatment
# Out:
# Treatment  Anaerobic digestion    Compost  Controlled landfill  Incineration  \
# LIC                        0.0   1.747421             1.489673      0.000000
# LMC                        0.0  10.939906            21.302216      0.200022
# UMC                       75.0  13.276427            40.932693      3.059675
# HIC                       25.0  74.036245            36.275418     96.740303
#
# Treatment  Landfill unspecified  Open dump      Other  Recycling  \
# LIC                    2.455136  23.154665  11.876520   4.011004
# LMC                   13.989960  30.008735  56.058385  10.903988
# UMC                   28.922494  35.619726  18.351188  13.918786
# HIC                   54.632410  11.216874  13.713906  71.166222
#
# Treatment  Sanitary & landfill & gas  Unaccounted  Waterways & marine
# LIC                         0.563618    22.370416            5.259698
# LMC                        14.310267    27.444833           53.254438
# UMC                        57.615910    23.347902           41.420118
# HIC                        27.510205    26.836849            0.065746

# %%
df_total = Treatment.fillna(0).drop_duplicates().sum(axis=0) #.sum()
a = pd.DataFrame(df_total)
Total = a[0].sum()
Total

df_LIC = Treatment.groupby('income_id').get_group('LIC').fillna(0).drop_duplicates().sum(axis=0).drop(['country_name','income_id'], axis=0)
Total_LIC= pd.DataFrame(df_LIC)
Treatment_LIC = Total_LIC[0].sum()
percentLIC = Treatment_LIC / Total *100
percentLIC

df_LMC = Treatment.groupby('income_id').get_group('LMC').fillna(0).drop_duplicates().sum(axis=0).drop(['country_name','income_id'], axis=0)
Total_LMC= pd.DataFrame(df_LMC)
Treatment_LMC = Total_LMC[0].sum()
percentLMC = Treatment_LMC / Total *100
percentLMC

df_UMC = Treatment.groupby('income_id').get_group('UMC').fillna(0).drop_duplicates().sum(axis=0).drop(['country_name','income_id'], axis=0)
Total_UMC= pd.DataFrame(df_UMC)
Treatment_UMC = Total_UMC[0].sum()
percentUMC = Treatment_UMC / Total *100
percentUMC

df_HIC = Treatment.groupby('income_id').get_group('HIC').fillna(0).drop_duplicates().sum(axis=0)#.drop(['country_name','income_id'], axis=0)
Total_HIC= pd.DataFrame(df_HIC)
Treatment_HIC = Total_HIC[0].sum()
percentHIC = Treatment_HIC / Total *100
percentHIC

Treatment_percent = [10.35 ,20.16, 28.20, 41.30] 
a = pd.DataFrame(Treatment_percent) 
b = a.T
b.columns = ['LIC', 'LMC', 'UMC', 'HIC']
b.index =['Treatment']
b
# Out:
#              LIC    LMC   UMC   HIC
# Treatment  10.35  20.16  28.2  41.3

# %% [markdown]
# # Total MSW

# %%
Total_MSW = country_data_df[['country_name', 
                       'income_id', 
                       #'gdp', 
                       'population_population_number_of_people', 
                       'total_msw_total_msw_generated_tons_year']]
Total_MSW.fillna(0).set_index('country_name').head(3)
# Out:
#              income_id  population_population_number_of_people  \
# country_name
# Aruba              HIC                                103187.0
# Afghanistan        LIC                              34656032.0
# Angola             LMC                              25096150.0
#
#               total_msw_total_msw_generated_tons_year
# country_name
# Aruba                                    8.813202e+04
# Afghanistan                              5.628525e+06
# Angola                                   4.213644e+06

# %%
# rate of MSW generation per day = total_msw_total_msw_generated_tons_year / 365

#MSW['rate_per_day_kgs'] = MSW['total_msw_total_msw_generated_tons_year'] / 365
Total_MSW['msw_per_day'] =  Total_MSW['total_msw_total_msw_generated_tons_year'] / 365
Total_MSW['msw_per_day_per_person'] =  Total_MSW['total_msw_total_msw_generated_tons_year'] / Total_MSW["population_population_number_of_people"]
Total_MSW
# Out:
# <ipython-input-7-097f24fa3491>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   Total_MSW['msw_per_day'] =  Total_MSW['total_msw_total_msw_generated_tons_year'] / 365
# <ipython-input-7-097f24fa3491>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   Total_MSW['msw_per_day_per_person'] =  Total_MSW['total_msw_total_msw_generated_tons_year'] / Total_MSW["population_population_number_of_people"]
#                        country_name income_id  \
# 0                             Aruba       HIC
# 1                       Afghanistan       LIC
# 2                            Angola       LMC
# 3                           Albania       UMC
# 4                           Andorra       HIC
# 5              United Arab Emirates       HIC
# 6                         Argentina       HIC
# 7                           Armenia       UMC
# 8                    American Samoa       UMC
# 9               Antigua and Barbuda       HIC
# 10                        Australia       HIC
# 11                          Austria       HIC
# 12                       Azerbaijan       UMC
# 13                          Burundi       LIC
# 14                          Belgium       HIC
# 15                            Benin       LIC
# 16                     Burkina Faso       LIC
# 17                       Bangladesh       LMC
# 18                         Bulgaria       UMC
# 19                          Bahrain       HIC
# 20                     Bahamas, The       HIC
# 21           Bosnia and Herzegovina       UMC
# 22                          Belarus       UMC
# 23                           Belize       UMC
# 24                          Bermuda       HIC
# 25                          Bolivia       LMC
# 26                           Brazil       UMC
# 27                         Barbados       HIC
# 28                Brunei Darussalam       HIC
# 29                           Bhutan       LMC
# ..                              ...       ...
# 187                            Chad       LIC
# 188                            Togo       LIC
# 189                        Thailand       UMC
# 190                      Tajikistan       LIC
# 191                    Turkmenistan       UMC
# 192                     Timor-Leste       LMC
# 193                           Tonga       UMC
# 194             Trinidad and Tobago       HIC
# 195                         Tunisia       LMC
# 196                          Turkey       UMC
# 197                          Tuvalu       UMC
# 198                             NaN       HIC
# 199                        Tanzania       LIC
# 200                          Uganda       LIC
# 201                         Ukraine       LMC
# 202                         Uruguay       HIC
# 203                   United States       HIC
# 204                      Uzbekistan       LMC
# 205  St. Vincent and the Grenadines       UMC
# 206                   Venezuela, RB       UMC
# 207          British Virgin Islands       HIC
# 208           Virgin Islands (U.S.)       HIC
# 209                         Vietnam       LMC
# 210                         Vanuatu       LMC
# 211                           Samoa       UMC
# 212                          Kosovo       LMC
# 213                     Yemen, Rep.       LIC
# 214                    South Africa       UMC
# 215                          Zambia       LMC
# 216                        Zimbabwe       LIC
#
#      population_population_number_of_people  \
# 0                              1.031870e+05
# 1                              3.465603e+07
# 2                              2.509615e+07
# 3                              2.880703e+06
# 4                              8.243100e+04
# 5                              9.269612e+06
# 6                              4.298152e+07
# 7                              2.906220e+06
# 8                              5.559900e+04
# 9                              9.677700e+04
# 10                             2.378934e+07
# 11                             8.633169e+06
# 12                             9.649341e+06
# 13                             6.741569e+06
# 14                             1.127420e+07
# 15                             5.521763e+06
# 16                             1.811062e+07
# 17                             1.557271e+08
# 18                             7.177991e+06
# 19                             1.425171e+06
# 20                             3.868380e+05
# 21                             3.535961e+06
# 22                             9.489616e+06
# 23                             3.592880e+05
# 24                             6.479800e+04
# 25                             1.072470e+07
# 26                             2.059621e+08
# 27                             2.806010e+05
# 28                             4.231960e+05
# 29                             6.869580e+05
# ..                                      ...
# 187                            1.188720e+07
# 188                            7.228915e+06
# 189                            6.865760e+07
# 190                            8.177809e+06
# 191                            5.366277e+06
# 192                            1.268671e+06
# 193                            1.049510e+05
# 194                            1.328100e+06
# 195                            1.114391e+07
# 196                            7.827147e+07
# 197                            1.109700e+04
# 198                            2.343400e+07
# 199                            4.908300e+07
# 200                            3.509365e+07
# 201                            4.500464e+07
# 202                            3.431552e+06
# 203                            3.185635e+08
# 204                            2.977450e+07
# 205                            1.094550e+05
# 206                            2.989308e+07
# 207                            2.064500e+04
# 208                            1.057840e+05
# 209                            8.693250e+07
# 210                            2.704020e+05
# 211                            1.876650e+05
# 212                            1.801800e+06
# 213                            2.758421e+07
# 214                            5.172935e+07
# 215                            1.426476e+07
# 216                            1.250052e+07
#
#      total_msw_total_msw_generated_tons_year    msw_per_day  \
# 0                               8.813202e+04     241.457580
# 1                               5.628525e+06   15420.617452
# 2                               4.213644e+06   11544.229000
# 3                               1.142964e+06    3131.408219
# 4                               4.300000e+04     117.808219
# 5                               5.413453e+06   14831.379200
# 6                               1.791055e+07   49070.000000
# 7                               4.928000e+05    1350.136986
# 8                               1.898949e+04      52.026000
# 9                               3.058500e+04      83.794521
# 10                              1.334500e+07   36561.643836
# 11                              4.836000e+06   13249.315068
# 12                              2.930349e+06    8028.353425
# 13                              1.872016e+06    5128.810959
# 14                              4.708000e+06   12898.630137
# 15                              6.859360e+05    1879.276740
# 16                              2.575251e+06    7055.482493
# 17                              1.477850e+07   40489.033781
# 18                              3.011000e+06    8249.315068
# 19                              9.519430e+05    2608.062930
# 20                              2.640000e+05     723.287671
# 21                              1.248718e+06    3421.145205
# 22                              4.280000e+06   11726.027397
# 23                              1.013788e+05     277.750220
# 24                              8.200000e+04     224.657534
# 25                              2.219052e+06    6079.594521
# 26                              7.988901e+07  218874.000000
# 27                              1.748154e+05     478.946423
# 28                              2.162532e+05     592.474400
# 29                              1.113141e+05     304.970000
# ..                                       ...            ...
# 187                             1.358851e+06    3722.878164
# 188                             1.109030e+06    3038.439589
# 189                             2.685337e+07   73570.865753
# 190                             1.787400e+06    4896.986301
# 191                             5.000000e+05    1369.863014
# 192                             6.387500e+04     175.000000
# 193                             1.723820e+04      47.227950
# 194                             7.278740e+05    1994.175342
# 195                             2.700000e+06    7397.260274
# 196                             3.128300e+07   85706.849315
# 197                             3.989486e+03      10.930100
# 198                             7.336000e+06   20098.630137
# 199                             9.276995e+06   25416.424658
# 200                             7.045050e+06   19301.506400
# 201                             1.524202e+07   41758.972603
# 202                             1.260140e+06    3452.437010
# 203                             2.580000e+08  706849.315068
# 204                             4.000000e+06   10958.904110
# 205                             3.156135e+04      86.469450
# 206                             9.779093e+06   26792.036000
# 207                             2.109919e+04      57.806000
# 208                             1.465000e+05     401.369863
# 209                             9.570300e+06   26220.000000
# 210                             7.022549e+04     192.398600
# 211                             2.739909e+04      75.066000
# 212                             3.190000e+05     873.972603
# 213                             4.836820e+06   13251.561644
# 214                             1.845723e+07   50567.758904
# 215                             2.608268e+06    7145.939726
# 216                             1.449752e+06    3971.923288
#
#      msw_per_day_per_person
# 0                  0.854100
# 1                  0.162411
# 2                  0.167900
# 3                  0.396766
# 4                  0.521648
# 5                  0.584000
# 6                  0.416704
# 7                  0.169567
# 8                  0.341544
# 9                  0.316036
# 10                 0.560966
# 11                 0.560165
# 12                 0.303684
# 13                 0.277683
# 14                 0.417591
# 15                 0.124224
# 16                 0.142196
# 17                 0.094900
# 18                 0.419477
# 19                 0.667950
# 20                 0.682456
# 21                 0.353148
# 22                 0.451019
# 23                 0.282166
# 24                 1.265471
# 25                 0.206910
# 26                 0.387882
# 27                 0.623004
# 28                 0.511000
# 29                 0.162039
# ..                      ...
# 187                0.114312
# 188                0.153416
# 189                0.391120
# 190                0.218567
# 191                0.093174
# 192                0.050348
# 193                0.164250
# 194                0.548057
# 195                0.242285
# 196                0.399673
# 197                0.359510
# 198                0.313049
# 199                0.189006
# 200                0.200750
# 201                0.338677
# 202                0.367221
# 203                0.809886
# 204                0.134343
# 205                0.288350
# 206                0.327136
# 207                1.022000
# 208                1.384898
# 209                0.110089
# 210                0.259708
# 211                0.146000
# 212                0.177045
# 213                0.175347
# 214                0.356804
# 215                0.182847
# 216                0.115975
#
# [217 rows x 6 columns]

# %%
#Total_MSW['default_rank'] = Total_MSW['msw_per_day_per_person'].rank(ascending = True)
# Total_MSW['default_rank'] = Total_MSW['msw_per_day_per_person']
# Total_MSW

# %%
df_world = Total_MSW
msw_per_person = df_world.drop(['population_population_number_of_people', 
               'total_msw_total_msw_generated_tons_year', 
               'msw_per_day'], axis=1)

# %%
Treatment_LIC = msw_per_person.groupby('income_id').get_group('LIC').fillna(0).drop_duplicates().set_index('country_name')
df1 = Treatment_LIC.median()
msw_LIC= pd.DataFrame(df1)


Treatment_LMC = msw_per_person.groupby('income_id').get_group('LMC').fillna(0).drop_duplicates().set_index('country_name')
df2 = Treatment_LMC.median()
msw_LMC= pd.DataFrame(df2)

Treatment_UMC = msw_per_person.groupby('income_id').get_group('UMC').fillna(0).drop_duplicates().set_index('country_name')
df3 = Treatment_UMC.median()
msw_UMC= pd.DataFrame(df3)

Treatment_HIC = msw_per_person.groupby('income_id').get_group('HIC').fillna(0).drop_duplicates().set_index('country_name')
df4 = Treatment_HIC.median()
msw_HIC= pd.DataFrame(df4)


MSW_per_person = pd.concat([msw_LIC, msw_LMC, msw_UMC, msw_HIC], axis=1)
MSW_per_person.index.names = ['Median waste/Person/day(kgs)']
MSW_per_person.columns=['LIC','LMC', 'UMC', 'HIC']
# MSW_per_person.reset_index(level=0, inplace=True)
# MSW_per_person['Median waste/Person/day(kgs)'] = MSW_per_person['Median waste/Person/day(kgs)'].replace({'msw_per_day_per_person': 'median waste per person'})
# MSW_per_person.set_index(['Median waste/Person/day(kgs)'])

MSW_per_person.reset_index()
Transposed_MSW = MSW_per_person.T
Transposed_MSW
# Out:
# Median waste/Person/day(kgs)  msw_per_day_per_person
# LIC                                         0.160683
# LMC                                         0.170360
# UMC                                         0.304267
# HIC                                         0.521648

# %% [markdown]
# # HeatMap data

# %%
df_corr = pd.concat([Transposed_Treatment ,Transposed_MSW], axis=1)
#df_corr.reset_index()#.columns=["LIC", "LMC", "UMC", "HIC"]

df_corr.index.names = ['Income']
df_corr
# Out:
#         Anaerobic digestion    Compost  Controlled landfill  Incineration  \
# Income
# LIC                     0.0   1.747421             1.489673      0.000000
# LMC                     0.0  10.939906            21.302216      0.200022
# UMC                    75.0  13.276427            40.932693      3.059675
# HIC                    25.0  74.036245            36.275418     96.740303
#
#         Landfill unspecified  Open dump      Other  Recycling  \
# Income
# LIC                 2.455136  23.154665  11.876520   4.011004
# LMC                13.989960  30.008735  56.058385  10.903988
# UMC                28.922494  35.619726  18.351188  13.918786
# HIC                54.632410  11.216874  13.713906  71.166222
#
#         Sanitary & landfill & gas  Unaccounted  Waterways & marine  \
# Income
# LIC                      0.563618    22.370416            5.259698
# LMC                     14.310267    27.444833           53.254438
# UMC                     57.615910    23.347902           41.420118
# HIC                     27.510205    26.836849            0.065746
#
#         msw_per_day_per_person
# Income
# LIC                   0.160683
# LMC                   0.170360
# UMC                   0.304267
# HIC                   0.521648

# %%
df_corr.corr()
# Out:
#                            Anaerobic digestion   Compost  Controlled landfill  \
# Anaerobic digestion                   1.000000  0.098832             0.783523
# Compost                               0.098832  1.000000             0.547272
# Controlled landfill                   0.783523  0.547272             1.000000
# Incineration                          0.029159  0.991265             0.446440
# Landfill unspecified                  0.433092  0.933321             0.805342
# Open dump                             0.405464 -0.794210             0.069000
# Other                                -0.352497 -0.292994            -0.035477
# Recycling                             0.098078  0.999735             0.537298
# Sanitary & landfill & gas             0.970694  0.189963             0.894430
# Unaccounted                          -0.292198  0.545665             0.351628
# Waterways & marine                    0.217789 -0.518219             0.242311
# msw_per_day_per_person                0.388796  0.951626             0.704910
#
#                            Incineration  Landfill unspecified  Open dump  \
# Anaerobic digestion            0.029159              0.433092   0.405464
# Compost                        0.991265              0.933321  -0.794210
# Controlled landfill            0.446440              0.805342   0.069000
# Incineration                   1.000000              0.889395  -0.861813
# Landfill unspecified           0.889395              1.000000  -0.535457
# Open dump                     -0.861813             -0.535457   1.000000
# Other                         -0.368929             -0.288038   0.402116
# Recycling                      0.993637              0.930347  -0.802736
# Sanitary & landfill & gas      0.097341              0.528743   0.394856
# Unaccounted                    0.479330              0.472208  -0.324803
# Waterways & marine            -0.623509             -0.303728   0.838628
# msw_per_day_per_person         0.932009              0.980832  -0.641506
#
#                               Other  Recycling  Sanitary & landfill & gas  \
# Anaerobic digestion       -0.352497   0.098078                   0.970694
# Compost                   -0.292994   0.999735                   0.189963
# Controlled landfill       -0.035477   0.537298                   0.894430
# Incineration              -0.368929   0.993637                   0.097341
# Landfill unspecified      -0.288038   0.930347                   0.528743
# Open dump                  0.402116  -0.802736                   0.394856
# Other                      1.000000  -0.313363                  -0.168005
# Recycling                 -0.313363   1.000000                   0.184130
# Sanitary & landfill & gas -0.168005   0.184130                   1.000000
# Unaccounted                0.638720   0.528236                  -0.060617
# Waterways & marine         0.793501  -0.536946                   0.339444
# msw_per_day_per_person    -0.448590   0.953037                   0.446060
#
#                            Unaccounted  Waterways & marine  \
# Anaerobic digestion          -0.292198            0.217789
# Compost                       0.545665           -0.518219
# Controlled landfill           0.351628            0.242311
# Incineration                  0.479330           -0.623509
# Landfill unspecified          0.472208           -0.303728
# Open dump                    -0.324803            0.838628
# Other                         0.638720            0.793501
# Recycling                     0.528236           -0.536946
# Sanitary & landfill & gas    -0.060617            0.339444
# Unaccounted                   1.000000            0.241814
# Waterways & marine            0.241814            1.000000
# msw_per_day_per_person        0.353949           -0.479380
#
#                            msw_per_day_per_person
# Anaerobic digestion                      0.388796
# Compost                                  0.951626
# Controlled landfill                      0.704910
# Incineration                             0.932009
# Landfill unspecified                     0.980832
# Open dump                               -0.641506
# Other                                   -0.448590
# Recycling                                0.953037
# Sanitary & landfill & gas                0.446060
# Unaccounted                              0.353949
# Waterways & marine                      -0.479380
# msw_per_day_per_person                   1.000000

# %%
# # sns heatmap correlation
 
# plt.figure(figsize=(10,8))

# mask = np.zeros(df_corr.corr().shape, dtype=bool)
# mask[np.triu_indices(len(mask))] = True
# sns.heatmap(df_corr.corr(), vmin = -1, vmax = 1, cmap='BuPu', annot = True, mask = mask)
# # sns.heatmap(df_corr.corr(), mask=df_corr < 1, cbar=False,
# #             annot=True, annot_kws={"weight": "bold"})

# plt.yticks(df_corr.country_name, fontsize=10)
# plt.title("Correlation of waste production / treatment", fontsize = 15)
# plt.xlabel("Waste Management", fontsize = 10)
# plt.ylabel("Countries", fontsize = 10)
# plt.show()

# %%
# sns heatmap correlation
 
plt.figure(figsize=(10,10))

mask = np.zeros(df_corr.corr().shape, dtype=bool)
mask[np.triu_indices(len(mask))] = True
res = sns.heatmap(df_corr.corr(), vmin = -1, vmax = 1, cmap='BuPu', cbar_kws={"shrink": .70}, annot = True, mask = mask, annot_kws={"size": 10})
# sns.heatmap(df_corr.corr(), mask=df_corr < 1, cbar=False,
#             annot=True, annot_kws={"weight": "bold"})


res.set_xticklabels(res.get_xmajorticklabels(), fontsize = 7, rotation = 30, ha='right')
res.set_yticklabels(res.get_ymajorticklabels(), fontsize = 7)
plt.title("Correlation of waste production / treatment", fontsize = 15)
#plt.xlabel("Waste Management", fontsize = 10)
plt.ylabel("Countries", fontsize = 10)
plt.savefig('Correlation.png')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %%
# sns.heatmap(a, cmap='coolwarm')
# midpoint = (a.values.max() - a.values.min()) / 2
# sns.heatmap(a, cmap='coolwarm', center=midpoint, vmin=150, vmax=400, 
#             robust=True, annot=True, annot_kws={'size':16}, cbar=False,
#                 square=True)

# %%
# fig, ax = plt.subplots(figsize=(10,8))
# sns.heatmap(a.corr(), center=0, annot=True, cmap='coolwarm')
# ax.set_title('Multi-Collinearity of Car Attributes')
