# %%
# %matplotlib notebook
import pandas as pd
#from IPython.display import display
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
country_data = "/Users/shilpa/Desktop/Boringppl_project/WasteManagement/Data/country_level_data_0.csv"
country_data_df = pd.read_csv(country_data, encoding = 'utf-8')
#country_data_df.head(1)

# %%
Total_MSW = country_data_df[['country_name', 
                       'income_id', 
                       #'gdp', 
                       'population_population_number_of_people', 
                       'total_msw_total_msw_generated_tons_year']]
Total_MSW.fillna(0).set_index('country_name').head(3)
# Out:
#              income_id  population_population_number_of_people  \
# country_name
# Aruba              HIC                                103187.0
# Afghanistan        LIC                              34656032.0
# Angola             LMC                              25096150.0
#
#               total_msw_total_msw_generated_tons_year
# country_name
# Aruba                                    8.813202e+04
# Afghanistan                              5.628525e+06
# Angola                                   4.213644e+06

# %%
# rate of MSW generation per day = total_msw_total_msw_generated_tons_year / 365

# Use 'total_msw_total_msw_generated_tons_year' column to calculate 'msw/day', 'msw/day/person' 
# and record the data in different columns accordingly

Total_MSW['msw_per_day'] =  Total_MSW['total_msw_total_msw_generated_tons_year'] / 365
Total_MSW['msw_per_day_per_person'] = Total_MSW['total_msw_total_msw_generated_tons_year']\
                                        /Total_MSW["population_population_number_of_people"]
Total_MSW
# Out:
# <ipython-input-4-05839a1561cf>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   Total_MSW['msw_per_day'] =  Total_MSW['total_msw_total_msw_generated_tons_year'] / 365
# <ipython-input-4-05839a1561cf>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   Total_MSW['msw_per_day_per_person'] = Total_MSW['total_msw_total_msw_generated_tons_year']\
#                        country_name income_id  \
# 0                             Aruba       HIC
# 1                       Afghanistan       LIC
# ...

# %%
import joypy
import pandas as pd
from matplotlib import pyplot as plt
from matplotlib import cm
# %matplotlib inline

# Draw Plot
plt.figure(figsize=(7,5), dpi= 10)
fig, axes = joypy.joyplot(Total_MSW, column=['msw_per_day_per_person'], 
                          by="income_id", xlim='msw_per_day_per_person', figsize=(10,4), color=['#0b5394'], alpha=0.4)

# # Decoration
#plt.title('Joy Plot of income in world', fontsize=12)
plt.xlabel('Waste produced per person per day (kgs)')
#plt.xlim(-2.0, 4.5)
plt.savefig('Joyplots.png')
plt.show()
# Out:
# /Users/shilpa/opt/anaconda3/lib/python3.8/site-packages/pandas/plotting/_tools.py:307: MatplotlibDeprecationWarning:
# The rowNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().rowspan.start instead.
#   layout[ax.rowNum, ax.colNum] = ax.get_visible()
# /Users/shilpa/opt/anaconda3/lib/python3.8/site-packages/pandas/plotting/_tools.py:307: MatplotlibDeprecationWarning:
# The colNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().colspan.start instead.
#   layout[ax.rowNum, ax.colNum] = ax.get_visible()
# /Users/shilpa/opt/anaconda3/lib/python3.8/site-packages/pandas/plotting/_tools.py:313: MatplotlibDeprecationWarning:
# The rowNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().rowspan.start instead.
#   if not layout[ax.rowNum + 1, ax.colNum]:
# ...

# %%
# Income_world = country_data_df.income_id.value_counts()

# Income_world.plot.bar(legend=True, stacked=False, rot=0);
# plt.legend(loc='center left',bbox_to_anchor=(1.0, 0.5))
# plt.show()
# plt.tight_layout()

# %% [markdown]
# # The end
