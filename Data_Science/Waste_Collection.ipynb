# %%
# %matplotlib notebook

# %%
# %matplotlib notebook
import pandas as pd
from IPython.display import display
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
country_data = "/Users/shilpa/Desktop/Boringppl_project/WasteManagement/Data/country_level_data_0.csv"
country_data_df = pd.read_csv(country_data, encoding = 'utf-8')
country_data_df.head(1)
# Out:
#   iso3c region_id country_name income_id  gdp  \
# 0   ABW       LCN        Aruba       HIC  NaN
#
#    composition_food_organic_waste_percent  composition_glass_percent  \
# 0                                     NaN                        NaN
#
#    composition_metal_percent  composition_other_percent  \
# 0                        NaN                        NaN
#
#    composition_paper_cardboard_percent  ...  \
# 0                                  NaN  ...
#
#    waste_treatment_controlled_landfill_percent  \
# 0                                          NaN
#
#    waste_treatment_incineration_percent  \
# 0                                   NaN
#
#    waste_treatment_landfill_unspecified_percent  \
# 0                                           NaN
#
#    waste_treatment_open_dump_percent waste_treatment_other_percent  \
# 0                                NaN                           NaN
#
#   waste_treatment_recycling_percent  \
# 0                              11.0
#
# ...

# %%
Collection = country_data_df[['country_name', 
                       'income_id', 
                       'gdp', 
                       'population_population_number_of_people', 
                       'total_msw_total_msw_generated_tons_year',
                       'waste_collection_coverage_rural_percent_of_geographic_area',
                       'waste_collection_coverage_rural_percent_of_households',
                       'waste_collection_coverage_rural_percent_of_population',
                       'waste_collection_coverage_rural_percent_of_waste',
                       'waste_collection_coverage_total_percent_of_geographic_area',
                       'waste_collection_coverage_total_percent_of_households',
                       'waste_collection_coverage_total_percent_of_population',
                       'waste_collection_coverage_total_percent_of_waste',
                       'waste_collection_coverage_urban_percent_of_geographic_area',
                       'waste_collection_coverage_urban_percent_of_households',
                       'waste_collection_coverage_urban_percent_of_population',
                       'waste_collection_coverage_urban_percent_of_waste']]
Collection.fillna(0).set_index('country_name').head(3)
# Out:
#              income_id           gdp  population_population_number_of_people  \
# country_name
# Aruba              HIC  0.000000e+00                                103187.0
# Afghanistan        LIC  2.141361e+10                              34656032.0
# Angola             LMC  1.030423e+11                              25096150.0
#
#               total_msw_total_msw_generated_tons_year  \
# country_name
# Aruba                                    8.813202e+04
# Afghanistan                              5.628525e+06
# Angola                                   4.213644e+06
#
#               waste_collection_coverage_rural_percent_of_geographic_area  \
# country_name
# Aruba                                                       0.0
# Afghanistan                                                 0.0
# Angola                                                      0.0
#
#               waste_collection_coverage_rural_percent_of_households  \
# country_name
# ...

# %%
North_Africa = Collection.loc[country_data_df['country_name'].isin(['Algeria', "Egypt, Arab Rep.", 
              "Libya", "Sudan", "Tunisia"])].set_index('country_name')
North_Africa

West_Africa = Collection.loc[country_data_df['country_name'] .\
            isin(['Benin', "Burkina Faso", "Cape Verde", "Côte d’Ivoire", "Gambia,The", "Ghana", 
                  "Guinea", "Guinea Bissau", "Liberia", "Mali", "Mauritania", "Niger", "Nigeria", 
                  "Senegal", "Sierra Leone","Togo"])].set_index('country_name')

Central_Africa = Collection.loc[country_data_df['country_name'] .\
            isin(['Angola', "Camaroon", "Central African Republic", "Chad", "Congo, Rep.", "Congo, Dem. Rep.", 
                  "Equatorial Guinea", "Gabon", "São Tomé and Príncipe"])].set_index('country_name')

East_Africa = Collection.loc[country_data_df['country_name'] .\
            isin(['Burundi', "Comaros", "Djibouti", "Eritrea", "Ethiopia", "Kenya", "Madagascar", "Malawi", 
                  "Mauritius", "Mozambique", "Rwanda", "Seychelles", "Somalia", "Somaliland", "South Sudan", 
                  "Tanzania", "Uganda", "Zambia", "Zimbabwe"])].set_index('country_name')


Southern_Africa = Collection.loc[country_data_df['country_name'] .\
            isin(['Botswana', "Lesotho", "Namibia", "South Africa", "Swaziland"])].set_index('country_name')

Africa = [North_Africa, West_Africa, Central_Africa, East_Africa, Southern_Africa]
df_Africa = pd.concat(Africa)
df_Africa.fillna(0)
#df_Africa.drop('default_rank', axis=1)
# Out:
#                          income_id           gdp  \
# country_name
# Algeria                        UMC  1.960348e+11
# Egypt, Arab Rep.               LMC  2.608163e+11
# Libya                          UMC  3.680884e+10
# Sudan                          LMC  7.614948e+10
# Tunisia                        LMC  4.868206e+10
# Benin                          LIC  9.102277e+09
# Burkina Faso                   LIC  1.238052e+10
# Côte d’Ivoire                  LMC  3.679647e+10
# Ghana                          LMC  4.819909e+10
# Guinea                         LIC  9.667718e+09
# Liberia                        LIC  1.627047e+09
# Mali                           LIC  1.342182e+10
# Mauritania                     LMC  5.574151e+09
# Niger                          LIC  8.106890e+09
# Nigeria                        LMC  4.567754e+11
# Senegal                        LIC  1.683335e+10
# Sierra Leone                   LIC  3.355385e+09
# Togo                           LIC  4.264876e+09
# ...

# %%
waste_collected_HIC = Collection.groupby('income_id').get_group('LIC').fillna(0).drop_duplicates().set_index('country_name')
waste_collected_HIC.columns
# Out:
# Index(['income_id', 'gdp', 'population_population_number_of_people',
#        'total_msw_total_msw_generated_tons_year',
#        'waste_collection_coverage_rural_percent_of_geographic_area',
#        'waste_collection_coverage_rural_percent_of_households',
#        'waste_collection_coverage_rural_percent_of_population',
#        'waste_collection_coverage_rural_percent_of_waste',
#        'waste_collection_coverage_total_percent_of_geographic_area',
#        'waste_collection_coverage_total_percent_of_households',
#        'waste_collection_coverage_total_percent_of_population',
#        'waste_collection_coverage_total_percent_of_waste',
#        'waste_collection_coverage_urban_percent_of_geographic_area',
#        'waste_collection_coverage_urban_percent_of_households',
#        'waste_collection_coverage_urban_percent_of_population',
#        'waste_collection_coverage_urban_percent_of_waste'],
#       dtype='object')

# %%
# Prepare Data
df_raw = pd.read_csv("/Users/shilpa/Desktop/Boringppl_project/WasteManagement/Data/country_level_data_0.csv")
df = df_raw[['waste_collection_coverage_total_percent_of_waste', 'income_id']].groupby('income_id').apply(lambda x: x.mean())
df.sort_values('waste_collection_coverage_total_percent_of_waste', inplace=True)
df.reset_index(inplace=True)

# Draw plot
import matplotlib.patches as patches

fig, ax = plt.subplots(figsize=(16,10), facecolor='white', dpi= 80)
ax.vlines(x=df.index, ymin=0, ymax=df.waste_collection_coverage_total_percent_of_waste, color='firebrick', alpha=0.7, linewidth=20)

# Annotate Text
for i, w in enumerate(df.waste_collection_coverage_total_percent_of_waste):
    ax.text(i, w+0.5, round(w, 1), horizontalalignment='center')


# Title, Label, Ticks and Ylim
ax.set_title('Bar Chart for Highway Mileage', fontdict={'size':22})
ax.set(ylabel='Miles Per Gallon', ylim=(0, 100))
plt.xticks(df.index, df.income_id.str.upper(), rotation=60, horizontalalignment='right', fontsize=12)

# Add patches to color the X axis labels
p1 = patches.Rectangle((.57, -0.005), width=.33, height=.13, alpha=.1, facecolor='green', transform=fig.transFigure)
p2 = patches.Rectangle((.124, -0.005), width=.446, height=.13, alpha=.1, facecolor='red', transform=fig.transFigure)
fig.add_artist(p1)
fig.add_artist(p2)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1279.9999722567477">

# %%
x = df_Africa.loc[:, ['waste_collection_coverage_total_percent_of_population']]
df_Africa['mpg_z'] = (x - x.mean())/x.std()
df_Africa['colors'] = ['green' if x < 0.5 else 'red' for x in df_Africa['mpg_z']]
df_Africa.sort_values('mpg_z', inplace=True)
df_Africa.reset_index(inplace=True)

# Draw plot
plt.figure(figsize=(14,14), dpi= 80)
plt.hlines(y=df_Africa.country_name, xmin=0, xmax=df_Africa.mpg_z)
for x, y, tex in zip(df_Africa.mpg_z, df_Africa.index, df_Africa.mpg_z):
    t = plt.text(x, y, round(tex, 2), horizontalalignment='right' if x < 0 else 'left', 
                 verticalalignment='center', fontdict={'color':'green' if x < 0 else 'red', 'size':10})
    

# Decorations    
plt.yticks(df_Africa.country_name, fontsize=10)
plt.title('Population-Based Waste collection Ranking in Africa', fontdict={'size':20})
plt.grid(linestyle='--', alpha=0.5)
plt.xlim(-2.0, 4.5)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1119.9999757246542">

# %%
Africa_waste = pd.DataFrame(df_Africa, columns =[
                       'waste_collection_coverage_total_percent_of_population',
                       #'waste_collection_coverage_total_percent_of_waste'
])
Africa_waste.plot.bar(legend=False, stacked=False);
#plt.legend(loc='center left',bbox_to_anchor=(1.0, 0.5))
plt.show()
plt.tight_layout()
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">

# %%
Northern_America = Collection.loc[country_data_df['country_name'].
            isin(['Canada', 'Greenland', 'Mexico', 'United States'])].set_index('country_name')

Caribbean = Collection.loc[country_data_df['country_name'] .\
            isin(['Anguilla', 'Antigua and Barbuda', 'Aruba', 'Bahamas', 'Barbados', 'Bermuda', 
                  'British Virgin Islands', 'Cayman Islands', 'Cuba', 'Curacao', 'Dominica', 'Dominican Republic',
                  'Grenada', 'Guadeloupe', 'Haiti', 'Jamaica', 'Martinique', 'Montserrat', 'Puerto Rico', 
                  'St. Kitts and Nevis', 'St. Lucia', 'St. Vincent and the Grenadines', 
                  'Trinidad and Tobago', 'Virgin Islands (U.S.)'])].set_index('country_name')


Central_America = Collection.loc[country_data_df['country_name'] .\
             isin(['Belize', 'Costa Rica', 'El Salvador', 'Guetamala', 'Honduras', 'Nicaragua', 'Panama'])].set_index('country_name')


South_America = Collection.loc[country_data_df['country_name'] .\
             isin(['Argentina', 'Bolivia', 'Brazil', 'Chile', 'Columbia', 'Eucador', 'French Guiana(France)', 'Guyana',
                  'Paraguay', 'Peru', 'Suriname', 'Uruguay', 'Venezuala'])].set_index('country_name')


Americas = [Northern_America, Caribbean, Central_America, South_America]
df_Americas = pd.concat(Americas)
df_Americas.fillna(0)
#df_Americas.drop('default_rank', axis=1)
# Out:
#                                income_id           gdp  \
# country_name
# Canada                               HIC  1.828002e+12
# Greenland                            HIC  2.823634e+09
# Mexico                               UMC  1.259037e+12
# United States                        HIC  1.692033e+13
# Aruba                                HIC  0.000000e+00
# Antigua and Barbuda                  HIC  1.344374e+09
# Bermuda                              HIC  0.000000e+00
# Barbados                             HIC  4.637856e+09
# Cuba                                 UMC  0.000000e+00
# Curacao                              HIC  0.000000e+00
# Cayman Islands                       HIC  0.000000e+00
# Dominica                             UMC  5.060219e+08
# Dominican Republic                   UMC  7.366413e+10
# Grenada                              UMC  9.311187e+08
# Haiti                                LIC  7.911616e+09
# Jamaica                              UMC  1.380180e+10
# ...

# %%
x = df_Americas.loc[:, ['waste_collection_coverage_total_percent_of_population']]
df_Americas['mpg_z'] = (x - x.mean())/x.std()
df_Americas['colors'] = ['green' if x < 0.5 else 'red' for x in df_Americas['mpg_z']]
df_Americas.sort_values('mpg_z', inplace=True)
df_Americas.reset_index(inplace=True)

# Draw plot
plt.figure(figsize=(14,14), dpi= 80)
plt.hlines(y=df_Americas.country_name, xmin=0, xmax=df_Americas.mpg_z)
for x, y, tex in zip(df_Americas.mpg_z, df_Americas.index, df_Americas.mpg_z):
    t = plt.text(x, y, round(tex, 2), horizontalalignment='right' if x < 0 else 'left', 
                 verticalalignment='center', fontdict={'color':'green' if x < 0 else 'red', 'size':10})
    

# Decorations    
plt.yticks(df_Americas.country_name, fontsize=10)
plt.title('Population-Based Waste collection Ranking in Americas', fontdict={'size':20})
plt.grid(linestyle='--', alpha=0.5)
plt.xlim(-2.0, 4.5)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1119.9999757246542">

# %%
America_waste = pd.DataFrame(df_Americas, columns =[
                       'waste_collection_coverage_total_percent_of_population',
                       #'waste_collection_coverage_total_percent_of_waste'
])
America_waste.plot.bar(legend=False, stacked=False);
#plt.legend(loc='center left',bbox_to_anchor=(1.0, 0.5))
plt.show()
plt.tight_layout()
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">

# %%
North_Asia = Collection.loc[country_data_df['country_name'].isin(['Russia', 'Siberia'])].set_index('country_name')

West_Asia = Collection.loc[country_data_df['country_name'] .\
            isin(['Armenia', 'Azerbaijan', 'Bahrain', 'Cyprus', 'Georgia','Iran', 'Iraq', 'Israel', 
                  'Jordan','Kuwait', 'Lebanon', 'Omar', 'Qatar', 'Saudi Arabia', 'State of Palestine', 
                  'Turkey', 'United Arab Emirates', 'Yemen'])].set_index('country_name')

Central_Asia = Collection.loc[country_data_df['country_name'] .\
            isin(['Afghanistan', 'Khazakstan', 'Kyrgyzstan', 'Tajikistan', 'Turkmenistan', 
                    'Uzbekistan'])].set_index('country_name')

East_Asia = Collection.loc[country_data_df['country_name'] .\
            isin(['China', 'Hong Kong SAR, China', 'Macao SAR, China', 'Japan', 'Korea(North)', 'Korea(South)',
                 'Mongolia', 'Taiwan', 'Korea, Rep.'])].set_index('country_name')


South_Asia = Collection.loc[country_data_df['country_name'] .\
            isin(['Bangladesh', 'Bhutan', 'India', 'Maldives', 'Nepal', 'Pakistan', 'Srilanka'])].set_index('country_name')

Southeast_Asia = Collection.loc[country_data_df['country_name'] .\
            isin(['Brunei Darussalam', 'Cambodia', 'Indonesia', 'Lao PDR', 'Malaysia', 'Myanmar', 'Phillipiness',
                  'Singapore', 'Thailand', 'Timor-Leste', 'Vietnam'])].set_index('country_name')
Southeast_Asia


Asia = [North_Asia, West_Asia, Central_Asia, East_Asia, South_Asia, Southeast_Asia]
df_Asia = pd.concat(Asia)
df_Asia.fillna(0)
#df_Asia.drop('default_rank', axis=1)
# Out:
#                      income_id           gdp  \
# country_name
# United Arab Emirates       HIC  3.842225e+11
# Armenia                    UMC  1.150200e+10
# Azerbaijan                 UMC  5.719553e+10
# Bahrain                    HIC  3.176906e+10
# Cyprus                     HIC  2.431161e+10
# Georgia                    LMC  1.518961e+10
# Iraq                       UMC  2.139375e+11
# Israel                     HIC  2.878076e+11
# Jordan                     UMC  3.081167e+10
# Kuwait                     HIC  1.428573e+11
# Lebanon                    UMC  4.291139e+10
# Qatar                      HIC  1.706626e+11
# Saudi Arabia               HIC  6.900688e+11
# Turkey                     UMC  1.122512e+12
# Afghanistan                LIC  2.141361e+10
# Tajikistan                 LIC  8.458801e+09
# Turkmenistan               UMC  3.956338e+10
# Uzbekistan                 LMC  6.246909e+10
# China                      UMC  9.505157e+12
# ...

# %%
x = df_Asia.loc[:, ['waste_collection_coverage_total_percent_of_population']]
df_Asia['mpg_z'] = (x - x.mean())/x.std()
df_Asia['colors'] = ['green' if x < 0 else 'red' for x in df_Asia['mpg_z']]
df_Asia.sort_values('mpg_z', inplace=True)
df_Asia.reset_index(inplace=True)

# Draw plot
plt.figure(figsize=(14,14), dpi= 80)
plt.hlines(y=df_Asia.country_name, xmin=0, xmax=df_Asia.mpg_z)
for x, y, tex in zip(df_Asia.mpg_z, df_Asia.index, df_Asia.mpg_z):
    t = plt.text(x, y, round(tex, 2), horizontalalignment='right' if x < 0 else 'left', 
                 verticalalignment='center', fontdict={'color':'green' if x < 0 else 'red', 'size':10})
    

# Decorations    
plt.yticks(df_Asia.country_name, fontsize=12)
plt.title('Population-Based Waste collection Ranking in Asia', fontdict={'size':20})
plt.grid(linestyle='--', alpha=0.5)
plt.xlim(-2.0, 4.5)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1119.9999757246542">

# %%
Asia_waste = pd.DataFrame(df_Asia, columns =[
                       'waste_collection_coverage_total_percent_of_population',
                       #'waste_collection_coverage_total_percent_of_waste'
])
Asia_waste.plot.bar(legend=False, stacked=True);
#plt.legend(loc='center left',bbox_to_anchor=(1.0, 0.5))
#plt.yticks(df_Asia.country_name, fontsize=10)
plt.show()
plt.tight_layout()
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">

# %%
Northern_Europe = Collection.loc[country_data_df['country_name'].
            isin(['Denmark', 'Estonia', 'Faroe Islands', 'Finland', 'Greenland', 'Iceland', 'Ireland', 'Latvia', 
                  'Lithuania', 'Norway', 'Sweden', 'United Kingdom'])].set_index('country_name')


### Run these !!!!!!!
Western_Europe = Collection.loc[country_data_df['country_name'] .\
            isin(['Austria', 'Belgium', 'France', 'Germany', 'Liechtenstein', 'Luxembourg', 'Netherlands', 
                   'Switzerland'])].set_index('country_name')


Eastern_Europe = Collection.loc[country_data_df['country_name'] .\
                isin(['Belarus', 'Bulgaria', 'Czech Republic', 'Hungary', 'Moldova', 'Poland', 'Romania',
                 'Russian Federation', 'Slovak Republic', 'Ukraine'])].set_index('country_name')

Southern_Europe = Collection.loc[country_data_df['country_name'] .\
               isin(['Albania', 'Andorra', 'Bosnia and Herzegovina', 'Croatia', 'Cyprus', 'Gibraltar',
                    'Greece', 'Italy', 'Kosovo', 'Macedonia, FYR', 'Malta', 'Monaco', 'Montenegro',
                    'Portugal', 'San Marino', 'Serbia', 'Slovenia', 'Spain', 'Turkey', 'Vatican City State'])].set_index('country_name')

Europe = [Northern_Europe, Western_Europe, Eastern_Europe, Southern_Europe]
df_Europe = pd.concat(Europe)
df_Europe.fillna(0)
#df_Europe.drop('default_rank', axis=1)
# Out:
#                        income_id           gdp  \
# country_name
# Denmark                      HIC  3.475197e+11
# Estonia                      HIC  2.380868e+10
# Finland                      HIC  2.526922e+11
# United Kingdom               HIC  2.757620e+12
# Greenland                    HIC  2.823634e+09
# Ireland                      HIC  3.323614e+11
# Iceland                      HIC  1.643489e+10
# Lithuania                    HIC  4.573544e+10
# Latvia                       HIC  2.887150e+10
# Norway                       HIC  4.727659e+11
# Sweden                       HIC  5.603866e+11
# Austria                      HIC  4.200405e+11
# Belgium                      HIC  5.151026e+11
# Switzerland                  HIC  6.420897e+11
# Germany                      HIC  3.781699e+12
# France                       HIC  2.806036e+12
# Liechtenstein                HIC  0.000000e+00
# Luxembourg                   HIC  6.320726e+10
# Netherlands                  HIC  8.901359e+11
# ...

# %%
x = df_Europe.loc[:, ['waste_collection_coverage_total_percent_of_population']]
df_Europe['mpg_z'] = (x - x.mean())/x.std()
df_Europe['colors'] = ['green' if x < 0 else 'red' for x in df_Europe['mpg_z']]
df_Europe.sort_values('mpg_z', inplace=True)
df_Europe.reset_index(inplace=True)

# Draw plot
plt.figure(figsize=(14,14), dpi= 80)
plt.hlines(y=df_Europe.country_name, xmin=0, xmax=df_Europe.mpg_z)
for x, y, tex in zip(df_Europe.mpg_z, df_Europe.index, df_Europe.mpg_z):
    t = plt.text(x, y, round(tex, 2), horizontalalignment='right' if x < 0 else 'left', 
                 verticalalignment='center', fontdict={'color':'green' if x < 0 else 'red', 'size':10})
    

# Decorations    
plt.yticks(df_Europe.country_name, fontsize=12)
plt.title('Population-Based Waste collection Ranking in Asia', fontdict={'size':20})
plt.grid(linestyle='--', alpha=0.5)
plt.xlim(-2.0, 4.5)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1119.9999757246542">

# %%
Europe_waste = pd.DataFrame(df_Europe, columns =[
                       'waste_collection_coverage_total_percent_of_population',
                       #'waste_collection_coverage_total_percent_of_waste'
])
Europe_waste.plot.bar(legend=False, stacked=True);
#plt.legend(loc='center left',bbox_to_anchor=(1.0, 0.5))
#plt.yticks(df_Asia.country_name, fontsize=10)
plt.show()
plt.tight_layout()
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">

# %%
Australia_NZ = Collection.loc[country_data_df['country_name'].
            isin(['Australia', 'New Zealand'])].set_index('country_name')


Melanesia = Collection.loc[country_data_df['country_name'] .\
            isin(['Fiji', 'New Caledonia', 'Papua New Guinea', 'Solomon Islands', 'Vanuatu'])].set_index('country_name')

Micronesia = Collection.loc[country_data_df['country_name'] .\
              isin(['Guam', 'Kiribati', 'Marshall Islands', 'Micronesia, Fed. Sts.', 'Nauru',
                    'Northern Mariana Islands', 'Palau'])].set_index('country_name')

Polynesia = Collection.loc[country_data_df['country_name'] .\
              isin(['American Samoa', 'Cook Islands', 'Easter Island', 'French Polynesia', 'Hawaii',
                   'Niue', 'Pitcairin', 'Samoa', 'Tonga', 'Tuvalu'])].set_index('country_name')

Oceania= [Australia_NZ, Melanesia, Micronesia, Polynesia]
df_Oceania = pd.concat(Oceania)
df_Oceania.fillna(0)
#df_Oceania.drop('default_rank', axis=1)
# Out:
#                          income_id           gdp  \
# country_name
# Australia                      HIC  1.349305e+12
# New Zealand                    HIC  1.761286e+11
# Fiji                           UMC  3.771168e+09
# New Caledonia                  HIC  0.000000e+00
# Papua New Guinea               LMC  1.938919e+10
# Solomon Islands                LMC  9.008590e+08
# Vanuatu                        LMC  7.770523e+08
# Micronesia, Fed. Sts.          LMC  2.962826e+08
# Guam                           HIC  5.214915e+09
# Kiribati                       LMC  1.928691e+08
# Marshall Islands               UMC  1.790418e+08
# Northern Mariana Islands       HIC  1.051785e+09
# Nauru                          UMC  1.259303e+08
# Palau                          HIC  2.253080e+08
# American Samoa                 UMC  5.345551e+08
# French Polynesia               HIC  0.000000e+00
# Tonga                          UMC  4.062377e+08
# Tuvalu                         UMC  3.921616e+07
# ...

# %%
x = df_Oceania.loc[:, ['waste_collection_coverage_total_percent_of_population']]
df_Oceania['mpg_z'] = (x - x.mean())/x.std()
df_Oceania['colors'] = ['green' if x < 0 else 'red' for x in df_Oceania['mpg_z']]
df_Oceania.sort_values('mpg_z', inplace=True)
df_Oceania.reset_index(inplace=True)

# Draw plot
plt.figure(figsize=(14,14), dpi= 80)
plt.hlines(y=df_Oceania.country_name, xmin=0, xmax=df_Oceania.mpg_z)
for x, y, tex in zip(df_Oceania.mpg_z, df_Oceania.index, df_Oceania.mpg_z):
    t = plt.text(x, y, round(tex, 2), horizontalalignment='right' if x < 0 else 'left', 
                 verticalalignment='center', fontdict={'color':'green' if x < 0 else 'red', 'size':10})
    

# Decorations    
plt.yticks(df_Oceania.country_name, fontsize=12)
plt.title('Population-Based Waste collection Ranking in Asia', fontdict={'size':20})
plt.grid(linestyle='--', alpha=0.5)
plt.xlim(-2.0, 4.5)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-25-925bace0e23d> in <module>
#       3 df_Oceania['colors'] = ['green' if x < 0 else 'red' for x in df_Oceania['mpg_z']]
#       4 df_Oceania.sort_values('mpg_z', inplace=True)
# ----> 5 df_Oceania.reset_index(inplace=True)
#       6
#       7 # Draw plot
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in reset_index(self, level, drop, inplace, col_level, col_fill)
#    4429                 # to ndarray and maybe infer different dtype
#    4430                 level_values = _maybe_casted_values(lev, lab)
# -> 4431                 new_obj.insert(0, name, level_values)
#    4432
#    4433         new_obj.index = new_index
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in insert(self, loc, column, value, allow_duplicates)
#    3470         self._ensure_valid_index(value)
# ...

# %%
Oceania_waste = pd.DataFrame(df_Oceania, columns =[
                       'waste_collection_coverage_total_percent_of_population',
                       #'waste_collection_coverage_total_percent_of_waste'
])
Oceania_waste.plot.bar(legend=False, stacked=True);
#plt.legend(loc='center left',bbox_to_anchor=(1.0, 0.5))
#plt.yticks(df_Asia.country_name, fontsize=10)
plt.show()
plt.tight_layout()
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">
