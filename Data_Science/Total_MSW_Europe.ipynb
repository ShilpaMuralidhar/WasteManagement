# %%
# %matplotlib notebook
import pandas as pd
pd.set_option('display.max_rows', None)
#from IPython.display import display
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
country_data = "/Users/shilpa/Desktop/Boringppl_project/WasteManagement/Data/country_level_data_0.csv"
country_data_df = pd.read_csv(country_data, encoding = 'utf-8')
country_data_df

Total_MSW = country_data_df[['country_name', 
                       'income_id', 
                       'gdp', 
                       'population_population_number_of_people', 
                       'total_msw_total_msw_generated_tons_year']]
Total_MSW.fillna(0).set_index('country_name')
# Out:
#                                income_id           gdp  \
# country_name
# Aruba                                HIC  0.000000e+00
# Afghanistan                          LIC  2.141361e+10
# Angola                               LMC  1.030423e+11
# Albania                              UMC  1.347108e+10
# Andorra                              HIC  3.319880e+09
# United Arab Emirates                 HIC  3.842225e+11
# Argentina                            HIC  4.475178e+11
# Armenia                              UMC  1.150200e+10
# American Samoa                       UMC  5.345551e+08
# Antigua and Barbuda                  HIC  1.344374e+09
# Australia                            HIC  1.349305e+12
# Austria                              HIC  4.200405e+11
# Azerbaijan                           UMC  5.719553e+10
# Burundi                              LIC  2.297241e+09
# Belgium                              HIC  5.151026e+11
# Benin                                LIC  9.102277e+09
# ...

# %%
# rate of MSW generation per day = total_msw_total_msw_generated_tons_year / 365

#MSW['rate_per_day_kgs'] = MSW['total_msw_total_msw_generated_tons_year'] / 365
Total_MSW['msw_per_day'] =  Total_MSW['total_msw_total_msw_generated_tons_year'] / 365
Total_MSW['msw_per_day_per_person'] =  Total_MSW['total_msw_total_msw_generated_tons_year'] / Total_MSW["population_population_number_of_people"]
Total_MSW.head(1)

#Total_MSW['default_rank'] = Total_MSW['msw_per_day_per_person'].rank(ascending = True)
Total_MSW['default_rank'] = Total_MSW['msw_per_day_per_person']
Total_MSW.head(3)
# Out:
# <ipython-input-3-9dc8b566fa97>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   Total_MSW['msw_per_day'] =  Total_MSW['total_msw_total_msw_generated_tons_year'] / 365
# <ipython-input-3-9dc8b566fa97>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   Total_MSW['msw_per_day_per_person'] =  Total_MSW['total_msw_total_msw_generated_tons_year'] / Total_MSW["population_population_number_of_people"]
# <ipython-input-3-9dc8b566fa97>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
Northern_Europe = Total_MSW.loc[country_data_df['country_name'].
            isin(['Denmark', 'Estonia', 'Faroe Islands', 'Finland', 'Greenland', 'Iceland', 'Ireland', 'Latvia', 
                  'Lithuania', 'Norway', 'Sweden', 'United Kingdom'])].set_index('country_name')


### Run these !!!!!!!
Western_Europe = Total_MSW.loc[country_data_df['country_name'] .\
            isin(['Austria', 'Belgium', 'France', 'Germany', 'Liechtenstein', 'Luxembourg', 'Netherlands', 
                   'Switzerland'])].set_index('country_name')


Eastern_Europe = Total_MSW.loc[country_data_df['country_name'] .\
                isin(['Belarus', 'Bulgaria', 'Czech Republic', 'Hungary', 'Moldova', 'Poland', 'Romania',
                 'Russian Federation', 'Slovak Republic', 'Ukraine'])].set_index('country_name')

Southern_Europe = Total_MSW.loc[country_data_df['country_name'] .\
               isin(['Albania', 'Andorra', 'Bosnia and Herzegovina', 'Croatia', 'Cyprus', 'Gibraltar',
                    'Greece', 'Italy', 'Kosovo', 'Macedonia, FYR', 'Malta', 'Monaco', 'Montenegro',
                    'Portugal', 'San Marino', 'Serbia', 'Slovenia', 'Spain', 'Turkey', 'Vatican City State'])].set_index('country_name')

Europe = [Northern_Europe, Western_Europe, Eastern_Europe, Southern_Europe]
df_Europe = pd.concat(Europe)
df_Europe.drop('default_rank', axis=1)
# Out:
#                        income_id           gdp  \
# country_name
# Denmark                      HIC  3.475197e+11
# Estonia                      HIC  2.380868e+10
# Finland                      HIC  2.526922e+11
# United Kingdom               HIC  2.757620e+12
# Greenland                    HIC  2.823634e+09
# Ireland                      HIC  3.323614e+11
# Iceland                      HIC  1.643489e+10
# Lithuania                    HIC  4.573544e+10
# Latvia                       HIC  2.887150e+10
# Norway                       HIC  4.727659e+11
# Sweden                       HIC  5.603866e+11
# Austria                      HIC  4.200405e+11
# Belgium                      HIC  5.151026e+11
# Switzerland                  HIC  6.420897e+11
# Germany                      HIC  3.781699e+12
# France                       HIC  2.806036e+12
# Liechtenstein                HIC           NaN
# Luxembourg                   HIC  6.320726e+10
# Netherlands                  HIC  8.901359e+11
# ...

# %%
#x = df_Africa.loc[:, ['msw_per_day_per_person']]
#df_Africa['mpg_z'] = (x - x.mean())/x.std()
#df_Africa['colors'] = ['green' if x < 0.5 else 'red' for x in df_Africa['mpg_z']]
#df_Africa.sort_values('mpg_z', inplace=True)
#Total_MSW.reset_index(inplace=True)


x = df_Europe.loc[:, ['msw_per_day_per_person']]
df_Europe['colors'] = ['green' if x < 0.5 else 'red' for x in df_Europe['msw_per_day_per_person']]
df_Europe.sort_values('msw_per_day_per_person', inplace=True)
Total_MSW.reset_index(inplace=True)


# Draw plot
plt.figure(figsize=(14,10), dpi= 80)
plt.hlines(y=df_Europe.index, xmin=0.01, xmax=df_Europe.msw_per_day_per_person, color=df_Europe.colors, alpha=0.4, linewidth=5)




#Decorations
plt.gca().set(ylabel='country_name', xlabel='msw_per_day_per_person')
plt.yticks(df_Europe.country_name, fontsize=12)
plt.title('Waste/person/day in Europe', fontdict={'size':10})
plt.grid(linestyle='--', alpha=0.5)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1120">
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-5-a2b2cf97e676> in <module>
#      21 #Decorations
#      22 plt.gca().set(ylabel='country_name', xlabel='msw_per_day_per_person')
# ---> 23 plt.yticks(df_Europe.country_name, fontsize=12)
#      24 plt.title('Waste/person/day in Europe', fontdict={'size':10})
#      25 plt.grid(linestyle='--', alpha=0.5)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5065             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5066                 return self[name]
# -> 5067             return object.__getattribute__(self, name)
#    5068
#    5069     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'country_name'

# %%
x = df_Europe.loc[:, ['msw_per_day_per_person']]
df_Europe['mpg_z'] = (x - x.mean())/x.std()
df_Europe['colors'] = ['green' if x < 0 else 'red' for x in df_Europe['mpg_z']]
df_Europe.sort_values('mpg_z', inplace=True)
#Total_MSW.reset_index(inplace=True)


#x = df_Africa.loc[:, ['msw_per_day_per_person']]
#df_Africa['colors'] = ['green' if x < 0.5 else 'red' for x in df_Africa['msw_per_day_per_person']]
#df_Africa.sort_values('msw_per_day_per_person', inplace=True)
#Total_MSW.reset_index(inplace=True)


# Draw plot
plt.figure(figsize=(14,10), dpi= 80)
plt.hlines(y=df_Europe.index, xmin=0, xmax=df_Europe.mpg_z, color=df_Europe.colors, alpha=0.4, linewidth=5)




#Decorations
plt.gca().set(ylabel='country_name', xlabel='mpg_z')
plt.yticks(df_Europe.country_name, fontsize=12)
plt.title('Waste/person/day in Europe', fontdict={'size':20})
plt.grid(linestyle='--', alpha=0.5)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1120">
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-6-d2cf08edc89a> in <module>
#      21 #Decorations
#      22 plt.gca().set(ylabel='country_name', xlabel='mpg_z')
# ---> 23 plt.yticks(df_Europe.country_name, fontsize=12)
#      24 plt.title('Waste/person/day in Europe', fontdict={'size':20})
#      25 plt.grid(linestyle='--', alpha=0.5)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5065             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5066                 return self[name]
# -> 5067             return object.__getattribute__(self, name)
#    5068
#    5069     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'country_name'

# %%
x = df_Europe.loc[:, ['msw_per_day_per_person']]
df_Europe['mpg_z'] = (x - x.mean())/x.std()
df_Europe['colors'] = ['green' if x < 0 else 'red' for x in df_Europe['mpg_z']]
df_Europe.sort_values('mpg_z', inplace=True)
df_Europe.reset_index(inplace=True)

# Draw plot
plt.figure(figsize=(14,14), dpi= 80)
plt.hlines(y=df_Europe.country_name, xmin=0, xmax=df_Europe.mpg_z)
for x, y, tex in zip(df_Europe.mpg_z, df_Europe.index, df_Europe.mpg_z):
    t = plt.text(x, y, round(tex, 2), horizontalalignment='right' if x < 0 else 'left', 
                 verticalalignment='center', fontdict={'color':'green' if x < 0 else 'red', 'size':10})
    

# Decorations    
plt.yticks(df_Europe.country_name, fontsize=12)
plt.title('Population-Based Waste Generation Ranking in Europe', fontdict={'size':20})
plt.grid(linestyle='--', alpha=0.5)
plt.xlim(-2.0, 4.5)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1120">

# %%
# Income_Asia = df_Asia.groupby('income_id').income_id.value_counts()
# df_Income_Asia = Income_Asia
Income_Europe = df_Europe.income_id.value_counts()

Income_Europe.plot.bar(legend=True, stacked=False);
plt.legend(loc='center left',bbox_to_anchor=(1.0, 0.5))
plt.show()
plt.tight_layout()

# %%
import joypy
import pandas as pd
from matplotlib import pyplot as plt
from matplotlib import cm
# %matplotlib inline


# !pip install joypy
# Import Data



# Draw Plot
plt.figure(figsize=(10,5), dpi= 80)
fig, axes = joypy.joyplot(df_Europe, column=['msw_per_day_per_person'], by="income_id",  ylim='own',figsize=(10, 5))

# # Decoration
plt.title('Joy Plot of income in Europe', fontsize=12)
#plt.xlim(-2.0, 4.5)
plt.show()
# Out:
# /Users/shilpa/opt/anaconda3/lib/python3.8/site-packages/pandas/plotting/_tools.py:307: MatplotlibDeprecationWarning:
# The rowNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().rowspan.start instead.
#   layout[ax.rowNum, ax.colNum] = ax.get_visible()
# /Users/shilpa/opt/anaconda3/lib/python3.8/site-packages/pandas/plotting/_tools.py:307: MatplotlibDeprecationWarning:
# The colNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().colspan.start instead.
#   layout[ax.rowNum, ax.colNum] = ax.get_visible()
# /Users/shilpa/opt/anaconda3/lib/python3.8/site-packages/pandas/plotting/_tools.py:313: MatplotlibDeprecationWarning:
# The rowNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().rowspan.start instead.
#   if not layout[ax.rowNum + 1, ax.colNum]:
# ...

# %%
MSW_HIC = Total_MSW.groupby('income_id').get_group('LIC')
MSW_HIC.head(5)
# Out:
#     index              country_name income_id           gdp  \
# 1       1               Afghanistan       LIC  2.141361e+10
# 13     13                   Burundi       LIC  2.297241e+09
# 15     15                     Benin       LIC  9.102277e+09
# 16     16              Burkina Faso       LIC  1.238052e+10
# 31     31  Central African Republic       LIC  1.496562e+09
#
#     population_population_number_of_people  \
# 1                               34656032.0
# 13                               6741569.0
# 15                               5521763.0
# 16                              18110624.0
# 31                               4515392.0
#
#     total_msw_total_msw_generated_tons_year   msw_per_day  \
# 1                                5628525.37  15420.617452
# 13                               1872016.00   5128.810959
# 15                                685936.01   1879.276740
# 16                               2575251.11   7055.482493
# ...

# %%
MSW_HIC['default_rank'] = MSW_HIC['msw_per_day_per_person'].rank(ascending = False)
MSW_HIC.head

#MSW_HIC.sort_values(by='msw_per_day_per_person', ascending=False)
# Out:
# <ipython-input-22-aac2b6047c44>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   MSW_HIC['default_rank'] = MSW_HIC['msw_per_day_per_person'].rank(ascending = False)
# <bound method NDFrame.head of      index              country_name income_id           gdp  \
# 1        1               Afghanistan       LIC  2.141361e+10
# 13      13                   Burundi       LIC  2.297241e+09
# 15      15                     Benin       LIC  9.102277e+09
# 16      16              Burkina Faso       LIC  1.238052e+10
# 31      31  Central African Republic       LIC  1.496562e+09
# 39      39          Congo, Dem. Rep.       LIC  3.209000e+10
# 42      42                   Comoros       LIC  6.113708e+08
# ...

# %%
Total_MSW['default_rank'] = Total_MSW['msw_per_day_per_person'].rank(ascending = False)
Total_MSW
# Out:
# <ipython-input-23-e0d78d10633a>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   Total_MSW['default_rank'] = Total_MSW['msw_per_day_per_person'].rank(ascending = False)
#      index                    country_name income_id           gdp  \
# 0        0                           Aruba       HIC           NaN
# 1        1                     Afghanistan       LIC  2.141361e+10
# 2        2                          Angola       LMC  1.030423e+11
# 3        3                         Albania       UMC  1.347108e+10
# 4        4                         Andorra       HIC  3.319880e+09
# 5        5            United Arab Emirates       HIC  3.842225e+11
# 6        6                       Argentina       HIC  4.475178e+11
# ...

# %%
x = MSW_HIC.loc[:, ['default_rank']]
MSW_HIC['mpg_z'] = (x - x.mean())/x.std()
MSW_HIC['colors'] = ['red' if x < 0 else 'green' for x in MSW_HIC['mpg_z']]
MSW_HIC.sort_values('mpg_z', inplace=True)
#Total_MSW.reset_index(inplace=True)



# Draw plot
plt.figure(figsize=(14,10), dpi= 80)
plt.hlines(y=MSW_HIC.index, xmin=0, xmax=MSW_HIC.mpg_z, color=MSW_HIC.colors, alpha=0.4, linewidth=5)




#Decorations
plt.gca().set(ylabel='country_name', xlabel='default_rank')
plt.yticks(MSW_HIC.country_name, fontsize=12)
plt.title('Diverging Bars of Car Mileage', fontdict={'size':20})
plt.grid(linestyle='--', alpha=0.5)
plt.show()
#plt.tight_layout()
# Out:
# <ipython-input-133-ad56b9686964>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   MSW_HIC['mpg_z'] = (x - x.mean())/x.std()
# <ipython-input-133-ad56b9686964>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   MSW_HIC['colors'] = ['red' if x < 0 else 'green' for x in MSW_HIC['mpg_z']]
# <ipython-input-133-ad56b9686964>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...
